# %%
# Import the dependencies.
import pandas as pd
from copy import deepcopy

# Import the requests library.
import requests

# %%
# Set seasons for which to pull data
season1 = 20192020
season2 = season1 - 10001
season3 = season2 - 10001

season1 = str(season1)
season2 = str(season2)
season3 = str(season3)

# %%
# Create endpoint URL for team info
team_url = 'https://statsapi.web.nhl.com/api/v1/teams'

# Run API request for info on all teams
team_info = requests.get(team_url).json()

# Parse JSON to retrieve IDs for all active teams
team_data = []

for team in team_info["teams"]:
    team_data.append({"ID": str(team["id"]),
                      "Team": team["abbreviation"]})
team_data
# Out:
# [{'ID': '1', 'Team': 'NJD'},
#  {'ID': '2', 'Team': 'NYI'},
#  {'ID': '3', 'Team': 'NYR'},
#  {'ID': '4', 'Team': 'PHI'},
#  {'ID': '5', 'Team': 'PIT'},
#  {'ID': '6', 'Team': 'BOS'},
#  {'ID': '7', 'Team': 'BUF'},
#  {'ID': '8', 'Team': 'MTL'},
#  {'ID': '9', 'Team': 'OTT'},
#  {'ID': '10', 'Team': 'TOR'},
#  {'ID': '12', 'Team': 'CAR'},
#  {'ID': '13', 'Team': 'FLA'},
#  {'ID': '14', 'Team': 'TBL'},
#  {'ID': '15', 'Team': 'WSH'},
#  {'ID': '16', 'Team': 'CHI'},
#  {'ID': '17', 'Team': 'DET'},
#  {'ID': '18', 'Team': 'NSH'},
#  {'ID': '19', 'Team': 'STL'},
#  {'ID': '20', 'Team': 'CGY'},
#  {'ID': '21', 'Team': 'COL'},
#  {'ID': '22', 'Team': 'EDM'},
#  {'ID': '23', 'Team': 'VAN'},
#  {'ID': '24', 'Team': 'ANA'},
#  {'ID': '25', 'Team': 'DAL'},
#  {'ID': '26', 'Team': 'LAK'},
#  {'ID': '28', 'Team': 'SJS'},
#  {'ID': '29', 'Team': 'CBJ'},
#  {'ID': '30', 'Team': 'MIN'},
#  {'ID': '52', 'Team': 'WPG'},
#  {'ID': '53', 'Team': 'ARI'},
#  {'ID': '54', 'Team': 'VGK'}]

# %%
# Creating list for player data
player_data = []

# Run API call for each team to get their roster information, then parse roster JSON to retrieve player data
for team in team_data:
    
    # Creating URL for team roster
    roster_url = team_url + "/" + team['ID'] + "/roster"
    
    # API call for team roster in JSON format
    roster_info = requests.get(roster_url).json()
    
    # Retrieving data for each player on roster
    for player in roster_info['roster']:
        player_data.append({'player_id': str(player['person']['id']),
                            'Player Name': player['person']['fullName'], 
                            'Team': team['Team'],
                            'Position': player['position']['abbreviation']})
player_data
# Out:
# [{'player_id': '8475222',
#   'Player Name': 'Sami Vatanen',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8478406',
#   'Player Name': 'Mackenzie Blackwood',
#   'Team': 'NJD',
#   'Position': 'G'},
#  {'player_id': '8478447',
#   'Player Name': 'Nicholas Merkley',
#   'Team': 'NJD',
#   'Position': 'RW'},
#  {'player_id': '8480003',
#   'Player Name': 'Jesper Boqvist',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8480860',
#   'Player Name': 'Kevin Bahl',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8474056',
#   'Player Name': 'P.K. Subban',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8475151',
#   'Player Name': 'Kyle Palmieri',
#   'Team': 'NJD',
#   'Position': 'RW'},
#  {'player_id': '8475179',
#   'Player Name': 'Dmitry Kulikov',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8475809',
#   'Player Name': 'Scott Wedgewood',
#   'Team': 'NJD',
#   'Position': 'G'},
#  {'player_id': '8476807',
#   'Player Name': 'Matt Tennyson',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8476850',
#   'Player Name': 'Ryan Murray',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8476923',
#   'Player Name': 'Damon Severson',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8476941',
#   'Player Name': 'Connor Carrick',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8477038',
#   'Player Name': 'Nikita Gusev',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8477341',
#   'Player Name': 'Andreas Johnsson',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8477355',
#   'Player Name': 'Will Butcher',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8477425',
#   'Player Name': 'Miles Wood',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8477480',
#   'Player Name': 'Eric Comrie',
#   'Team': 'NJD',
#   'Position': 'G'},
#  {'player_id': '8478401',
#   'Player Name': 'Pavel Zacha',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8479407',
#   'Player Name': 'Jesper Bratt',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8479414',
#   'Player Name': 'Nathan Bastian',
#   'Team': 'NJD',
#   'Position': 'RW'},
#  {'player_id': '8479415',
#   'Player Name': 'Michael McLeod',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8479511',
#   'Player Name': 'Janne Kuokkanen',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8479573',
#   'Player Name': 'Mikhail Maltsev',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8480883',
#   'Player Name': 'Ty Smith',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8481068',
#   'Player Name': 'Yegor Sharangovich',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8481559',
#   'Player Name': 'Jack Hughes',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8478463',
#   'Player Name': 'Anthony Beauvillier',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8470187',
#   'Player Name': 'Johnny Boychuk',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8474066',
#   'Player Name': 'Thomas Hickey',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8478857',
#   'Player Name': 'Dmytro Timashov',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8479526',
#   'Player Name': 'Otto Koivula',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8480789',
#   'Player Name': 'Oliver Wahlstrom',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8471239',
#   'Player Name': 'Cory Schneider',
#   'Team': 'NYI',
#   'Position': 'G'},
#  {'player_id': '8472382',
#   'Player Name': 'Andy Greene',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8473463',
#   'Player Name': 'Leo Komarov',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8473504',
#   'Player Name': 'Cal Clutterbuck',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8473575',
#   'Player Name': 'Semyon Varlamov',
#   'Team': 'NYI',
#   'Position': 'G'},
#  {'player_id': '8474573',
#   'Player Name': 'Josh Bailey',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8474586',
#   'Player Name': 'Jordan Eberle',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8474709',
#   'Player Name': 'Matt Martin',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8475181',
#   'Player Name': 'Nick Leddy',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8475231',
#   'Player Name': 'Casey Cizikas',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8475314',
#   'Player Name': 'Anders Lee',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8475754',
#   'Player Name': 'Brock Nelson',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8476419',
#   'Player Name': 'Jean-Gabriel Pageau',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8476429',
#   'Player Name': 'Scott Mayfield',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8476917',
#   'Player Name': 'Adam Pelech',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8477506',
#   'Player Name': 'Ryan Pulock',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8477527',
#   'Player Name': 'Ross Johnston',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8477936',
#   'Player Name': 'Michael Dal Colle',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8478009',
#   'Player Name': 'Ilya Sorokin',
#   'Team': 'NYI',
#   'Position': 'G'},
#  {'player_id': '8478445',
#   'Player Name': 'Mathew Barzal',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8480222',
#   'Player Name': 'Sebastian Aho',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8480865',
#   'Player Name': 'Noah Dobson',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8480078',
#   'Player Name': 'Filip Chytil',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8471677',
#   'Player Name': 'Jack Johnson',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8474090',
#   'Player Name': 'Brendan Smith',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8475184',
#   'Player Name': 'Chris Kreider',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8475868',
#   'Player Name': 'Anthony Bitetto',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8476278',
#   'Player Name': 'Colin Blackwell',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8476458',
#   'Player Name': 'Ryan Strome',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8476459',
#   'Player Name': 'Mika Zibanejad',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8476858',
#   'Player Name': 'Phillip Di Giuseppe',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8476885',
#   'Player Name': 'Jacob Trouba',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8477402',
#   'Player Name': 'Pavel Buchnevich',
#   'Team': 'NYR',
#   'Position': 'RW'},
#  {'player_id': '8477962',
#   'Player Name': 'Brendan Lemieux',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8478048',
#   'Player Name': 'Igor Shesterkin',
#   'Team': 'NYR',
#   'Position': 'G'},
#  {'player_id': '8478550',
#   'Player Name': 'Artemi Panarin',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8479291',
#   'Player Name': 'Kevin Rooney',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8479323',
#   'Player Name': 'Adam Fox',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8479324',
#   'Player Name': 'Ryan Lindgren',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8479328',
#   'Player Name': 'Julien Gauthier',
#   'Team': 'NYR',
#   'Position': 'RW'},
#  {'player_id': '8479353',
#   'Player Name': 'Brett Howden',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8480382',
#   'Player Name': 'Alexandar Georgiev',
#   'Team': 'NYR',
#   'Position': 'G'},
#  {'player_id': '8482109',
#   'Player Name': 'Alexis Lafrenière',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8480028',
#   'Player Name': 'Morgan Frost',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8470880',
#   'Player Name': 'Brian Elliott',
#   'Team': 'PHI',
#   'Position': 'G'},
#  {'player_id': '8473512',
#   'Player Name': 'Claude Giroux',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8474027',
#   'Player Name': 'Justin Braun',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8474037',
#   'Player Name': 'James van Riemsdyk',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8474161',
#   'Player Name': 'Jakub Voracek',
#   'Team': 'PHI',
#   'Position': 'RW'},
#  {'player_id': '8475763',
#   'Player Name': 'Kevin Hayes',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8476461',
#   'Player Name': 'Sean Couturier',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8476872',
#   'Player Name': 'Scott Laughton',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8476906',
#   'Player Name': 'Shayne Gostisbehere',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8476979',
#   'Player Name': 'Erik Gustafsson',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8477290',
#   'Player Name': 'Michael Raffl',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8477462',
#   'Player Name': 'Robert Hagg',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8477948',
#   'Player Name': 'Travis Sanheim',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8477979',
#   'Player Name': 'Nicolas Aube-Kubel',
#   'Team': 'PHI',
#   'Position': 'RW'},
#  {'player_id': '8478017',
#   'Player Name': 'Mark Friedman',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8478067',
#   'Player Name': 'Oskar Lindblom',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8478439',
#   'Player Name': 'Travis Konecny',
#   'Team': 'PHI',
#   'Position': 'RW'},
#  {'player_id': '8478500',
#   'Player Name': 'Ivan Provorov',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8479026',
#   'Player Name': 'Philippe Myers',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8479394',
#   'Player Name': 'Carter Hart',
#   'Team': 'PHI',
#   'Position': 'G'},
#  {'player_id': '8479974',
#   'Player Name': 'Nolan Patrick',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8480797',
#   'Player Name': 'Joel Farabee',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8475208',
#   'Player Name': 'Brian Dumoulin',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8477969',
#   'Player Name': 'Marcus Pettersson',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8478542',
#   'Player Name': 'Evan Rodrigues',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8480945',
#   'Player Name': 'Juuso Riikola',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8476509',
#   'Player Name': 'Maxime Lagace',
#   'Team': 'PIT',
#   'Position': 'G'},
#  {'player_id': '8477814',
#   'Player Name': 'Kevin Czuczman',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8477919',
#   'Player Name': 'Frederick Gaudreau',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8478074',
#   'Player Name': 'Anthony Angello',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8480394',
#   'Player Name': "Alex D'Orio",
#   'Team': 'PIT',
#   'Position': 'G'},
#  {'player_id': '8471215',
#   'Player Name': 'Evgeni Malkin',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8471675',
#   'Player Name': 'Sidney Crosby',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8471724',
#   'Player Name': 'Kris Letang',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8474098',
#   'Player Name': 'Colton Sceviour',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8474134',
#   'Player Name': 'Yannick Weber',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8475722',
#   'Player Name': 'Jason Zucker',
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8475810',
#   'Player Name': 'Bryan Rust',
#   'Team': 'PIT',
#   'Position': 'RW'},
#  {'player_id': '8476873',
#   'Player Name': 'Mark Jankowski',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8476875',
#   'Player Name': 'Mike Matheson',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8476879',
#   'Player Name': 'Cody Ceci',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8476927',
#   'Player Name': 'Teddy Blueger',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8477244',
#   'Player Name': 'Chad Ruhwedel',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8477404',
#   'Player Name': 'Jake Guentzel',
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8477465',
#   'Player Name': 'Tristan Jarry',
#   'Team': 'PIT',
#   'Position': 'G'},
#  {'player_id': '8477953',
#   'Player Name': 'Kasperi Kapanen',
#   'Team': 'PIT',
#   'Position': 'RW'},
#  {'player_id': '8477955',
#   'Player Name': 'Jared McCann',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8478043',
#   'Player Name': 'Sam Lafferty',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8478507',
#   'Player Name': 'John Marino',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8479193',
#   'Player Name': 'Casey DeSmith',
#   'Team': 'PIT',
#   'Position': 'G'},
#  {'player_id': '8479293',
#   'Player Name': 'Brandon Tanev',
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8480058',
#   'Player Name': 'Pierre-Olivier Joseph',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8482055',
#   'Player Name': "Drew O'Connor",
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8478131',
#   'Player Name': 'Ondrej Kase',
#   'Team': 'BOS',
#   'Position': 'RW'},
#  {'player_id': '8478498',
#   'Player Name': 'Jake DeBrusk',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8480021',
#   'Player Name': 'Jack Studnicka',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8470638',
#   'Player Name': 'Patrice Bergeron',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8470860',
#   'Player Name': 'Jaroslav Halak',
#   'Team': 'BOS',
#   'Position': 'G'},
#  {'player_id': '8471276',
#   'Player Name': 'David Krejci',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8471695',
#   'Player Name': 'Tuukka Rask',
#   'Team': 'BOS',
#   'Position': 'G'},
#  {'player_id': '8473419',
#   'Player Name': 'Brad Marchand',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8475186',
#   'Player Name': 'John Moore',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8475225',
#   'Player Name': 'Craig Smith',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8475745',
#   'Player Name': 'Charlie Coyle',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8475780',
#   'Player Name': 'Chris Wagner',
#   'Team': 'BOS',
#   'Position': 'RW'},
#  {'player_id': '8476191',
#   'Player Name': 'Kevan Miller',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8476374',
#   'Player Name': 'Sean Kuraly',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8476891',
#   'Player Name': 'Matt Grzelcyk',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8477365',
#   'Player Name': 'Connor Clifton',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8477941',
#   'Player Name': 'Nick Ritchie',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8477956',
#   'Player Name': 'David Pastrnak',
#   'Team': 'BOS',
#   'Position': 'RW'},
#  {'player_id': '8478075',
#   'Player Name': 'Anders Bjork',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8478415',
#   'Player Name': 'Jakub Zboril',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8478443',
#   'Player Name': 'Brandon Carlo',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8478468',
#   'Player Name': 'Jeremy Lauzon',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8479325',
#   'Player Name': 'Charlie McAvoy',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8479365',
#   'Player Name': 'Trent Frederic',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8476878',
#   'Player Name': 'Zemgus Girgensons',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8475869',
#   'Player Name': 'Brandon Davidson',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8477520',
#   'Player Name': 'Jean-Sebastien Dea',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8477992',
#   'Player Name': 'Jonas Johansson',
#   'Team': 'BUF',
#   'Position': 'G'},
#  {'player_id': '8478840',
#   'Player Name': 'William Borgen',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8480083',
#   'Player Name': 'C.J. Smith',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8470595',
#   'Player Name': 'Eric Staal',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8473449',
#   'Player Name': 'Kyle Okposo',
#   'Team': 'BUF',
#   'Position': 'RW'},
#  {'player_id': '8475236',
#   'Player Name': 'Cody Eakin',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8475622',
#   'Player Name': 'Carter Hutton',
#   'Team': 'BUF',
#   'Position': 'G'},
#  {'player_id': '8475625',
#   'Player Name': 'Matt Irwin',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8475772',
#   'Player Name': 'Riley Sheahan',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8475784',
#   'Player Name': 'Jeff Skinner',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8475791',
#   'Player Name': 'Taylor Hall',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8476356',
#   'Player Name': 'Tobias Rieder',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8476525',
#   'Player Name': 'Colin Miller',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8476931',
#   'Player Name': 'Jake McCabe',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8476999',
#   'Player Name': 'Linus Ullmark',
#   'Team': 'BUF',
#   'Position': 'G'},
#  {'player_id': '8477499',
#   'Player Name': 'Rasmus Ristolainen',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8477508',
#   'Player Name': 'Curtis Lazar',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8477933',
#   'Player Name': 'Sam Reinhart',
#   'Team': 'BUF',
#   'Position': 'RW'},
#  {'player_id': '8477986',
#   'Player Name': 'Brandon Montour',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8478109',
#   'Player Name': 'Victor Olofsson',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8478403',
#   'Player Name': 'Jack Eichel',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8479420',
#   'Player Name': 'Tage Thompson',
#   'Team': 'BUF',
#   'Position': 'RW'},
#  {'player_id': '8479999',
#   'Player Name': 'Casey Mittelstadt',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8480035',
#   'Player Name': 'Henri Jokiharju',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8480839',
#   'Player Name': 'Rasmus Dahlin',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8481528',
#   'Player Name': 'Dylan Cozens',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8470621',
#   'Player Name': 'Corey Perry',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8473564',
#   'Player Name': 'Michael Frolik',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8478133',
#   'Player Name': 'Jake Evans',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8479292',
#   'Player Name': 'Charlie Lindgren',
#   'Team': 'MTL',
#   'Position': 'G'},
#  {'player_id': '8470642',
#   'Player Name': 'Shea Weber',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8471679',
#   'Player Name': 'Carey Price',
#   'Team': 'MTL',
#   'Position': 'G'},
#  {'player_id': '8473507',
#   'Player Name': 'Jeff Petry',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8474038',
#   'Player Name': 'Paul Byron',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8474596',
#   'Player Name': 'Jake Allen',
#   'Team': 'MTL',
#   'Position': 'G'},
#  {'player_id': '8475193',
#   'Player Name': 'Tomas Tatar',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8475279',
#   'Player Name': 'Ben Chiarot',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8475726',
#   'Player Name': 'Tyler Toffoli',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8475848',
#   'Player Name': 'Brendan Gallagher',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8476441',
#   'Player Name': 'Joel Edmundson',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8476469',
#   'Player Name': 'Joel Armia',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8476479',
#   'Player Name': 'Phillip Danault',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8476967',
#   'Player Name': 'Brett Kulak',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8476981',
#   'Player Name': 'Josh Anderson',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8477476',
#   'Player Name': 'Artturi Lehkonen',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8477494',
#   'Player Name': 'Jonathan Drouin',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8479376',
#   'Player Name': 'Victor Mete',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8480018',
#   'Player Name': 'Nick Suzuki',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8480829',
#   'Player Name': 'Jesperi Kotkaniemi',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8481014',
#   'Player Name': 'Alexander Romanov',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8480073',
#   'Player Name': 'Erik Brannstrom',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8474230',
#   'Player Name': 'Micheal Haley',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8476285',
#   'Player Name': 'Matthew Peca',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8478488',
#   'Player Name': 'Filip Chlapik',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8473573',
#   'Player Name': 'Artem Anisimov',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8474149',
#   'Player Name': 'Evgenii Dadonov',
#   'Team': 'OTT',
#   'Position': 'RW'},
#  {'player_id': '8474613',
#   'Player Name': 'Derek Stepan',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8475766',
#   'Player Name': 'Austin Watson',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8475790',
#   'Player Name': 'Erik Gudbranson',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8476422',
#   'Player Name': 'Mike Reilly',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8476851',
#   'Player Name': 'Alex Galchenyuk',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8476899',
#   'Player Name': 'Matt Murray',
#   'Team': 'OTT',
#   'Position': 'G'},
#  {'player_id': '8476919',
#   'Player Name': 'Chris Tierney',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8476975',
#   'Player Name': 'Cedric Paquette',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8477015',
#   'Player Name': 'Connor Brown',
#   'Team': 'OTT',
#   'Position': 'RW'},
#  {'player_id': '8477384',
#   'Player Name': 'Josh Brown',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8477405',
#   'Player Name': 'Marcus Hogberg',
#   'Team': 'OTT',
#   'Position': 'G'},
#  {'player_id': '8477426',
#   'Player Name': 'Nick Paul',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8478400',
#   'Player Name': 'Colin White',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8478469',
#   'Player Name': 'Thomas Chabot',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8478846',
#   'Player Name': 'Christian Wolanin',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8479458',
#   'Player Name': 'Nikita Zaitsev',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8480064',
#   'Player Name': 'Josh Norris',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8480208',
#   'Player Name': 'Drake Batherson',
#   'Team': 'OTT',
#   'Position': 'RW'},
#  {'player_id': '8480801',
#   'Player Name': 'Brady Tkachuk',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8482116',
#   'Player Name': 'Tim Stützle',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8482245',
#   'Player Name': 'Artem Zub',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8466138',
#   'Player Name': 'Joe Thornton',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8474190',
#   'Player Name': 'Wayne Simmonds',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8475789',
#   'Player Name': 'Jack Campbell',
#   'Team': 'TOR',
#   'Position': 'G'},
#  {'player_id': '8481582',
#   'Player Name': 'Nicholas Robertson',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8478115',
#   'Player Name': 'Pierre Engvall',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8469455',
#   'Player Name': 'Jason Spezza',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8474162',
#   'Player Name': 'Jake Muzzin',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8474567',
#   'Player Name': 'Zach Bogosian',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8474636',
#   'Player Name': 'Michael Hutchinson',
#   'Team': 'TOR',
#   'Position': 'G'},
#  {'player_id': '8474673',
#   'Player Name': 'TJ Brodie',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8475166',
#   'Player Name': 'John Tavares',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8475718',
#   'Player Name': 'Justin Holl',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8475786',
#   'Player Name': 'Zach Hyman',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8475883',
#   'Player Name': 'Frederik Andersen',
#   'Team': 'TOR',
#   'Position': 'G'},
#  {'player_id': '8476329',
#   'Player Name': 'Travis Boyd',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8476853',
#   'Player Name': 'Morgan Rielly',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8476918',
#   'Player Name': 'Jimmy Vesey',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8477021',
#   'Player Name': 'Alexander Kerfoot',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8477939',
#   'Player Name': 'William Nylander',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8478408',
#   'Player Name': 'Travis Dermott',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8478483',
#   'Player Name': 'Mitchell Marner',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8479318',
#   'Player Name': 'Auston Matthews',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8480873',
#   'Player Name': 'Rasmus Sandin',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8481624',
#   'Player Name': 'Ilya Mikheyev',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8482222',
#   'Player Name': 'Alexander Barabanov',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8482247',
#   'Player Name': 'Mikko Lehtonen',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8476323',
#   'Player Name': 'Max McCormick',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8473503',
#   'Player Name': 'James Reimer',
#   'Team': 'CAR',
#   'Position': 'G'},
#  {'player_id': '8473533',
#   'Player Name': 'Jordan Staal',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8474581',
#   'Player Name': 'Jake Gardiner',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8475799',
#   'Player Name': 'Nino Niederreiter',
#   'Team': 'CAR',
#   'Position': 'RW'},
#  {'player_id': '8475852',
#   'Player Name': 'Petr Mrazek',
#   'Team': 'CAR',
#   'Position': 'G'},
#  {'player_id': '8475855',
#   'Player Name': 'Jesper Fast',
#   'Team': 'CAR',
#   'Position': 'RW'},
#  {'player_id': '8476288',
#   'Player Name': 'Ryan Dzingel',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8476389',
#   'Player Name': 'Vincent Trocheck',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8476462',
#   'Player Name': 'Dougie Hamilton',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8476869',
#   'Player Name': 'Brady Skjei',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8476882',
#   'Player Name': 'Teuvo Teravainen',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8476921',
#   'Player Name': 'Jordan Martinook',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8476934',
#   'Player Name': 'Brock McGinn',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8476958',
#   'Player Name': 'Jaccob Slavin',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8477488',
#   'Player Name': 'Brett Pesce',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8477938',
#   'Player Name': 'Haydn Fleury',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8477998',
#   'Player Name': 'Warren Foegele',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8478427',
#   'Player Name': 'Sebastian Aho',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8480039',
#   'Player Name': 'Martin Necas',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8480830',
#   'Player Name': 'Andrei Svechnikov',
#   'Team': 'CAR',
#   'Position': 'RW'},
#  {'player_id': '8478055',
#   'Player Name': 'Gustav Forsling',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8475246',
#   'Player Name': 'Kevin Connauton',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8477475',
#   'Player Name': 'Philippe Desrosiers',
#   'Team': 'FLA',
#   'Position': 'G'},
#  {'player_id': '8478975',
#   'Player Name': 'Mason Marchment',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8471735',
#   'Player Name': 'Keith Yandle',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8471873',
#   'Player Name': 'Anton Stralman',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8471887',
#   'Player Name': 'Patric Hornqvist',
#   'Team': 'FLA',
#   'Position': 'RW'},
#  {'player_id': '8475462',
#   'Player Name': 'Radko Gudas',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8475683',
#   'Player Name': 'Sergei Bobrovsky',
#   'Team': 'FLA',
#   'Position': 'G'},
#  {'player_id': '8475792',
#   'Player Name': 'Brett Connolly',
#   'Team': 'FLA',
#   'Position': 'RW'},
#  {'player_id': '8476456',
#   'Player Name': 'Jonathan Huberdeau',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8476904',
#   'Player Name': 'Chris Driedger',
#   'Team': 'FLA',
#   'Position': 'G'},
#  {'player_id': '8476994',
#   'Player Name': 'Vinnie Hinostroza',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477346',
#   'Player Name': 'MacKenzie Weegar',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8477407',
#   'Player Name': 'Anthony Duclair',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8477409',
#   'Player Name': 'Carter Verhaeghe',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477493',
#   'Player Name': 'Aleksander Barkov',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477505',
#   'Player Name': 'Alex Wennberg',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477932',
#   'Player Name': 'Aaron Ekblad',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8477996',
#   'Player Name': 'Juho Lammikko',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8478366',
#   'Player Name': 'Frank Vatrano',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8478454',
#   'Player Name': 'Noah Juulsen',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8478569',
#   'Player Name': 'Noel Acciari',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8478906',
#   'Player Name': 'Markus Nutivaara',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8479066',
#   'Player Name': 'Ryan Lomberg',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8480015',
#   'Player Name': 'Owen Tippett',
#   'Team': 'FLA',
#   'Position': 'RW'},
#  {'player_id': '8480185',
#   'Player Name': 'Eetu Luostarinen',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8475195',
#   'Player Name': 'Anders Nilsson',
#   'Team': 'TBL',
#   'Position': 'G'},
#  {'player_id': '8478477',
#   'Player Name': 'Mitchell Stephens',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8476444',
#   'Player Name': 'Christopher Gibson',
#   'Team': 'TBL',
#   'Position': 'G'},
#  {'player_id': '8476966',
#   'Player Name': 'Gemel Smith',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8480158',
#   'Player Name': 'Andreas Borgman',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8470147',
#   'Player Name': 'Curtis McElhinney',
#   'Team': 'TBL',
#   'Position': 'G'},
#  {'player_id': '8473986',
#   'Player Name': 'Alex Killorn',
#   'Team': 'TBL',
#   'Position': 'LW'},
#  {'player_id': '8474034',
#   'Player Name': 'Pat Maroon',
#   'Team': 'TBL',
#   'Position': 'LW'},
#  {'player_id': '8474151',
#   'Player Name': 'Ryan McDonagh',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8474564',
#   'Player Name': 'Steven Stamkos',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8474568',
#   'Player Name': 'Luke Schenn',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8474870',
#   'Player Name': 'Tyler Johnson',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8475167',
#   'Player Name': 'Victor Hedman',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8476292',
#   'Player Name': 'Ondrej Palat',
#   'Team': 'TBL',
#   'Position': 'LW'},
#  {'player_id': '8476399',
#   'Player Name': 'Blake Coleman',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8476624',
#   'Player Name': 'Barclay Goodrow',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8476826',
#   'Player Name': 'Yanni Gourde',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8476883',
#   'Player Name': 'Andrei Vasilevskiy',
#   'Team': 'TBL',
#   'Position': 'G'},
#  {'player_id': '8478010',
#   'Player Name': 'Brayden Point',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8478416',
#   'Player Name': 'Erik Cernak',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8478472',
#   'Player Name': 'Mathieu Joseph',
#   'Team': 'TBL',
#   'Position': 'RW'},
#  {'player_id': '8478519',
#   'Player Name': 'Anthony Cirelli',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8479410',
#   'Player Name': 'Mikhail Sergachev',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8479984',
#   'Player Name': 'Callan Foote',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8480172',
#   'Player Name': 'Jan Rutta',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8480186',
#   'Player Name': 'Alexander Volkov',
#   'Team': 'TBL',
#   'Position': 'RW'},
#  {'player_id': '8467950',
#   'Player Name': 'Craig Anderson',
#   'Team': 'WSH',
#   'Position': 'G'},
#  {'player_id': '8475744',
#   'Player Name': 'Evgeny Kuznetsov',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8475958',
#   'Player Name': 'Michael Sgarbossa',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8477314',
#   'Player Name': 'Brian Pinho',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8477901',
#   'Player Name': 'Daniel Carr',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8477944',
#   'Player Name': 'Jakub Vrana',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8478492',
#   'Player Name': 'Ilya Samsonov',
#   'Team': 'WSH',
#   'Position': 'G'},
#  {'player_id': '8479482',
#   'Player Name': 'Michal Kempny',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8465009',
#   'Player Name': 'Zdeno Chara',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8471214',
#   'Player Name': 'Alex Ovechkin',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8471698',
#   'Player Name': 'T.J. Oshie',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8473563',
#   'Player Name': 'Nicklas Backstrom',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8474176',
#   'Player Name': 'Carl Hagelin',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8474189',
#   'Player Name': 'Lars Eller',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8474590',
#   'Player Name': 'John Carlson',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8474602',
#   'Player Name': 'Justin Schultz',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8475200',
#   'Player Name': 'Dmitry Orlov',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8475209',
#   'Player Name': 'Richard Panik',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8475324',
#   'Player Name': 'Nick Jensen',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8475343',
#   'Player Name': 'Nic Dowd',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8475455',
#   'Player Name': 'Brenden Dillon',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8476880',
#   'Player Name': 'Tom Wilson',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8477839',
#   'Player Name': 'Conor Sheary',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8477845',
#   'Player Name': 'Trevor van Riemsdyk',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8477903',
#   'Player Name': 'Garnet Hathaway',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8477970',
#   'Player Name': 'Vitek Vanecek',
#   'Team': 'WSH',
#   'Position': 'G'},
#  {'player_id': '8478399',
#   'Player Name': 'Jonas Siegenthaler',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8478466',
#   'Player Name': 'Daniel Sprong',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8470607',
#   'Player Name': 'Brent Seabrook',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8474250',
#   'Player Name': 'Zack Smith',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8473604',
#   'Player Name': 'Jonathan Toews',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8477846',
#   'Player Name': 'Ryan Carpenter',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8478027',
#   'Player Name': 'Lucas Wallmark',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8478073',
#   'Player Name': 'Anton Lindholm',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8479423',
#   'Player Name': 'Alex Nylander',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8480025',
#   'Player Name': 'MacKenzie Entwistle',
#   'Team': 'CHI',
#   'Position': 'RW'},
#  {'player_id': '8480871',
#   'Player Name': 'Adam Boqvist',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8481147',
#   'Player Name': 'Reese Johnson',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8481523',
#   'Player Name': 'Kirby Dach',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8470281',
#   'Player Name': 'Duncan Keith',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8471262',
#   'Player Name': 'Carl Soderberg',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8474141',
#   'Player Name': 'Patrick Kane',
#   'Team': 'CHI',
#   'Position': 'RW'},
#  {'player_id': '8475177',
#   'Player Name': 'Calvin de Haan',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8476381',
#   'Player Name': 'Andrew Shaw',
#   'Team': 'CHI',
#   'Position': 'RW'},
#  {'player_id': '8476473',
#   'Player Name': 'Connor Murphy',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8476876',
#   'Player Name': 'Malcolm Subban',
#   'Team': 'CHI',
#   'Position': 'G'},
#  {'player_id': '8477330',
#   'Player Name': 'Dominik Kubalik',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8477406',
#   'Player Name': 'Mattias Janmark',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8477474',
#   'Player Name': 'Madison Bowey',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8477507',
#   'Player Name': 'Nikita Zadorov',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8478146',
#   'Player Name': 'Matthew Highmore',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8478440',
#   'Player Name': 'Dylan Strome',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8479337',
#   'Player Name': 'Alex DeBrincat',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8479523',
#   'Player Name': 'Lucas Carlsson',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8479542',
#   'Player Name': 'Brandon Hagel',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8480070',
#   'Player Name': 'Ian Mitchell',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8480144',
#   'Player Name': 'David Kampf',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8480420',
#   'Player Name': 'Collin Delia',
#   'Team': 'CHI',
#   'Position': 'G'},
#  {'player_id': '8480459',
#   'Player Name': 'Pius Suter',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8480798',
#   'Player Name': 'Philipp Kurashev',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8480814',
#   'Player Name': 'Nicolas Beaudin',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8480947',
#   'Player Name': 'Kevin Lankinen',
#   'Team': 'CHI',
#   'Position': 'G'},
#  {'player_id': '8473541',
#   'Player Name': 'Jonathan Bernier',
#   'Team': 'DET',
#   'Position': 'G'},
#  {'player_id': '8477479',
#   'Player Name': 'Tyler Bertuzzi',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8470047',
#   'Player Name': 'Valtteri Filppula',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8470144',
#   'Player Name': 'Frans Nielsen',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8471306',
#   'Player Name': 'Thomas Greiss',
#   'Team': 'DET',
#   'Position': 'G'},
#  {'player_id': '8471676',
#   'Player Name': 'Bobby Ryan',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8471686',
#   'Player Name': 'Marc Staal',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8471794',
#   'Player Name': 'Darren Helm',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8474040',
#   'Player Name': 'Sam Gagner',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8475717',
#   'Player Name': 'Calvin Pickard',
#   'Team': 'DET',
#   'Position': 'G'},
#  {'player_id': '8475747',
#   'Player Name': 'Patrik Nemeth',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8475750',
#   'Player Name': 'Jon Merrill',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8476480',
#   'Player Name': 'Vladislav Namestnikov',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8476822',
#   'Player Name': 'Luke Glendening',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8477043',
#   'Player Name': 'Christian Djoos',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8477215',
#   'Player Name': 'Danny DeKeyser',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8477454',
#   'Player Name': 'Adam Erne',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8477511',
#   'Player Name': 'Anthony Mantha',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8477946',
#   'Player Name': 'Dylan Larkin',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8477952',
#   'Player Name': 'Robby Fabbri',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8479379',
#   'Player Name': 'Givani Smith',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8479425',
#   'Player Name': 'Filip Hronek',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8479442',
#   'Player Name': 'Troy Stecher',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8480821',
#   'Player Name': 'Filip Zadina',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8482240',
#   'Player Name': 'Mathias Brome',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8470755',
#   'Player Name': 'Brad Richardson',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8474579',
#   'Player Name': 'Luca Sbisa',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475793',
#   'Player Name': 'Ryan Johansen',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8477433',
#   'Player Name': 'Ben Harpur',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8479288',
#   'Player Name': 'Kasimir Kaskisuo',
#   'Team': 'NSH',
#   'Position': 'G'},
#  {'player_id': '8480009',
#   'Player Name': 'Eeli Tolvanen',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8471469',
#   'Player Name': 'Pekka Rinne',
#   'Team': 'NSH',
#   'Position': 'G'},
#  {'player_id': '8474600',
#   'Player Name': 'Roman Josi',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8474697',
#   'Player Name': 'Mark Borowiecki',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475168',
#   'Player Name': 'Matt Duchene',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8475176',
#   'Player Name': 'Ryan Ellis',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475218',
#   'Player Name': 'Mattias Ekholm',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475287',
#   'Player Name': 'Erik Haula',
#   'Team': 'NSH',
#   'Position': 'LW'},
#  {'player_id': '8475714',
#   'Player Name': 'Calle Jarnkrok',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8475797',
#   'Player Name': 'Jarred Tinordi',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475798',
#   'Player Name': 'Mikael Granlund',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8476393',
#   'Player Name': 'Nick Cousins',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8476428',
#   'Player Name': 'Rocco Grimaldi',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8476887',
#   'Player Name': 'Filip Forsberg',
#   'Team': 'NSH',
#   'Position': 'LW'},
#  {'player_id': '8476925',
#   'Player Name': 'Colton Sissons',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8476988',
#   'Player Name': 'Matt Benning',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8477391',
#   'Player Name': 'Sean Malone',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8477424',
#   'Player Name': 'Juuse Saros',
#   'Team': 'NSH',
#   'Position': 'G'},
#  {'player_id': '8477446',
#   'Player Name': 'Michael McCarron',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8478042',
#   'Player Name': 'Viktor Arvidsson',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8478508',
#   'Player Name': 'Yakov Trenin',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8479316',
#   'Player Name': 'Luke Kunin',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8479371',
#   'Player Name': 'Dante Fabbro',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8479671',
#   'Player Name': 'Mathieu Olivier',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8475098',
#   'Player Name': 'Tyler Bozak',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8480023',
#   'Player Name': 'Robert Thomas',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8476907',
#   'Player Name': 'Mackenzie MacEachern',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8477455',
#   'Player Name': 'Jacob de la Rose',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8474102',
#   'Player Name': 'David Perron',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8474125',
#   'Player Name': 'Carl Gunnarsson',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8474145',
#   'Player Name': 'Robert Bortuzzo',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8474618',
#   'Player Name': 'Marco Scandella',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8474884',
#   'Player Name': 'Mike Hoffman',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8475158',
#   'Player Name': "Ryan O'Reilly",
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8475160',
#   'Player Name': 'Kyle Clifford',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8475170',
#   'Player Name': 'Brayden Schenn',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8475753',
#   'Player Name': 'Justin Faulk',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8475768',
#   'Player Name': 'Jaden Schwartz',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8476412',
#   'Player Name': 'Jordan Binnington',
#   'Team': 'STL',
#   'Position': 'G'},
#  {'player_id': '8476792',
#   'Player Name': 'Torey Krug',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8476892',
#   'Player Name': 'Colton Parayko',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8476897',
#   'Player Name': 'Oskar Sundqvist',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8477482',
#   'Player Name': 'Zach Sanford',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8477964',
#   'Player Name': 'Ivan Barbashev',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8478024',
#   'Player Name': 'Ville Husso',
#   'Team': 'STL',
#   'Position': 'G'},
#  {'player_id': '8478104',
#   'Player Name': 'Sammy Blais',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8478407',
#   'Player Name': 'Vince Dunn',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8478859',
#   'Player Name': 'Niko Mikkola',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8479385',
#   'Player Name': 'Jordan Kyrou',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8478585',
#   'Player Name': 'Derek Ryan',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8474736',
#   'Player Name': 'Zac Rinaldo',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8475839',
#   'Player Name': 'Louis Domingue',
#   'Team': 'CGY',
#   'Position': 'G'},
#  {'player_id': '8477210',
#   'Player Name': 'Buddy Robinson',
#   'Team': 'CGY',
#   'Position': 'RW'},
#  {'player_id': '8478430',
#   'Player Name': 'Oliver Kylington',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8470966',
#   'Player Name': 'Mark Giordano',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8473473',
#   'Player Name': 'Milan Lucic',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8474150',
#   'Player Name': 'Mikael Backlund',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8474593',
#   'Player Name': 'Jacob Markstrom',
#   'Team': 'CGY',
#   'Position': 'G'},
#  {'player_id': '8475278',
#   'Player Name': 'Byron Froese',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8475690',
#   'Player Name': 'Christopher Tanev',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8475807',
#   'Player Name': 'Joakim Nordstrom',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8476300',
#   'Player Name': 'Nikita Nesterov',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8476346',
#   'Player Name': 'Johnny Gaudreau',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8476410',
#   'Player Name': 'Josh Leivo',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8476439',
#   'Player Name': 'Brett Ritchie',
#   'Team': 'CGY',
#   'Position': 'RW'},
#  {'player_id': '8477496',
#   'Player Name': 'Elias Lindholm',
#   'Team': 'CGY',
# ...
#   'Player Name': 'Trevor Moore',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8479994',
#   'Player Name': 'Jaret Anderson-Dolan',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8479998',
#   'Player Name': 'Mikey Anderson',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8480014',
#   'Player Name': 'Gabriel Vilardi',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8480072',
#   'Player Name': 'Lias Andersson',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8480113',
#   'Player Name': 'Alex Iafallo',
#   'Team': 'LAK',
#   'Position': 'LW'},
#  {'player_id': '8480467',
#   'Player Name': 'Austin Strand',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8481600',
#   'Player Name': 'Tobias Bjornfot',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8466139',
#   'Player Name': 'Patrick Marleau',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8470613',
#   'Player Name': 'Brent Burns',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8471227',
#   'Player Name': 'Devan Dubnyk',
#   'Team': 'SJS',
#   'Position': 'G'},
#  {'player_id': '8471709',
#   'Player Name': 'Marc-Edouard Vlasic',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8474053',
#   'Player Name': 'Logan Couture',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8474578',
#   'Player Name': 'Erik Karlsson',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8474889',
#   'Player Name': 'Martin Jones',
#   'Team': 'SJS',
#   'Position': 'G'},
#  {'player_id': '8475169',
#   'Player Name': 'Evander Kane',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8475834',
#   'Player Name': 'Marcus Sorensen',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8476442',
#   'Player Name': 'Matt Nieto',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8476474',
#   'Player Name': 'Stefan Noesen',
#   'Team': 'SJS',
#   'Position': 'RW'},
#  {'player_id': '8476881',
#   'Player Name': 'Tomas Hertl',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8477987',
#   'Player Name': 'Ryan Donato',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8478099',
#   'Player Name': 'Kevin Labanc',
#   'Team': 'SJS',
#   'Position': 'RW'},
#  {'player_id': '8478414',
#   'Player Name': 'Timo Meier',
#   'Team': 'SJS',
#   'Position': 'RW'},
#  {'player_id': '8478467',
#   'Player Name': 'Nicolas Meloche',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8478870',
#   'Player Name': 'Rudolfs Balcers',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8479393',
#   'Player Name': 'Noah Gregor',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8479580',
#   'Player Name': 'Dylan Gambrell',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8479983',
#   'Player Name': 'Mario Ferraro',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8480053',
#   'Player Name': 'Alexander Chmelevski',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8480160',
#   'Player Name': 'Radim Simek',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8481812',
#   'Player Name': 'Nikolai Knyzhov',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8471273',
#   'Player Name': 'Brandon Dubinsky',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478007',
#   'Player Name': 'Elvis Merzlikins',
#   'Team': 'CBJ',
#   'Position': 'G'},
#  {'player_id': '8478460',
#   'Player Name': 'Zach Werenski',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8476870',
#   'Player Name': 'Stefan Matteau',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8473422',
#   'Player Name': 'Nick Foligno',
#   'Team': 'CBJ',
#   'Position': 'LW'},
#  {'player_id': '8474062',
#   'Player Name': 'Riley Nash',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8474584',
#   'Player Name': 'Michael Del Zotto',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8474715',
#   'Player Name': 'Cam Atkinson',
#   'Team': 'CBJ',
#   'Position': 'RW'},
#  {'player_id': '8475233',
#   'Player Name': 'David Savard',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8476432',
#   'Player Name': 'Boone Jenner',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8476449',
#   'Player Name': 'Scott Harrington',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8476888',
#   'Player Name': 'Mikhail Grigorenko',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8476914',
#   'Player Name': 'Joonas Korpisalo',
#   'Team': 'CBJ',
#   'Position': 'G'},
#  {'player_id': '8477416',
#   'Player Name': 'Oliver Bjorkstrand',
#   'Team': 'CBJ',
#   'Position': 'RW'},
#  {'player_id': '8477495',
#   'Player Name': 'Seth Jones',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8477503',
#   'Player Name': 'Max Domi',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478458',
#   'Player Name': 'Jack Roslovic',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478506',
#   'Player Name': 'Gabriel Carlsson',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8478567',
#   'Player Name': 'Dean Kukan',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8478831',
#   'Player Name': 'Kevin Stenlund',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478882',
#   'Player Name': 'Vladislav Gavrikov',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8479339',
#   'Player Name': 'Patrik Laine',
#   'Team': 'CBJ',
#   'Position': 'RW'},
#  {'player_id': '8480074',
#   'Player Name': 'Alexandre Texier',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8480162',
#   'Player Name': 'Matiss Kivlenieks',
#   'Team': 'CBJ',
#   'Position': 'G'},
#  {'player_id': '8480762',
#   'Player Name': 'Eric Robinson',
#   'Team': 'CBJ',
#   'Position': 'LW'},
#  {'player_id': '8476856',
#   'Player Name': 'Matt Dumba',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8471774',
#   'Player Name': 'Alex Stalock',
#   'Team': 'MIN',
#   'Position': 'G'},
#  {'player_id': '8474749',
#   'Player Name': 'Matt Bartkowski',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8475692',
#   'Player Name': 'Mats Zuccarello',
#   'Team': 'MIN',
#   'Position': 'RW'},
#  {'player_id': '8476415',
#   'Player Name': 'Kyle Rau',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8477202',
#   'Player Name': 'Andrew Hammond',
#   'Team': 'MIN',
#   'Position': 'G'},
#  {'player_id': '8477366',
#   'Player Name': 'Luke Johnson',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8477541',
#   'Player Name': 'Dakota Mermis',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8478011',
#   'Player Name': 'Louie Belpedio',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8479933',
#   'Player Name': 'Gerald Mayhew',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8482079',
#   'Player Name': 'Marco Rossi',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8470600',
#   'Player Name': 'Ryan Suter',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8470610',
#   'Player Name': 'Zach Parise',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8474009',
#   'Player Name': 'Nick Bonino',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8474013',
#   'Player Name': 'Ian Cole',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8474716',
#   'Player Name': 'Jared Spurgeon',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8475149',
#   'Player Name': 'Marcus Johansson',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8475220',
#   'Player Name': 'Marcus Foligno',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8475660',
#   'Player Name': 'Cam Talbot',
#   'Team': 'MIN',
#   'Position': 'G'},
#  {'player_id': '8475760',
#   'Player Name': 'Nick Bjugstad',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8476437',
#   'Player Name': 'Victor Rask',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8476463',
#   'Player Name': 'Jonas Brodin',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8476779',
#   'Player Name': 'Brad Hunt',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8477369',
#   'Player Name': 'Carson Soucy',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8477451',
#   'Player Name': 'Ryan Hartman',
#   'Team': 'MIN',
#   'Position': 'RW'},
#  {'player_id': '8477942',
#   'Player Name': 'Kevin Fiala',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8478039',
#   'Player Name': 'Kaapo Kahkonen',
#   'Team': 'MIN',
#   'Position': 'G'},
#  {'player_id': '8478413',
#   'Player Name': 'Jordan Greenway',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8478493',
#   'Player Name': 'Joel Eriksson Ek',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8478864',
#   'Player Name': 'Kirill Kaprizov',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8481477',
#   'Player Name': 'Nico Sturm',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8470775',
#   'Player Name': 'Nate Thompson',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8473412',
#   'Player Name': 'Bryan Little',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8478424',
#   'Player Name': 'Jansen Harkins',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8477359',
#   'Player Name': 'Tucker Poolman',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8481572',
#   'Player Name': 'Ville Heinola',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8471218',
#   'Player Name': 'Blake Wheeler',
#   'Team': 'WPG',
#   'Position': 'RW'},
#  {'player_id': '8471669',
#   'Player Name': 'Paul Stastny',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8473453',
#   'Player Name': 'Trevor Lewis',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8473618',
#   'Player Name': 'Mathieu Perreault',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8475762',
#   'Player Name': 'Derek Forbort',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8476316',
#   'Player Name': 'Laurent Brossoit',
#   'Team': 'WPG',
#   'Position': 'G'},
#  {'player_id': '8476331',
#   'Player Name': 'Dylan DeMelo',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8476341',
#   'Player Name': 'Anton Forsberg',
#   'Team': 'WPG',
#   'Position': 'G'},
#  {'player_id': '8476392',
#   'Player Name': 'Adam Lowry',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8476460',
#   'Player Name': 'Mark Scheifele',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8476470',
#   'Player Name': 'Nathan Beaulieu',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8476945',
#   'Player Name': 'Connor Hellebuyck',
#   'Team': 'WPG',
#   'Position': 'G'},
#  {'player_id': '8477429',
#   'Player Name': 'Andrew Copp',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8477504',
#   'Player Name': 'Josh Morrissey',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8477940',
#   'Player Name': 'Nikolaj Ehlers',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8478398',
#   'Player Name': 'Kyle Connor',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8478891',
#   'Player Name': 'Mason Appleton',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8478915',
#   'Player Name': 'Sami Niku',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8479378',
#   'Player Name': 'Logan Stanley',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8479400',
#   'Player Name': 'Pierre-Luc Dubois',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8480145',
#   'Player Name': 'Neal Pionk',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8481019',
#   'Player Name': 'David Gustafsson',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8475171',
#   'Player Name': 'Oliver Ekman-Larsson',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8478432',
#   'Player Name': 'Christian Fischer',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8478476',
#   'Player Name': 'Kyle Capobianco',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8480913',
#   'Player Name': 'Jordan Gross',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8471274',
#   'Player Name': 'Alex Goligoski',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8471769',
#   'Player Name': 'Niklas Hjalmarsson',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8473544',
#   'Player Name': 'Derick Brassard',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8473548',
#   'Player Name': 'Phil Kessel',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8474218',
#   'Player Name': 'Jason Demers',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8475311',
#   'Player Name': 'Darcy Kuemper',
#   'Team': 'ARI',
#   'Position': 'G'},
#  {'player_id': '8475728',
#   'Player Name': 'Johan Larsson',
#   'Team': 'ARI',
#   'Position': 'LW'},
#  {'player_id': '8475752',
#   'Player Name': 'Tyler Pitlick',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8477293',
#   'Player Name': 'Antti Raanta',
#   'Team': 'ARI',
#   'Position': 'G'},
#  {'player_id': '8477401',
#   'Player Name': 'John Hayden',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8477851',
#   'Player Name': 'Jordan Oesterle',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8477951',
#   'Player Name': 'Nick Schmaltz',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8477989',
#   'Player Name': 'Christian Dvorak',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8478474',
#   'Player Name': 'Lawson Crouse',
#   'Team': 'ARI',
#   'Position': 'LW'},
#  {'player_id': '8478499',
#   'Player Name': 'Adin Hill',
#   'Team': 'ARI',
#   'Position': 'G'},
#  {'player_id': '8478856',
#   'Player Name': 'Conor Garland',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8479343',
#   'Player Name': 'Clayton Keller',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8479345',
#   'Player Name': 'Jakob Chychrun',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8479465',
#   'Player Name': 'Drake Caggiula',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8480849',
#   'Player Name': 'Barrett Hayton',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8480950',
#   'Player Name': 'Ilya Lyubushkin',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8475188',
#   'Player Name': 'Brayden McNabb',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8476430',
#   'Player Name': 'Tomas Jurco',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8481522',
#   'Player Name': 'Peyton Krebs',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8470594',
#   'Player Name': 'Marc-Andre Fleury',
#   'Team': 'VGK',
#   'Position': 'G'},
#  {'player_id': '8471817',
#   'Player Name': 'Ryan Reaves',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8474157',
#   'Player Name': 'Max Pacioretty',
#   'Team': 'VGK',
#   'Position': 'LW'},
#  {'player_id': '8474166',
#   'Player Name': 'Alec Martinez',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8474207',
#   'Player Name': 'Nick Holden',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8474565',
#   'Player Name': 'Alex Pietrangelo',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8475191',
#   'Player Name': 'Reilly Smith',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8475215',
#   'Player Name': 'Robin Lehner',
#   'Team': 'VGK',
#   'Position': 'G'},
#  {'player_id': '8475913',
#   'Player Name': 'Mark Stone',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8476448',
#   'Player Name': 'William Karlsson',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8476539',
#   'Player Name': 'Jonathan Marchessault',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8476905',
#   'Player Name': 'Chandler Stephenson',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8477447',
#   'Player Name': 'Shea Theodore',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8477478',
#   'Player Name': 'William Carrier',
#   'Team': 'VGK',
#   'Position': 'LW'},
#  {'player_id': '8477931',
#   'Player Name': 'Tomas Nosek',
#   'Team': 'VGK',
#   'Position': 'LW'},
#  {'player_id': '8477949',
#   'Player Name': 'Alex Tuch',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8478434',
#   'Player Name': 'Keegan Kolesar',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8478462',
#   'Player Name': 'Nicolas Roy',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8479639',
#   'Player Name': 'Dylan Coghlan',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8479980',
#   'Player Name': 'Nicolas Hague',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8479996',
#   'Player Name': 'Cody Glass',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8480727',
#   'Player Name': 'Zach Whitecloud',
#   'Team': 'VGK',
#   'Position': 'D'}]

# %%
# Separate goalies from skaters
goalie_data = []
skater_data = []

for player in player_data:
    if player['Position'] == 'G':
        goalie_data.append(player)
    else:
        skater_data.append(player)

# %%
# Looping through every goalie and adding stats from last season
for player in goalie_data:
    
    # Creating URL for API call for a specific player's stats in a specific season
    player_url = "https://statsapi.web.nhl.com/api/v1/people/" + player['player_id'] + "/stats?stats=statsSingleSeason&season=" + season1
    
    try:
        # API call for player stats in JSON format
        player_info = requests.get(player_url).json()
        player_stats = player_info['stats'][0]['splits'][0]['stat']

        # Adding selected stats to each player
        player["Games"] = player_stats['games']
        player["Games Started"] = player_stats['gamesStarted']
        player["W"] = player_stats['wins']
        player["L"] = player_stats['losses']
        player["OTL"] = player_stats['ot']
        player["GAA"] = player_stats['goalAgainstAverage']
        player["GA"] = player_stats['goalsAgainst']
        player["SA"] = player_stats['shotsAgainst']
        player["SV"] = player_stats['saves']
        player["SV%"] = player_stats['savePercentage']
        player["SO"] = player_stats['shutouts']
        player["MIN"] = player_stats['timeOnIce']
        
    except:
        # Add stats as 0 if player not found or if player did not play that season
        player["Games"] = 0
        player["Games Started"] = 0
        player["W"] = 0
        player["L"] = 0
        player["OTL"] = 0
        player["GAA"] = 0
        player["GA"] = 0
        player["SA"] = 0
        player["SV"] = 0
        player["SV%"] = 0
        player["SO"] = 0
        player["MIN"] = "0"
    
    
goalie_data
# Out:
# [{'player_id': '8478406',
#   'Player Name': 'Mackenzie Blackwood',
#   'Team': 'NJD',
#   'Position': 'G',
#   'Games': 47,
#   'Games Started': 43,
#   'W': 22,
#   'L': 14,
#   'OTL': 8,
#   'GAA': 2.772,
#   'GA': 124,
#   'SA': 1452,
#   'SV': 1328,
#   'SV%': 0.915,
#   'SO': 3,
#   'MIN': '2684:01'},
#  {'player_id': '8475809',
#   'Player Name': 'Scott Wedgewood',
#   'Team': 'NJD',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8477480',
#   'Player Name': 'Eric Comrie',
#   'Team': 'NJD',
#   'Position': 'G',
#   'Games': 3,
#   'Games Started': 2,
#   'W': 0,
#   'L': 2,
#   'OTL': 0,
#   'GAA': 4.2772,
#   'GA': 9,
#   'SA': 66,
#   'SV': 57,
#   'SV%': 0.864,
#   'SO': 0,
#   'MIN': '126:15'},
#  {'player_id': '8471239',
#   'Player Name': 'Cory Schneider',
#   'Team': 'NYI',
#   'Position': 'G',
#   'Games': 13,
#   'Games Started': 11,
#   'W': 3,
#   'L': 6,
#   'OTL': 2,
#   'GAA': 3.5332,
#   'GA': 40,
#   'SA': 355,
#   'SV': 315,
#   'SV%': 0.887,
#   'SO': 1,
#   'MIN': '679:16'},
#  {'player_id': '8473575',
#   'Player Name': 'Semyon Varlamov',
#   'Team': 'NYI',
#   'Position': 'G',
#   'Games': 45,
#   'Games Started': 39,
#   'W': 19,
#   'L': 14,
#   'OTL': 6,
#   'GAA': 2.6218,
#   'GA': 110,
#   'SA': 1278,
#   'SV': 1168,
#   'SV%': 0.914,
#   'SO': 2,
#   'MIN': '2517:19'},
#  {'player_id': '8478009',
#   'Player Name': 'Ilya Sorokin',
#   'Team': 'NYI',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8478048',
#   'Player Name': 'Igor Shesterkin',
#   'Team': 'NYR',
#   'Position': 'G',
#   'Games': 12,
#   'Games Started': 12,
#   'W': 10,
#   'L': 2,
#   'OTL': 0,
#   'GAA': 2.516,
#   'GA': 29,
#   'SA': 424,
#   'SV': 395,
#   'SV%': 0.932,
#   'SO': 0,
#   'MIN': '691:35'},
#  {'player_id': '8480382',
#   'Player Name': 'Alexandar Georgiev',
#   'Team': 'NYR',
#   'Position': 'G',
#   'Games': 34,
#   'Games Started': 32,
#   'W': 17,
#   'L': 14,
#   'OTL': 2,
#   'GAA': 3.0448,
#   'GA': 96,
#   'SA': 1063,
#   'SV': 967,
#   'SV%': 0.91,
#   'SO': 2,
#   'MIN': '1891:44'},
#  {'player_id': '8470880',
#   'Player Name': 'Brian Elliott',
#   'Team': 'PHI',
#   'Position': 'G',
#   'Games': 31,
#   'Games Started': 27,
#   'W': 16,
#   'L': 7,
#   'OTL': 4,
#   'GAA': 2.8676,
#   'GA': 80,
#   'SA': 796,
#   'SV': 716,
#   'SV%': 0.899,
#   'SO': 2,
#   'MIN': '1673:54'},
#  {'player_id': '8479394',
#   'Player Name': 'Carter Hart',
#   'Team': 'PHI',
#   'Position': 'G',
#   'Games': 43,
#   'Games Started': 40,
#   'W': 24,
#   'L': 13,
#   'OTL': 3,
#   'GAA': 2.4195,
#   'GA': 95,
#   'SA': 1100,
#   'SV': 1005,
#   'SV%': 0.914,
#   'SO': 1,
#   'MIN': '2355:50'},
#  {'player_id': '8476509',
#   'Player Name': 'Maxime Lagace',
#   'Team': 'PIT',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8480394',
#   'Player Name': "Alex D'Orio",
#   'Team': 'PIT',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8477465',
#   'Player Name': 'Tristan Jarry',
#   'Team': 'PIT',
#   'Position': 'G',
#   'Games': 33,
#   'Games Started': 31,
#   'W': 20,
#   'L': 12,
#   'OTL': 1,
#   'GAA': 2.4293,
#   'GA': 78,
#   'SA': 985,
#   'SV': 907,
#   'SV%': 0.921,
#   'SO': 3,
#   'MIN': '1926:29'},
#  {'player_id': '8479193',
#   'Player Name': 'Casey DeSmith',
#   'Team': 'PIT',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8470860',
#   'Player Name': 'Jaroslav Halak',
#   'Team': 'BOS',
#   'Position': 'G',
#   'Games': 31,
#   'Games Started': 29,
#   'W': 18,
#   'L': 6,
#   'OTL': 6,
#   'GAA': 2.389,
#   'GA': 73,
#   'SA': 905,
#   'SV': 832,
#   'SV%': 0.919,
#   'SO': 3,
#   'MIN': '1833:22'},
#  {'player_id': '8471695',
#   'Player Name': 'Tuukka Rask',
#   'Team': 'BOS',
#   'Position': 'G',
#   'Games': 41,
#   'Games Started': 41,
#   'W': 26,
#   'L': 8,
#   'OTL': 6,
#   'GAA': 2.1234,
#   'GA': 85,
#   'SA': 1189,
#   'SV': 1104,
#   'SV%': 0.929,
#   'SO': 5,
#   'MIN': '2401:47'},
#  {'player_id': '8477992',
#   'Player Name': 'Jonas Johansson',
#   'Team': 'BUF',
#   'Position': 'G',
#   'Games': 6,
#   'Games Started': 5,
#   'W': 1,
#   'L': 3,
#   'OTL': 1,
#   'GAA': 2.9382,
#   'GA': 16,
#   'SA': 151,
#   'SV': 135,
#   'SV%': 0.894,
#   'SO': 0,
#   'MIN': '326:44'},
#  {'player_id': '8475622',
#   'Player Name': 'Carter Hutton',
#   'Team': 'BUF',
#   'Position': 'G',
#   'Games': 31,
#   'Games Started': 30,
#   'W': 12,
#   'L': 14,
#   'OTL': 4,
#   'GAA': 3.1767,
#   'GA': 94,
#   'SA': 918,
#   'SV': 824,
#   'SV%': 0.898,
#   'SO': 2,
#   'MIN': '1775:26'},
#  {'player_id': '8476999',
#   'Player Name': 'Linus Ullmark',
#   'Team': 'BUF',
#   'Position': 'G',
#   'Games': 34,
#   'Games Started': 34,
#   'W': 17,
#   'L': 14,
#   'OTL': 3,
#   'GAA': 2.6941,
#   'GA': 91,
#   'SA': 1066,
#   'SV': 975,
#   'SV%': 0.915,
#   'SO': 1,
#   'MIN': '2026:38'},
#  {'player_id': '8479292',
#   'Player Name': 'Charlie Lindgren',
#   'Team': 'MTL',
#   'Position': 'G',
#   'Games': 6,
#   'Games Started': 6,
#   'W': 2,
#   'L': 4,
#   'OTL': 0,
#   'GAA': 3.3255,
#   'GA': 20,
#   'SA': 178,
#   'SV': 158,
#   'SV%': 0.888,
#   'SO': 0,
#   'MIN': '360:51'},
#  {'player_id': '8471679',
#   'Player Name': 'Carey Price',
#   'Team': 'MTL',
#   'Position': 'G',
#   'Games': 58,
#   'Games Started': 58,
#   'W': 27,
#   'L': 25,
#   'OTL': 6,
#   'GAA': 2.7908,
#   'GA': 160,
#   'SA': 1755,
#   'SV': 1595,
#   'SV%': 0.909,
#   'SO': 4,
#   'MIN': '3439:49'},
#  {'player_id': '8474596',
#   'Player Name': 'Jake Allen',
#   'Team': 'MTL',
#   'Position': 'G',
#   'Games': 24,
#   'Games Started': 21,
#   'W': 12,
#   'L': 6,
#   'OTL': 3,
#   'GAA': 2.1508,
#   'GA': 48,
#   'SA': 655,
#   'SV': 607,
#   'SV%': 0.927,
#   'SO': 2,
#   'MIN': '1339:04'},
#  {'player_id': '8476899',
#   'Player Name': 'Matt Murray',
#   'Team': 'OTT',
#   'Position': 'G',
#   'Games': 38,
#   'Games Started': 38,
#   'W': 20,
#   'L': 11,
#   'OTL': 5,
#   'GAA': 2.8693,
#   'GA': 107,
#   'SA': 1055,
#   'SV': 948,
#   'SV%': 0.899,
#   'SO': 1,
#   'MIN': '2237:30'},
#  {'player_id': '8477405',
#   'Player Name': 'Marcus Hogberg',
#   'Team': 'OTT',
#   'Position': 'G',
#   'Games': 24,
#   'Games Started': 21,
#   'W': 5,
#   'L': 8,
#   'OTL': 8,
#   'GAA': 3.1237,
#   'GA': 70,
#   'SA': 728,
#   'SV': 658,
#   'SV%': 0.904,
#   'SO': 0,
#   'MIN': '1344:33'},
#  {'player_id': '8475789',
#   'Player Name': 'Jack Campbell',
#   'Team': 'TOR',
#   'Position': 'G',
#   'Games': 26,
#   'Games Started': 26,
#   'W': 11,
#   'L': 12,
#   'OTL': 3,
#   'GAA': 2.7952,
#   'GA': 73,
#   'SA': 761,
#   'SV': 688,
#   'SV%': 0.904,
#   'SO': 0,
#   'MIN': '1566:59'},
#  {'player_id': '8474636',
#   'Player Name': 'Michael Hutchinson',
#   'Team': 'TOR',
#   'Position': 'G',
#   'Games': 16,
#   'Games Started': 12,
#   'W': 5,
#   'L': 9,
#   'OTL': 1,
#   'GAA': 3.471,
#   'GA': 49,
#   'SA': 439,
#   'SV': 390,
#   'SV%': 0.888,
#   'SO': 1,
#   'MIN': '847:01'},
#  {'player_id': '8475883',
#   'Player Name': 'Frederik Andersen',
#   'Team': 'TOR',
#   'Position': 'G',
#   'Games': 52,
#   'Games Started': 52,
#   'W': 29,
#   'L': 13,
#   'OTL': 7,
#   'GAA': 2.8537,
#   'GA': 143,
#   'SA': 1577,
#   'SV': 1434,
#   'SV%': 0.909,
#   'SO': 3,
#   'MIN': '3006:40'},
#  {'player_id': '8473503',
#   'Player Name': 'James Reimer',
#   'Team': 'CAR',
#   'Position': 'G',
#   'Games': 25,
#   'Games Started': 24,
#   'W': 14,
#   'L': 6,
#   'OTL': 2,
#   'GAA': 2.656,
#   'GA': 61,
#   'SA': 712,
#   'SV': 651,
#   'SV%': 0.914,
#   'SO': 3,
#   'MIN': '1378:01'},
#  {'player_id': '8475852',
#   'Player Name': 'Petr Mrazek',
#   'Team': 'CAR',
#   'Position': 'G',
#   'Games': 40,
#   'Games Started': 38,
#   'W': 21,
#   'L': 16,
#   'OTL': 2,
#   'GAA': 2.6885,
#   'GA': 104,
#   'SA': 1091,
#   'SV': 987,
#   'SV%': 0.905,
#   'SO': 3,
#   'MIN': '2320:59'},
#  {'player_id': '8477475',
#   'Player Name': 'Philippe Desrosiers',
#   'Team': 'FLA',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8475683',
#   'Player Name': 'Sergei Bobrovsky',
#   'Team': 'FLA',
#   'Position': 'G',
#   'Games': 50,
#   'Games Started': 49,
#   'W': 23,
#   'L': 19,
#   'OTL': 6,
#   'GAA': 3.2288,
#   'GA': 151,
#   'SA': 1505,
#   'SV': 1354,
#   'SV%': 0.9,
#   'SO': 1,
#   'MIN': '2805:59'},
#  {'player_id': '8476904',
#   'Player Name': 'Chris Driedger',
#   'Team': 'FLA',
#   'Position': 'G',
#   'Games': 12,
#   'Games Started': 11,
#   'W': 7,
#   'L': 2,
#   'OTL': 1,
#   'GAA': 2.0539,
#   'GA': 22,
#   'SA': 354,
#   'SV': 332,
#   'SV%': 0.938,
#   'SO': 1,
#   'MIN': '642:40'},
#  {'player_id': '8475195',
#   'Player Name': 'Anders Nilsson',
#   'Team': 'TBL',
#   'Position': 'G',
#   'Games': 20,
#   'Games Started': 19,
#   'W': 9,
#   'L': 9,
#   'OTL': 2,
#   'GAA': 3.1831,
#   'GA': 58,
#   'SA': 628,
#   'SV': 570,
#   'SV%': 0.908,
#   'SO': 0,
#   'MIN': '1093:16'},
#  {'player_id': '8476444',
#   'Player Name': 'Christopher Gibson',
#   'Team': 'TBL',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8470147',
#   'Player Name': 'Curtis McElhinney',
#   'Team': 'TBL',
#   'Position': 'G',
#   'Games': 18,
#   'Games Started': 18,
#   'W': 8,
#   'L': 7,
#   'OTL': 3,
#   'GAA': 2.8864,
#   'GA': 52,
#   'SA': 551,
#   'SV': 499,
#   'SV%': 0.906,
#   'SO': 1,
#   'MIN': '1080:56'},
#  {'player_id': '8476883',
#   'Player Name': 'Andrei Vasilevskiy',
#   'Team': 'TBL',
#   'Position': 'G',
#   'Games': 52,
#   'Games Started': 52,
#   'W': 35,
#   'L': 14,
#   'OTL': 3,
#   'GAA': 2.5561,
#   'GA': 133,
#   'SA': 1605,
#   'SV': 1472,
#   'SV%': 0.917,
#   'SO': 3,
#   'MIN': '3121:54'},
#  {'player_id': '8467950',
#   'Player Name': 'Craig Anderson',
#   'Team': 'WSH',
#   'Position': 'G',
#   'Games': 34,
#   'Games Started': 31,
#   'W': 11,
#   'L': 17,
#   'OTL': 2,
#   'GAA': 3.2517,
#   'GA': 100,
#   'SA': 1018,
#   'SV': 918,
#   'SV%': 0.902,
#   'SO': 0,
#   'MIN': '1845:11'},
#  {'player_id': '8478492',
#   'Player Name': 'Ilya Samsonov',
#   'Team': 'WSH',
#   'Position': 'G',
#   'Games': 26,
#   'Games Started': 22,
#   'W': 16,
#   'L': 6,
#   'OTL': 2,
#   'GAA': 2.5513,
#   'GA': 60,
#   'SA': 689,
#   'SV': 629,
#   'SV%': 0.913,
#   'SO': 1,
#   'MIN': '1411:02'},
#  {'player_id': '8477970',
#   'Player Name': 'Vitek Vanecek',
#   'Team': 'WSH',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8476876',
#   'Player Name': 'Malcolm Subban',
#   'Team': 'CHI',
#   'Position': 'G',
#   'Games': 21,
#   'Games Started': 19,
#   'W': 9,
#   'L': 7,
#   'OTL': 3,
#   'GAA': 3.1739,
#   'GA': 60,
#   'SA': 546,
#   'SV': 486,
#   'SV%': 0.89,
#   'SO': 0,
#   'MIN': '1134:15'},
#  {'player_id': '8480420',
#   'Player Name': 'Collin Delia',
#   'Team': 'CHI',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8480947',
#   'Player Name': 'Kevin Lankinen',
#   'Team': 'CHI',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8473541',
#   'Player Name': 'Jonathan Bernier',
#   'Team': 'DET',
#   'Position': 'G',
#   'Games': 46,
#   'Games Started': 41,
#   'W': 15,
#   'L': 22,
#   'OTL': 3,
#   'GAA': 2.9463,
#   'GA': 126,
#   'SA': 1353,
#   'SV': 1227,
#   'SV%': 0.907,
#   'SO': 1,
#   'MIN': '2565:56'},
#  {'player_id': '8471306',
#   'Player Name': 'Thomas Greiss',
#   'Team': 'DET',
#   'Position': 'G',
#   'Games': 31,
#   'Games Started': 29,
#   'W': 16,
#   'L': 9,
#   'OTL': 4,
#   'GAA': 2.7445,
#   'GA': 73,
#   'SA': 838,
#   'SV': 765,
#   'SV%': 0.913,
#   'SO': 0,
#   'MIN': '1595:56'},
#  {'player_id': '8475717',
#   'Player Name': 'Calvin Pickard',
#   'Team': 'DET',
#   'Position': 'G',
#   'Games': 3,
#   'Games Started': 1,
#   'W': 0,
#   'L': 2,
#   'OTL': 0,
#   'GAA': 5.4584,
#   'GA': 15,
#   'SA': 74,
#   'SV': 59,
#   'SV%': 0.797,
#   'SO': 0,
#   'MIN': '164:53'},
#  {'player_id': '8479288',
#   'Player Name': 'Kasimir Kaskisuo',
#   'Team': 'NSH',
#   'Position': 'G',
#   'Games': 1,
#   'Games Started': 1,
#   'W': 0,
#   'L': 1,
#   'OTL': 0,
#   'GAA': 6.0,
#   'GA': 6,
#   'SA': 38,
#   'SV': 32,
#   'SV%': 0.842,
#   'SO': 0,
#   'MIN': '60:00'},
#  {'player_id': '8471469',
#   'Player Name': 'Pekka Rinne',
#   'Team': 'NSH',
#   'Position': 'G',
#   'Games': 36,
#   'Games Started': 35,
#   'W': 18,
#   'L': 14,
#   'OTL': 4,
#   'GAA': 3.1694,
#   'GA': 105,
#   'SA': 1004,
#   'SV': 899,
#   'SV%': 0.895,
#   'SO': 3,
#   'MIN': '1987:46'},
#  {'player_id': '8477424',
#   'Player Name': 'Juuse Saros',
#   'Team': 'NSH',
#   'Position': 'G',
#   'Games': 40,
#   'Games Started': 34,
#   'W': 17,
#   'L': 12,
#   'OTL': 4,
#   'GAA': 2.7012,
#   'GA': 98,
#   'SA': 1142,
#   'SV': 1044,
#   'SV%': 0.914,
#   'SO': 4,
#   'MIN': '2176:50'},
#  {'player_id': '8476412',
#   'Player Name': 'Jordan Binnington',
#   'Team': 'STL',
#   'Position': 'G',
#   'Games': 50,
#   'Games Started': 50,
#   'W': 30,
#   'L': 13,
#   'OTL': 7,
#   'GAA': 2.5647,
#   'GA': 126,
#   'SA': 1430,
#   'SV': 1304,
#   'SV%': 0.912,
#   'SO': 3,
#   'MIN': '2947:41'},
#  {'player_id': '8478024',
#   'Player Name': 'Ville Husso',
#   'Team': 'STL',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8475839',
#   'Player Name': 'Louis Domingue',
#   'Team': 'CGY',
#   'Position': 'G',
#   'Games': 17,
#   'Games Started': 15,
#   'W': 3,
#   'L': 9,
#   'OTL': 2,
#   'GAA': 3.814,
#   'GA': 51,
#   'SA': 433,
#   'SV': 382,
#   'SV%': 0.882,
#   'SO': 0,
#   'MIN': '802:19'},
#  {'player_id': '8474593',
#   'Player Name': 'Jacob Markstrom',
#   'Team': 'CGY',
#   'Position': 'G',
#   'Games': 43,
#   'Games Started': 43,
#   'W': 23,
#   'L': 16,
#   'OTL': 4,
#   'GAA': 2.7509,
#   'GA': 117,
#   'SA': 1420,
#   'SV': 1303,
#   'SV%': 0.918,
#   'SO': 2,
#   'MIN': '2551:53'},
#  {'player_id': '8479496',
#   'Player Name': 'David Rittich',
#   'Team': 'CGY',
#   'Position': 'G',
#   'Games': 48,
#   'Games Started': 48,
#   'W': 24,
#   'L': 17,
#   'OTL': 6,
#   'GAA': 2.9657,
#   'GA': 138,
#   'SA': 1478,
#   'SV': 1340,
#   'SV%': 0.907,
#   'SO': 2,
#   'MIN': '2791:58'},
#  {'player_id': '8480925',
#   'Player Name': 'Pavel Francouz',
#   'Team': 'COL',
#   'Position': 'G',
#   'Games': 34,
#   'Games Started': 31,
#   'W': 21,
#   'L': 7,
#   'OTL': 4,
#   'GAA': 2.4132,
#   'GA': 77,
#   'SA': 996,
#   'SV': 919,
#   'SV%': 0.923,
#   'SO': 1,
#   'MIN': '1914:26'},
#  {'player_id': '8479530',
#   'Player Name': 'Adam Werner',
#   'Team': 'COL',
#   'Position': 'G',
#   'Games': 2,
#   'Games Started': 1,
#   'W': 1,
#   'L': 1,
#   'OTL': 0,
#   'GAA': 3.4156,
#   'GA': 5,
#   'SA': 58,
#   'SV': 53,
#   'SV%': 0.914,
#   'SO': 0,
#   'MIN': '87:50'},
#  {'player_id': '8475831',
#   'Player Name': 'Philipp Grubauer',
#   'Team': 'COL',
#   'Position': 'G',
#   'Games': 36,
#   'Games Started': 36,
#   'W': 18,
#   'L': 12,
#   'OTL': 4,
#   'GAA': 2.6251,
#   'GA': 90,
#   'SA': 1067,
#   'SV': 977,
#   'SV%': 0.916,
#   'SO': 2,
#   'MIN': '2057:06'},
#  {'player_id': '8480112',
#   'Player Name': 'Hunter Miska',
#   'Team': 'COL',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8479380',
#   'Player Name': 'Dylan Wells',
#   'Team': 'EDM',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8469608',
#   'Player Name': 'Mike Smith',
#   'Team': 'EDM',
#   'Position': 'G',
#   'Games': 39,
#   'Games Started': 37,
#   'W': 19,
#   'L': 12,
#   'OTL': 6,
#   'GAA': 2.9487,
#   'GA': 106,
#   'SA': 1087,
#   'SV': 981,
#   'SV%': 0.902,
#   'SO': 1,
#   'MIN': '2156:51'},
#  {'player_id': '8475156',
#   'Player Name': 'Mikko Koskinen',
#   'Team': 'EDM',
#   'Position': 'G',
#   'Games': 38,
#   'Games Started': 34,
#   'W': 18,
#   'L': 13,
#   'OTL': 3,
#   'GAA': 2.7498,
#   'GA': 97,
#   'SA': 1175,
#   'SV': 1078,
#   'SV%': 0.917,
#   'SO': 1,
#   'MIN': '2116:31'},
#  {'player_id': '8474651',
#   'Player Name': 'Braden Holtby',
#   'Team': 'VAN',
#   'Position': 'G',
#   'Games': 48,
#   'Games Started': 47,
#   'W': 25,
#   'L': 14,
#   'OTL': 6,
#   'GAA': 3.1059,
#   'GA': 142,
#   'SA': 1385,
#   'SV': 1243,
#   'SV%': 0.897,
#   'SO': 0,
#   'MIN': '2743:10'},
#  {'player_id': '8477967',
#   'Player Name': 'Thatcher Demko',
#   'Team': 'VAN',
#   'Position': 'G',
#   'Games': 27,
#   'Games Started': 25,
#   'W': 13,
#   'L': 10,
#   'OTL': 2,
#   'GAA': 3.0607,
#   'GA': 78,
#   'SA': 822,
#   'SV': 744,
#   'SV%': 0.905,
#   'SO': 0,
#   'MIN': '1529:03'},
#  {'player_id': '8468011',
#   'Player Name': 'Ryan Miller',
#   'Team': 'ANA',
#   'Position': 'G',
#   'Games': 23,
#   'Games Started': 19,
#   'W': 9,
#   'L': 6,
#   'OTL': 4,
#   'GAA': 3.1012,
#   'GA': 64,
#   'SA': 685,
#   'SV': 621,
#   'SV%': 0.907,
#   'SO': 0,
#   'MIN': '1238:14'},
#  {'player_id': '8476434',
#   'Player Name': 'John Gibson',
#   'Team': 'ANA',
#   'Position': 'G',
#   'Games': 51,
#   'Games Started': 51,
#   'W': 20,
#   'L': 26,
#   'OTL': 5,
#   'GAA': 2.9987,
#   'GA': 149,
#   'SA': 1552,
#   'SV': 1403,
#   'SV%': 0.904,
#   'SO': 1,
#   'MIN': '2981:17'},
#  {'player_id': '8476932',
#   'Player Name': 'Anthony Stolarz',
#   'Team': 'ANA',
#   'Position': 'G',
#   'Games': 1,
#   'Games Started': 1,
#   'W': 0,
#   'L': 1,
#   'OTL': 0,
#   'GAA': 2.0385,
#   'GA': 2,
#   'SA': 36,
#   'SV': 34,
#   'SV%': 0.944,
#   'SO': 0,
#   'MIN': '58:52'},
#  {'player_id': '8471750',
#   'Player Name': 'Ben Bishop',
#   'Team': 'DAL',
#   'Position': 'G',
#   'Games': 44,
#   'Games Started': 43,
#   'W': 21,
#   'L': 16,
#   'OTL': 4,
#   'GAA': 2.4982,
#   'GA': 103,
#   'SA': 1286,
#   'SV': 1183,
#   'SV%': 0.92,
#   'SO': 2,
#   'MIN': '2473:49'},
#  {'player_id': '8471418',
#   'Player Name': 'Anton Khudobin',
#   'Team': 'DAL',
#   'Position': 'G',
#   'Games': 30,
#   'Games Started': 26,
#   'W': 16,
#   'L': 8,
#   'OTL': 4,
#   'GAA': 2.2176,
#   'GA': 62,
#   'SA': 882,
#   'SV': 820,
#   'SV%': 0.93,
#   'SO': 0,
#   'MIN': '1677:29'},
#  {'player_id': '8479979',
#   'Player Name': 'Jake Oettinger',
#   'Team': 'DAL',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8480857',
#   'Player Name': 'Jacob Ingham',
#   'Team': 'LAK',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8471734',
#   'Player Name': 'Jonathan Quick',
#   'Team': 'LAK',
#   'Position': 'G',
#   'Games': 42,
#   'Games Started': 42,
#   'W': 16,
#   'L': 22,
#   'OTL': 4,
#   'GAA': 2.7899,
#   'GA': 117,
#   'SA': 1224,
#   'SV': 1107,
#   'SV%': 0.904,
#   'SO': 1,
#   'MIN': '2516:14'},
#  {'player_id': '8477361',
#   'Player Name': 'Calvin Petersen',
#   'Team': 'LAK',
#   'Position': 'G',
#   'Games': 8,
#   'Games Started': 8,
#   'W': 5,
#   'L': 3,
#   'OTL': 0,
#   'GAA': 2.6395,
#   'GA': 21,
#   'SA': 269,
#   'SV': 248,
#   'SV%': 0.922,
#   'SO': 0,
#   'MIN': '477:22'},
#  {'player_id': '8471227',
#   'Player Name': 'Devan Dubnyk',
#   'Team': 'SJS',
#   'Position': 'G',
#   'Games': 30,
#   'Games Started': 28,
#   'W': 12,
#   'L': 15,
#   'OTL': 2,
#   'GAA': 3.3521,
#   'GA': 93,
#   'SA': 849,
#   'SV': 756,
#   'SV%': 0.89,
#   'SO': 1,
#   'MIN': '1664:39'},
#  {'player_id': '8474889',
#   'Player Name': 'Martin Jones',
#   'Team': 'SJS',
#   'Position': 'G',
#   'Games': 41,
#   'Games Started': 40,
#   'W': 17,
#   'L': 21,
#   'OTL': 2,
#   'GAA': 3.0002,
#   'GA': 118,
#   'SA': 1139,
#   'SV': 1021,
#   'SV%': 0.896,
#   'SO': 2,
#   'MIN': '2359:50'},
#  {'player_id': '8478007',
#   'Player Name': 'Elvis Merzlikins',
#   'Team': 'CBJ',
#   'Position': 'G',
#   'Games': 33,
#   'Games Started': 31,
#   'W': 13,
#   'L': 9,
#   'OTL': 8,
#   'GAA': 2.3469,
#   'GA': 71,
#   'SA': 919,
#   'SV': 848,
#   'SV%': 0.923,
#   'SO': 5,
#   'MIN': '1815:08'},
#  {'player_id': '8476914',
#   'Player Name': 'Joonas Korpisalo',
#   'Team': 'CBJ',
#   'Position': 'G',
#   'Games': 37,
#   'Games Started': 35,
#   'W': 19,
#   'L': 12,
#   'OTL': 5,
#   'GAA': 2.5965,
#   'GA': 92,
#   'SA': 1030,
#   'SV': 938,
#   'SV%': 0.911,
#   'SO': 2,
#   'MIN': '2125:54'},
#  {'player_id': '8480162',
#   'Player Name': 'Matiss Kivlenieks',
#   'Team': 'CBJ',
#   'Position': 'G',
#   'Games': 6,
#   'Games Started': 4,
#   'W': 1,
#   'L': 1,
#   'OTL': 2,
#   'GAA': 2.9491,
#   'GA': 14,
#   'SA': 137,
#   'SV': 123,
#   'SV%': 0.898,
#   'SO': 0,
#   'MIN': '284:50'},
#  {'player_id': '8471774',
#   'Player Name': 'Alex Stalock',
#   'Team': 'MIN',
#   'Position': 'G',
#   'Games': 38,
#   'Games Started': 36,
#   'W': 20,
#   'L': 11,
#   'OTL': 4,
#   'GAA': 2.673,
#   'GA': 97,
#   'SA': 1082,
#   'SV': 985,
#   'SV%': 0.91,
#   'SO': 4,
#   'MIN': '2177:21'},
#  {'player_id': '8477202',
#   'Player Name': 'Andrew Hammond',
#   'Team': 'MIN',
#   'Position': 'G',
#   'Games': 0,
#   'Games Started': 0,
#   'W': 0,
#   'L': 0,
#   'OTL': 0,
#   'GAA': 0,
#   'GA': 0,
#   'SA': 0,
#   'SV': 0,
#   'SV%': 0,
#   'SO': 0,
#   'MIN': '0'},
#  {'player_id': '8475660',
#   'Player Name': 'Cam Talbot',
#   'Team': 'MIN',
#   'Position': 'G',
#   'Games': 26,
#   'Games Started': 22,
#   'W': 12,
#   'L': 10,
#   'OTL': 1,
#   'GAA': 2.6348,
#   'GA': 63,
#   'SA': 780,
#   'SV': 717,
#   'SV%': 0.919,
#   'SO': 2,
#   'MIN': '1434:39'},
#  {'player_id': '8478039',
#   'Player Name': 'Kaapo Kahkonen',
#   'Team': 'MIN',
#   'Position': 'G',
#   'Games': 5,
#   'Games Started': 5,
#   'W': 3,
#   'L': 1,
#   'OTL': 1,
#   'GAA': 2.9586,
#   'GA': 15,
#   'SA': 172,
#   'SV': 157,
#   'SV%': 0.913,
#   'SO': 0,
#   'MIN': '304:12'},
#  {'player_id': '8476316',
#   'Player Name': 'Laurent Brossoit',
#   'Team': 'WPG',
#   'Position': 'G',
#   'Games': 19,
#   'Games Started': 15,
#   'W': 6,
#   'L': 7,
#   'OTL': 1,
#   'GAA': 3.2797,
#   'GA': 54,
#   'SA': 512,
#   'SV': 458,
#   'SV%': 0.895,
#   'SO': 0,
#   'MIN': '987:53'},
#  {'player_id': '8476341',
#   'Player Name': 'Anton Forsberg',
#   'Team': 'WPG',
#   'Position': 'G',
#   'Games': 3,
#   'Games Started': 3,
#   'W': 1,
#   'L': 1,
#   'OTL': 0,
#   'GAA': 3.3531,
#   'GA': 8,
#   'SA': 78,
#   'SV': 70,
#   'SV%': 0.897,
#   'SO': 0,
#   'MIN': '143:09'},
#  {'player_id': '8476945',
#   'Player Name': 'Connor Hellebuyck',
#   'Team': 'WPG',
#   'Position': 'G',
#   'Games': 58,
#   'Games Started': 56,
#   'W': 31,
#   'L': 21,
#   'OTL': 5,
#   'GAA': 2.5699,
#   'GA': 140,
#   'SA': 1796,
#   'SV': 1656,
#   'SV%': 0.922,
#   'SO': 6,
#   'MIN': '3268:33'},
#  {'player_id': '8475311',
#   'Player Name': 'Darcy Kuemper',
#   'Team': 'ARI',
#   'Position': 'G',
#   'Games': 29,
#   'Games Started': 29,
#   'W': 16,
#   'L': 11,
#   'OTL': 2,
#   'GAA': 2.2243,
#   'GA': 65,
#   'SA': 903,
#   'SV': 838,
#   'SV%': 0.928,
#   'SO': 2,
#   'MIN': '1753:24'},
#  {'player_id': '8477293',
#   'Player Name': 'Antti Raanta',
#   'Team': 'ARI',
#   'Position': 'G',
#   'Games': 33,
#   'Games Started': 32,
#   'W': 15,
#   'L': 14,
#   'OTL': 3,
#   'GAA': 2.6332,
#   'GA': 80,
#   'SA': 1014,
#   'SV': 934,
#   'SV%': 0.921,
#   'SO': 2,
#   'MIN': '1822:54'},
#  {'player_id': '8478499',
#   'Player Name': 'Adin Hill',
#   'Team': 'ARI',
#   'Position': 'G',
#   'Games': 13,
#   'Games Started': 9,
#   'W': 2,
#   'L': 4,
#   'OTL': 3,
#   'GAA': 2.6219,
#   'GA': 28,
#   'SA': 343,
#   'SV': 315,
#   'SV%': 0.918,
#   'SO': 0,
#   'MIN': '640:46'},
#  {'player_id': '8470594',
#   'Player Name': 'Marc-Andre Fleury',
#   'Team': 'VGK',
#   'Position': 'G',
#   'Games': 49,
#   'Games Started': 48,
#   'W': 27,
#   'L': 16,
#   'OTL': 5,
#   'GAA': 2.7707,
#   'GA': 133,
#   'SA': 1399,
#   'SV': 1266,
#   'SV%': 0.905,
#   'SO': 5,
#   'MIN': '2880:06'},
#  {'player_id': '8475215',
#   'Player Name': 'Robin Lehner',
#   'Team': 'VGK',
#   'Position': 'G',
#   'Games': 36,
#   'Games Started': 34,
#   'W': 19,
#   'L': 10,
#   'OTL': 5,
#   'GAA': 2.8899,
#   'GA': 99,
#   'SA': 1235,
#   'SV': 1136,
#   'SV%': 0.92,
#   'SO': 1,
#   'MIN': '2055:28'}]

# %%
# Building function to get skater stats for a specific season
def get_skater_stats(data, season):
    
    # Looping through every skater and adding stats from season
    for player in data:

        # Creating URL for API call for a specific player's stats in a specific season
        player_url = "https://statsapi.web.nhl.com/api/v1/people/" + player['player_id'] + "/stats?stats=statsSingleSeason&season=" + season

        try:
            # API call for player stats in JSON format
            player_info = requests.get(player_url).json()
            player_stats = player_info['stats'][0]['splits'][0]['stat']

            # Adding selected stats to each player
            player["Games"] = player_stats['games']
            player["G"] = player_stats['goals']
            player["A"] = player_stats['assists']
            player["Points"] = player_stats['points']
            player["+/-"] = player_stats['plusMinus']
            player["PIM"] = int(player_stats['penaltyMinutes'])
            player["SOG"] = player_stats['shots']
            player["GWG"] = player_stats['gameWinningGoals']
            player["PPG"] = player_stats['powerPlayGoals']
            player["PPA"] = player_stats['powerPlayPoints'] - player_stats['powerPlayGoals']
            player["PPP"] = player_stats['powerPlayPoints']
            player["BS"] = player_stats['blocked']
            player["Hits"] = player_stats['hits']
            player["SHG"] = player_stats['shortHandedGoals']
            player["SHA"] = player_stats['shortHandedPoints'] - player_stats['shortHandedGoals']
            
        except:
            # Add stats as 0 if player not found or if player did not play that season
            player["Games"] = 0
            player["G"] = 0
            player["A"] = 0
            player["Points"] = 0
            player["+/-"] = 0
            player["PIM"] = 0
            player["SOG"] = 0
            player["GWG"] = 0
            player["PPG"] = 0
            player["PPA"] = 0
            player["PPP"] = 0
            player["BS"] = 0
            player["Hits"] = 0
            player["SHG"] = 0
            player["SHA"] = 0
    
    return data

# %%
# Get skater stats for most recent season
skater_data_season1 = get_skater_stats(deepcopy(skater_data), season1)

# %%
# Get skater stats for most second season
skater_data_season2 = get_skater_stats(deepcopy(skater_data), season2)
# Out:
# [{'player_id': '8475222',
#   'Player Name': 'Sami Vatanen',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8478447',
#   'Player Name': 'Nicholas Merkley',
#   'Team': 'NJD',
#   'Position': 'RW'},
#  {'player_id': '8480003',
#   'Player Name': 'Jesper Boqvist',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8480860',
#   'Player Name': 'Kevin Bahl',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8474056',
#   'Player Name': 'P.K. Subban',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8475151',
#   'Player Name': 'Kyle Palmieri',
#   'Team': 'NJD',
#   'Position': 'RW'},
#  {'player_id': '8475179',
#   'Player Name': 'Dmitry Kulikov',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8476807',
#   'Player Name': 'Matt Tennyson',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8476850',
#   'Player Name': 'Ryan Murray',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8476923',
#   'Player Name': 'Damon Severson',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8476941',
#   'Player Name': 'Connor Carrick',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8477038',
#   'Player Name': 'Nikita Gusev',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8477341',
#   'Player Name': 'Andreas Johnsson',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8477355',
#   'Player Name': 'Will Butcher',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8477425',
#   'Player Name': 'Miles Wood',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8478401',
#   'Player Name': 'Pavel Zacha',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8479407',
#   'Player Name': 'Jesper Bratt',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8479414',
#   'Player Name': 'Nathan Bastian',
#   'Team': 'NJD',
#   'Position': 'RW'},
#  {'player_id': '8479415',
#   'Player Name': 'Michael McLeod',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8479511',
#   'Player Name': 'Janne Kuokkanen',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8479573',
#   'Player Name': 'Mikhail Maltsev',
#   'Team': 'NJD',
#   'Position': 'LW'},
#  {'player_id': '8480883',
#   'Player Name': 'Ty Smith',
#   'Team': 'NJD',
#   'Position': 'D'},
#  {'player_id': '8481068',
#   'Player Name': 'Yegor Sharangovich',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8481559',
#   'Player Name': 'Jack Hughes',
#   'Team': 'NJD',
#   'Position': 'C'},
#  {'player_id': '8478463',
#   'Player Name': 'Anthony Beauvillier',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8470187',
#   'Player Name': 'Johnny Boychuk',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8474066',
#   'Player Name': 'Thomas Hickey',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8478857',
#   'Player Name': 'Dmytro Timashov',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8479526',
#   'Player Name': 'Otto Koivula',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8480789',
#   'Player Name': 'Oliver Wahlstrom',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8472382',
#   'Player Name': 'Andy Greene',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8473463',
#   'Player Name': 'Leo Komarov',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8473504',
#   'Player Name': 'Cal Clutterbuck',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8474573',
#   'Player Name': 'Josh Bailey',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8474586',
#   'Player Name': 'Jordan Eberle',
#   'Team': 'NYI',
#   'Position': 'RW'},
#  {'player_id': '8474709',
#   'Player Name': 'Matt Martin',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8475181',
#   'Player Name': 'Nick Leddy',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8475231',
#   'Player Name': 'Casey Cizikas',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8475314',
#   'Player Name': 'Anders Lee',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8475754',
#   'Player Name': 'Brock Nelson',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8476419',
#   'Player Name': 'Jean-Gabriel Pageau',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8476429',
#   'Player Name': 'Scott Mayfield',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8476917',
#   'Player Name': 'Adam Pelech',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8477506',
#   'Player Name': 'Ryan Pulock',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8477527',
#   'Player Name': 'Ross Johnston',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8477936',
#   'Player Name': 'Michael Dal Colle',
#   'Team': 'NYI',
#   'Position': 'LW'},
#  {'player_id': '8478445',
#   'Player Name': 'Mathew Barzal',
#   'Team': 'NYI',
#   'Position': 'C'},
#  {'player_id': '8480222',
#   'Player Name': 'Sebastian Aho',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8480865',
#   'Player Name': 'Noah Dobson',
#   'Team': 'NYI',
#   'Position': 'D'},
#  {'player_id': '8480078',
#   'Player Name': 'Filip Chytil',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8471677',
#   'Player Name': 'Jack Johnson',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8474090',
#   'Player Name': 'Brendan Smith',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8475184',
#   'Player Name': 'Chris Kreider',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8475868',
#   'Player Name': 'Anthony Bitetto',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8476278',
#   'Player Name': 'Colin Blackwell',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8476458',
#   'Player Name': 'Ryan Strome',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8476459',
#   'Player Name': 'Mika Zibanejad',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8476858',
#   'Player Name': 'Phillip Di Giuseppe',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8476885',
#   'Player Name': 'Jacob Trouba',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8477402',
#   'Player Name': 'Pavel Buchnevich',
#   'Team': 'NYR',
#   'Position': 'RW'},
#  {'player_id': '8477962',
#   'Player Name': 'Brendan Lemieux',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8478550',
#   'Player Name': 'Artemi Panarin',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8479291',
#   'Player Name': 'Kevin Rooney',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8479323',
#   'Player Name': 'Adam Fox',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8479324',
#   'Player Name': 'Ryan Lindgren',
#   'Team': 'NYR',
#   'Position': 'D'},
#  {'player_id': '8479328',
#   'Player Name': 'Julien Gauthier',
#   'Team': 'NYR',
#   'Position': 'RW'},
#  {'player_id': '8479353',
#   'Player Name': 'Brett Howden',
#   'Team': 'NYR',
#   'Position': 'C'},
#  {'player_id': '8482109',
#   'Player Name': 'Alexis Lafrenière',
#   'Team': 'NYR',
#   'Position': 'LW'},
#  {'player_id': '8480028',
#   'Player Name': 'Morgan Frost',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8473512',
#   'Player Name': 'Claude Giroux',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8474027',
#   'Player Name': 'Justin Braun',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8474037',
#   'Player Name': 'James van Riemsdyk',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8474161',
#   'Player Name': 'Jakub Voracek',
#   'Team': 'PHI',
#   'Position': 'RW'},
#  {'player_id': '8475763',
#   'Player Name': 'Kevin Hayes',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8476461',
#   'Player Name': 'Sean Couturier',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8476872',
#   'Player Name': 'Scott Laughton',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8476906',
#   'Player Name': 'Shayne Gostisbehere',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8476979',
#   'Player Name': 'Erik Gustafsson',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8477290',
#   'Player Name': 'Michael Raffl',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8477462',
#   'Player Name': 'Robert Hagg',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8477948',
#   'Player Name': 'Travis Sanheim',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8477979',
#   'Player Name': 'Nicolas Aube-Kubel',
#   'Team': 'PHI',
#   'Position': 'RW'},
#  {'player_id': '8478017',
#   'Player Name': 'Mark Friedman',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8478067',
#   'Player Name': 'Oskar Lindblom',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8478439',
#   'Player Name': 'Travis Konecny',
#   'Team': 'PHI',
#   'Position': 'RW'},
#  {'player_id': '8478500',
#   'Player Name': 'Ivan Provorov',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8479026',
#   'Player Name': 'Philippe Myers',
#   'Team': 'PHI',
#   'Position': 'D'},
#  {'player_id': '8479974',
#   'Player Name': 'Nolan Patrick',
#   'Team': 'PHI',
#   'Position': 'C'},
#  {'player_id': '8480797',
#   'Player Name': 'Joel Farabee',
#   'Team': 'PHI',
#   'Position': 'LW'},
#  {'player_id': '8475208',
#   'Player Name': 'Brian Dumoulin',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8477969',
#   'Player Name': 'Marcus Pettersson',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8478542',
#   'Player Name': 'Evan Rodrigues',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8480945',
#   'Player Name': 'Juuso Riikola',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8477814',
#   'Player Name': 'Kevin Czuczman',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8477919',
#   'Player Name': 'Frederick Gaudreau',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8478074',
#   'Player Name': 'Anthony Angello',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8471215',
#   'Player Name': 'Evgeni Malkin',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8471675',
#   'Player Name': 'Sidney Crosby',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8471724',
#   'Player Name': 'Kris Letang',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8474098',
#   'Player Name': 'Colton Sceviour',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8474134',
#   'Player Name': 'Yannick Weber',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8475722',
#   'Player Name': 'Jason Zucker',
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8475810',
#   'Player Name': 'Bryan Rust',
#   'Team': 'PIT',
#   'Position': 'RW'},
#  {'player_id': '8476873',
#   'Player Name': 'Mark Jankowski',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8476875',
#   'Player Name': 'Mike Matheson',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8476879',
#   'Player Name': 'Cody Ceci',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8476927',
#   'Player Name': 'Teddy Blueger',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8477244',
#   'Player Name': 'Chad Ruhwedel',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8477404',
#   'Player Name': 'Jake Guentzel',
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8477953',
#   'Player Name': 'Kasperi Kapanen',
#   'Team': 'PIT',
#   'Position': 'RW'},
#  {'player_id': '8477955',
#   'Player Name': 'Jared McCann',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8478043',
#   'Player Name': 'Sam Lafferty',
#   'Team': 'PIT',
#   'Position': 'C'},
#  {'player_id': '8478507',
#   'Player Name': 'John Marino',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8479293',
#   'Player Name': 'Brandon Tanev',
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8480058',
#   'Player Name': 'Pierre-Olivier Joseph',
#   'Team': 'PIT',
#   'Position': 'D'},
#  {'player_id': '8482055',
#   'Player Name': "Drew O'Connor",
#   'Team': 'PIT',
#   'Position': 'LW'},
#  {'player_id': '8478131',
#   'Player Name': 'Ondrej Kase',
#   'Team': 'BOS',
#   'Position': 'RW'},
#  {'player_id': '8478498',
#   'Player Name': 'Jake DeBrusk',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8480021',
#   'Player Name': 'Jack Studnicka',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8470638',
#   'Player Name': 'Patrice Bergeron',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8471276',
#   'Player Name': 'David Krejci',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8473419',
#   'Player Name': 'Brad Marchand',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8475186',
#   'Player Name': 'John Moore',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8475225',
#   'Player Name': 'Craig Smith',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8475745',
#   'Player Name': 'Charlie Coyle',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8475780',
#   'Player Name': 'Chris Wagner',
#   'Team': 'BOS',
#   'Position': 'RW'},
#  {'player_id': '8476191',
#   'Player Name': 'Kevan Miller',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8476374',
#   'Player Name': 'Sean Kuraly',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8476891',
#   'Player Name': 'Matt Grzelcyk',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8477365',
#   'Player Name': 'Connor Clifton',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8477941',
#   'Player Name': 'Nick Ritchie',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8477956',
#   'Player Name': 'David Pastrnak',
#   'Team': 'BOS',
#   'Position': 'RW'},
#  {'player_id': '8478075',
#   'Player Name': 'Anders Bjork',
#   'Team': 'BOS',
#   'Position': 'LW'},
#  {'player_id': '8478415',
#   'Player Name': 'Jakub Zboril',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8478443',
#   'Player Name': 'Brandon Carlo',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8478468',
#   'Player Name': 'Jeremy Lauzon',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8479325',
#   'Player Name': 'Charlie McAvoy',
#   'Team': 'BOS',
#   'Position': 'D'},
#  {'player_id': '8479365',
#   'Player Name': 'Trent Frederic',
#   'Team': 'BOS',
#   'Position': 'C'},
#  {'player_id': '8476878',
#   'Player Name': 'Zemgus Girgensons',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8475869',
#   'Player Name': 'Brandon Davidson',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8477520',
#   'Player Name': 'Jean-Sebastien Dea',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8478840',
#   'Player Name': 'William Borgen',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8480083',
#   'Player Name': 'C.J. Smith',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8470595',
#   'Player Name': 'Eric Staal',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8473449',
#   'Player Name': 'Kyle Okposo',
#   'Team': 'BUF',
#   'Position': 'RW'},
#  {'player_id': '8475236',
#   'Player Name': 'Cody Eakin',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8475625',
#   'Player Name': 'Matt Irwin',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8475772',
#   'Player Name': 'Riley Sheahan',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8475784',
#   'Player Name': 'Jeff Skinner',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8475791',
#   'Player Name': 'Taylor Hall',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8476356',
#   'Player Name': 'Tobias Rieder',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8476525',
#   'Player Name': 'Colin Miller',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8476931',
#   'Player Name': 'Jake McCabe',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8477499',
#   'Player Name': 'Rasmus Ristolainen',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8477508',
#   'Player Name': 'Curtis Lazar',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8477933',
#   'Player Name': 'Sam Reinhart',
#   'Team': 'BUF',
#   'Position': 'RW'},
#  {'player_id': '8477986',
#   'Player Name': 'Brandon Montour',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8478109',
#   'Player Name': 'Victor Olofsson',
#   'Team': 'BUF',
#   'Position': 'LW'},
#  {'player_id': '8478403',
#   'Player Name': 'Jack Eichel',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8479420',
#   'Player Name': 'Tage Thompson',
#   'Team': 'BUF',
#   'Position': 'RW'},
#  {'player_id': '8479999',
#   'Player Name': 'Casey Mittelstadt',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8480035',
#   'Player Name': 'Henri Jokiharju',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8480839',
#   'Player Name': 'Rasmus Dahlin',
#   'Team': 'BUF',
#   'Position': 'D'},
#  {'player_id': '8481528',
#   'Player Name': 'Dylan Cozens',
#   'Team': 'BUF',
#   'Position': 'C'},
#  {'player_id': '8470621',
#   'Player Name': 'Corey Perry',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8473564',
#   'Player Name': 'Michael Frolik',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8478133',
#   'Player Name': 'Jake Evans',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8470642',
#   'Player Name': 'Shea Weber',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8473507',
#   'Player Name': 'Jeff Petry',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8474038',
#   'Player Name': 'Paul Byron',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8475193',
#   'Player Name': 'Tomas Tatar',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8475279',
#   'Player Name': 'Ben Chiarot',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8475726',
#   'Player Name': 'Tyler Toffoli',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8475848',
#   'Player Name': 'Brendan Gallagher',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8476441',
#   'Player Name': 'Joel Edmundson',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8476469',
#   'Player Name': 'Joel Armia',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8476479',
#   'Player Name': 'Phillip Danault',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8476967',
#   'Player Name': 'Brett Kulak',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8476981',
#   'Player Name': 'Josh Anderson',
#   'Team': 'MTL',
#   'Position': 'RW'},
#  {'player_id': '8477476',
#   'Player Name': 'Artturi Lehkonen',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8477494',
#   'Player Name': 'Jonathan Drouin',
#   'Team': 'MTL',
#   'Position': 'LW'},
#  {'player_id': '8479376',
#   'Player Name': 'Victor Mete',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8480018',
#   'Player Name': 'Nick Suzuki',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8480829',
#   'Player Name': 'Jesperi Kotkaniemi',
#   'Team': 'MTL',
#   'Position': 'C'},
#  {'player_id': '8481014',
#   'Player Name': 'Alexander Romanov',
#   'Team': 'MTL',
#   'Position': 'D'},
#  {'player_id': '8480073',
#   'Player Name': 'Erik Brannstrom',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8474230',
#   'Player Name': 'Micheal Haley',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8476285',
#   'Player Name': 'Matthew Peca',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8478488',
#   'Player Name': 'Filip Chlapik',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8473573',
#   'Player Name': 'Artem Anisimov',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8474149',
#   'Player Name': 'Evgenii Dadonov',
#   'Team': 'OTT',
#   'Position': 'RW'},
#  {'player_id': '8474613',
#   'Player Name': 'Derek Stepan',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8475766',
#   'Player Name': 'Austin Watson',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8475790',
#   'Player Name': 'Erik Gudbranson',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8476422',
#   'Player Name': 'Mike Reilly',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8476851',
#   'Player Name': 'Alex Galchenyuk',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8476919',
#   'Player Name': 'Chris Tierney',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8476975',
#   'Player Name': 'Cedric Paquette',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8477015',
#   'Player Name': 'Connor Brown',
#   'Team': 'OTT',
#   'Position': 'RW'},
#  {'player_id': '8477384',
#   'Player Name': 'Josh Brown',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8477426',
#   'Player Name': 'Nick Paul',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8478400',
#   'Player Name': 'Colin White',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8478469',
#   'Player Name': 'Thomas Chabot',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8478846',
#   'Player Name': 'Christian Wolanin',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8479458',
#   'Player Name': 'Nikita Zaitsev',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8480064',
#   'Player Name': 'Josh Norris',
#   'Team': 'OTT',
#   'Position': 'C'},
#  {'player_id': '8480208',
#   'Player Name': 'Drake Batherson',
#   'Team': 'OTT',
#   'Position': 'RW'},
#  {'player_id': '8480801',
#   'Player Name': 'Brady Tkachuk',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8482116',
#   'Player Name': 'Tim Stützle',
#   'Team': 'OTT',
#   'Position': 'LW'},
#  {'player_id': '8482245',
#   'Player Name': 'Artem Zub',
#   'Team': 'OTT',
#   'Position': 'D'},
#  {'player_id': '8466138',
#   'Player Name': 'Joe Thornton',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8474190',
#   'Player Name': 'Wayne Simmonds',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8481582',
#   'Player Name': 'Nicholas Robertson',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8478115',
#   'Player Name': 'Pierre Engvall',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8469455',
#   'Player Name': 'Jason Spezza',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8474162',
#   'Player Name': 'Jake Muzzin',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8474567',
#   'Player Name': 'Zach Bogosian',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8474673',
#   'Player Name': 'TJ Brodie',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8475166',
#   'Player Name': 'John Tavares',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8475718',
#   'Player Name': 'Justin Holl',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8475786',
#   'Player Name': 'Zach Hyman',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8476329',
#   'Player Name': 'Travis Boyd',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8476853',
#   'Player Name': 'Morgan Rielly',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8476918',
#   'Player Name': 'Jimmy Vesey',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8477021',
#   'Player Name': 'Alexander Kerfoot',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8477939',
#   'Player Name': 'William Nylander',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8478408',
#   'Player Name': 'Travis Dermott',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8478483',
#   'Player Name': 'Mitchell Marner',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8479318',
#   'Player Name': 'Auston Matthews',
#   'Team': 'TOR',
#   'Position': 'C'},
#  {'player_id': '8480873',
#   'Player Name': 'Rasmus Sandin',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8481624',
#   'Player Name': 'Ilya Mikheyev',
#   'Team': 'TOR',
#   'Position': 'RW'},
#  {'player_id': '8482222',
#   'Player Name': 'Alexander Barabanov',
#   'Team': 'TOR',
#   'Position': 'LW'},
#  {'player_id': '8482247',
#   'Player Name': 'Mikko Lehtonen',
#   'Team': 'TOR',
#   'Position': 'D'},
#  {'player_id': '8476323',
#   'Player Name': 'Max McCormick',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8473533',
#   'Player Name': 'Jordan Staal',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8474581',
#   'Player Name': 'Jake Gardiner',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8475799',
#   'Player Name': 'Nino Niederreiter',
#   'Team': 'CAR',
#   'Position': 'RW'},
#  {'player_id': '8475855',
#   'Player Name': 'Jesper Fast',
#   'Team': 'CAR',
#   'Position': 'RW'},
#  {'player_id': '8476288',
#   'Player Name': 'Ryan Dzingel',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8476389',
#   'Player Name': 'Vincent Trocheck',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8476462',
#   'Player Name': 'Dougie Hamilton',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8476869',
#   'Player Name': 'Brady Skjei',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8476882',
#   'Player Name': 'Teuvo Teravainen',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8476921',
#   'Player Name': 'Jordan Martinook',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8476934',
#   'Player Name': 'Brock McGinn',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8476958',
#   'Player Name': 'Jaccob Slavin',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8477488',
#   'Player Name': 'Brett Pesce',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8477938',
#   'Player Name': 'Haydn Fleury',
#   'Team': 'CAR',
#   'Position': 'D'},
#  {'player_id': '8477998',
#   'Player Name': 'Warren Foegele',
#   'Team': 'CAR',
#   'Position': 'LW'},
#  {'player_id': '8478427',
#   'Player Name': 'Sebastian Aho',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8480039',
#   'Player Name': 'Martin Necas',
#   'Team': 'CAR',
#   'Position': 'C'},
#  {'player_id': '8480830',
#   'Player Name': 'Andrei Svechnikov',
#   'Team': 'CAR',
#   'Position': 'RW'},
#  {'player_id': '8478055',
#   'Player Name': 'Gustav Forsling',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8475246',
#   'Player Name': 'Kevin Connauton',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8478975',
#   'Player Name': 'Mason Marchment',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8471735',
#   'Player Name': 'Keith Yandle',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8471873',
#   'Player Name': 'Anton Stralman',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8471887',
#   'Player Name': 'Patric Hornqvist',
#   'Team': 'FLA',
#   'Position': 'RW'},
#  {'player_id': '8475462',
#   'Player Name': 'Radko Gudas',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8475792',
#   'Player Name': 'Brett Connolly',
#   'Team': 'FLA',
#   'Position': 'RW'},
#  {'player_id': '8476456',
#   'Player Name': 'Jonathan Huberdeau',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8476994',
#   'Player Name': 'Vinnie Hinostroza',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477346',
#   'Player Name': 'MacKenzie Weegar',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8477407',
#   'Player Name': 'Anthony Duclair',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8477409',
#   'Player Name': 'Carter Verhaeghe',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477493',
#   'Player Name': 'Aleksander Barkov',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477505',
#   'Player Name': 'Alex Wennberg',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8477932',
#   'Player Name': 'Aaron Ekblad',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8477996',
#   'Player Name': 'Juho Lammikko',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8478366',
#   'Player Name': 'Frank Vatrano',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8478454',
#   'Player Name': 'Noah Juulsen',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8478569',
#   'Player Name': 'Noel Acciari',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8478906',
#   'Player Name': 'Markus Nutivaara',
#   'Team': 'FLA',
#   'Position': 'D'},
#  {'player_id': '8479066',
#   'Player Name': 'Ryan Lomberg',
#   'Team': 'FLA',
#   'Position': 'LW'},
#  {'player_id': '8480015',
#   'Player Name': 'Owen Tippett',
#   'Team': 'FLA',
#   'Position': 'RW'},
#  {'player_id': '8480185',
#   'Player Name': 'Eetu Luostarinen',
#   'Team': 'FLA',
#   'Position': 'C'},
#  {'player_id': '8478477',
#   'Player Name': 'Mitchell Stephens',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8476966',
#   'Player Name': 'Gemel Smith',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8480158',
#   'Player Name': 'Andreas Borgman',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8473986',
#   'Player Name': 'Alex Killorn',
#   'Team': 'TBL',
#   'Position': 'LW'},
#  {'player_id': '8474034',
#   'Player Name': 'Pat Maroon',
#   'Team': 'TBL',
#   'Position': 'LW'},
#  {'player_id': '8474151',
#   'Player Name': 'Ryan McDonagh',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8474564',
#   'Player Name': 'Steven Stamkos',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8474568',
#   'Player Name': 'Luke Schenn',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8474870',
#   'Player Name': 'Tyler Johnson',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8475167',
#   'Player Name': 'Victor Hedman',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8476292',
#   'Player Name': 'Ondrej Palat',
#   'Team': 'TBL',
#   'Position': 'LW'},
#  {'player_id': '8476399',
#   'Player Name': 'Blake Coleman',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8476624',
#   'Player Name': 'Barclay Goodrow',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8476826',
#   'Player Name': 'Yanni Gourde',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8478010',
#   'Player Name': 'Brayden Point',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8478416',
#   'Player Name': 'Erik Cernak',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8478472',
#   'Player Name': 'Mathieu Joseph',
#   'Team': 'TBL',
#   'Position': 'RW'},
#  {'player_id': '8478519',
#   'Player Name': 'Anthony Cirelli',
#   'Team': 'TBL',
#   'Position': 'C'},
#  {'player_id': '8479410',
#   'Player Name': 'Mikhail Sergachev',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8479984',
#   'Player Name': 'Callan Foote',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8480172',
#   'Player Name': 'Jan Rutta',
#   'Team': 'TBL',
#   'Position': 'D'},
#  {'player_id': '8480186',
#   'Player Name': 'Alexander Volkov',
#   'Team': 'TBL',
#   'Position': 'RW'},
#  {'player_id': '8475744',
#   'Player Name': 'Evgeny Kuznetsov',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8475958',
#   'Player Name': 'Michael Sgarbossa',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8477314',
#   'Player Name': 'Brian Pinho',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8477901',
#   'Player Name': 'Daniel Carr',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8477944',
#   'Player Name': 'Jakub Vrana',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8479482',
#   'Player Name': 'Michal Kempny',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8465009',
#   'Player Name': 'Zdeno Chara',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8471214',
#   'Player Name': 'Alex Ovechkin',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8471698',
#   'Player Name': 'T.J. Oshie',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8473563',
#   'Player Name': 'Nicklas Backstrom',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8474176',
#   'Player Name': 'Carl Hagelin',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8474189',
#   'Player Name': 'Lars Eller',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8474590',
#   'Player Name': 'John Carlson',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8474602',
#   'Player Name': 'Justin Schultz',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8475200',
#   'Player Name': 'Dmitry Orlov',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8475209',
#   'Player Name': 'Richard Panik',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8475324',
#   'Player Name': 'Nick Jensen',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8475343',
#   'Player Name': 'Nic Dowd',
#   'Team': 'WSH',
#   'Position': 'C'},
#  {'player_id': '8475455',
#   'Player Name': 'Brenden Dillon',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8476880',
#   'Player Name': 'Tom Wilson',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8477839',
#   'Player Name': 'Conor Sheary',
#   'Team': 'WSH',
#   'Position': 'LW'},
#  {'player_id': '8477845',
#   'Player Name': 'Trevor van Riemsdyk',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8477903',
#   'Player Name': 'Garnet Hathaway',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8478399',
#   'Player Name': 'Jonas Siegenthaler',
#   'Team': 'WSH',
#   'Position': 'D'},
#  {'player_id': '8478466',
#   'Player Name': 'Daniel Sprong',
#   'Team': 'WSH',
#   'Position': 'RW'},
#  {'player_id': '8470607',
#   'Player Name': 'Brent Seabrook',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8474250',
#   'Player Name': 'Zack Smith',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8473604',
#   'Player Name': 'Jonathan Toews',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8477846',
#   'Player Name': 'Ryan Carpenter',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8478027',
#   'Player Name': 'Lucas Wallmark',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8478073',
#   'Player Name': 'Anton Lindholm',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8479423',
#   'Player Name': 'Alex Nylander',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8480025',
#   'Player Name': 'MacKenzie Entwistle',
#   'Team': 'CHI',
#   'Position': 'RW'},
#  {'player_id': '8480871',
#   'Player Name': 'Adam Boqvist',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8481147',
#   'Player Name': 'Reese Johnson',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8481523',
#   'Player Name': 'Kirby Dach',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8470281',
#   'Player Name': 'Duncan Keith',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8471262',
#   'Player Name': 'Carl Soderberg',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8474141',
#   'Player Name': 'Patrick Kane',
#   'Team': 'CHI',
#   'Position': 'RW'},
#  {'player_id': '8475177',
#   'Player Name': 'Calvin de Haan',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8476381',
#   'Player Name': 'Andrew Shaw',
#   'Team': 'CHI',
#   'Position': 'RW'},
#  {'player_id': '8476473',
#   'Player Name': 'Connor Murphy',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8477330',
#   'Player Name': 'Dominik Kubalik',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8477406',
#   'Player Name': 'Mattias Janmark',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8477474',
#   'Player Name': 'Madison Bowey',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8477507',
#   'Player Name': 'Nikita Zadorov',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8478146',
#   'Player Name': 'Matthew Highmore',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8478440',
#   'Player Name': 'Dylan Strome',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8479337',
#   'Player Name': 'Alex DeBrincat',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8479523',
#   'Player Name': 'Lucas Carlsson',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8479542',
#   'Player Name': 'Brandon Hagel',
#   'Team': 'CHI',
#   'Position': 'LW'},
#  {'player_id': '8480070',
#   'Player Name': 'Ian Mitchell',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8480144',
#   'Player Name': 'David Kampf',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8480459',
#   'Player Name': 'Pius Suter',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8480798',
#   'Player Name': 'Philipp Kurashev',
#   'Team': 'CHI',
#   'Position': 'C'},
#  {'player_id': '8480814',
#   'Player Name': 'Nicolas Beaudin',
#   'Team': 'CHI',
#   'Position': 'D'},
#  {'player_id': '8477479',
#   'Player Name': 'Tyler Bertuzzi',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8470047',
#   'Player Name': 'Valtteri Filppula',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8470144',
#   'Player Name': 'Frans Nielsen',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8471676',
#   'Player Name': 'Bobby Ryan',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8471686',
#   'Player Name': 'Marc Staal',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8471794',
#   'Player Name': 'Darren Helm',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8474040',
#   'Player Name': 'Sam Gagner',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8475747',
#   'Player Name': 'Patrik Nemeth',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8475750',
#   'Player Name': 'Jon Merrill',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8476480',
#   'Player Name': 'Vladislav Namestnikov',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8476822',
#   'Player Name': 'Luke Glendening',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8477043',
#   'Player Name': 'Christian Djoos',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8477215',
#   'Player Name': 'Danny DeKeyser',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8477454',
#   'Player Name': 'Adam Erne',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8477511',
#   'Player Name': 'Anthony Mantha',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8477946',
#   'Player Name': 'Dylan Larkin',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8477952',
#   'Player Name': 'Robby Fabbri',
#   'Team': 'DET',
#   'Position': 'C'},
#  {'player_id': '8479379',
#   'Player Name': 'Givani Smith',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8479425',
#   'Player Name': 'Filip Hronek',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8479442',
#   'Player Name': 'Troy Stecher',
#   'Team': 'DET',
#   'Position': 'D'},
#  {'player_id': '8480821',
#   'Player Name': 'Filip Zadina',
#   'Team': 'DET',
#   'Position': 'RW'},
#  {'player_id': '8482240',
#   'Player Name': 'Mathias Brome',
#   'Team': 'DET',
#   'Position': 'LW'},
#  {'player_id': '8470755',
#   'Player Name': 'Brad Richardson',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8474579',
#   'Player Name': 'Luca Sbisa',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475793',
#   'Player Name': 'Ryan Johansen',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8477433',
#   'Player Name': 'Ben Harpur',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8480009',
#   'Player Name': 'Eeli Tolvanen',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8474600',
#   'Player Name': 'Roman Josi',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8474697',
#   'Player Name': 'Mark Borowiecki',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475168',
#   'Player Name': 'Matt Duchene',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8475176',
#   'Player Name': 'Ryan Ellis',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475218',
#   'Player Name': 'Mattias Ekholm',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475287',
#   'Player Name': 'Erik Haula',
#   'Team': 'NSH',
#   'Position': 'LW'},
#  {'player_id': '8475714',
#   'Player Name': 'Calle Jarnkrok',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8475797',
#   'Player Name': 'Jarred Tinordi',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8475798',
#   'Player Name': 'Mikael Granlund',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8476393',
#   'Player Name': 'Nick Cousins',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8476428',
#   'Player Name': 'Rocco Grimaldi',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8476887',
#   'Player Name': 'Filip Forsberg',
#   'Team': 'NSH',
#   'Position': 'LW'},
#  {'player_id': '8476925',
#   'Player Name': 'Colton Sissons',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8476988',
#   'Player Name': 'Matt Benning',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8477391',
#   'Player Name': 'Sean Malone',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8477446',
#   'Player Name': 'Michael McCarron',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8478042',
#   'Player Name': 'Viktor Arvidsson',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8478508',
#   'Player Name': 'Yakov Trenin',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8479316',
#   'Player Name': 'Luke Kunin',
#   'Team': 'NSH',
#   'Position': 'C'},
#  {'player_id': '8479371',
#   'Player Name': 'Dante Fabbro',
#   'Team': 'NSH',
#   'Position': 'D'},
#  {'player_id': '8479671',
#   'Player Name': 'Mathieu Olivier',
#   'Team': 'NSH',
#   'Position': 'RW'},
#  {'player_id': '8475098',
#   'Player Name': 'Tyler Bozak',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8480023',
#   'Player Name': 'Robert Thomas',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8476907',
#   'Player Name': 'Mackenzie MacEachern',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8477455',
#   'Player Name': 'Jacob de la Rose',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8474102',
#   'Player Name': 'David Perron',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8474125',
#   'Player Name': 'Carl Gunnarsson',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8474145',
#   'Player Name': 'Robert Bortuzzo',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8474618',
#   'Player Name': 'Marco Scandella',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8474884',
#   'Player Name': 'Mike Hoffman',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8475158',
#   'Player Name': "Ryan O'Reilly",
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8475160',
#   'Player Name': 'Kyle Clifford',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8475170',
#   'Player Name': 'Brayden Schenn',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8475753',
#   'Player Name': 'Justin Faulk',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8475768',
#   'Player Name': 'Jaden Schwartz',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8476792',
#   'Player Name': 'Torey Krug',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8476892',
#   'Player Name': 'Colton Parayko',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8476897',
#   'Player Name': 'Oskar Sundqvist',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8477482',
#   'Player Name': 'Zach Sanford',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8477964',
#   'Player Name': 'Ivan Barbashev',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8478104',
#   'Player Name': 'Sammy Blais',
#   'Team': 'STL',
#   'Position': 'LW'},
#  {'player_id': '8478407',
#   'Player Name': 'Vince Dunn',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8478859',
#   'Player Name': 'Niko Mikkola',
#   'Team': 'STL',
#   'Position': 'D'},
#  {'player_id': '8479385',
#   'Player Name': 'Jordan Kyrou',
#   'Team': 'STL',
#   'Position': 'C'},
#  {'player_id': '8478585',
#   'Player Name': 'Derek Ryan',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8474736',
#   'Player Name': 'Zac Rinaldo',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8477210',
#   'Player Name': 'Buddy Robinson',
#   'Team': 'CGY',
#   'Position': 'RW'},
#  {'player_id': '8478430',
#   'Player Name': 'Oliver Kylington',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8470966',
#   'Player Name': 'Mark Giordano',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8473473',
#   'Player Name': 'Milan Lucic',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8474150',
#   'Player Name': 'Mikael Backlund',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8475278',
#   'Player Name': 'Byron Froese',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8475690',
#   'Player Name': 'Christopher Tanev',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8475807',
#   'Player Name': 'Joakim Nordstrom',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8476300',
#   'Player Name': 'Nikita Nesterov',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8476346',
#   'Player Name': 'Johnny Gaudreau',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8476410',
#   'Player Name': 'Josh Leivo',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8476439',
#   'Player Name': 'Brett Ritchie',
#   'Team': 'CGY',
#   'Position': 'RW'},
#  {'player_id': '8477496',
#   'Player Name': 'Elias Lindholm',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8477497',
#   'Player Name': 'Sean Monahan',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8477935',
#   'Player Name': 'Sam Bennett',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8478233',
#   'Player Name': 'Andrew Mangiapane',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8478396',
#   'Player Name': 'Noah Hanifin',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8478397',
#   'Player Name': 'Rasmus Andersson',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8478866',
#   'Player Name': 'Dominik Simon',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8479314',
#   'Player Name': 'Matthew Tkachuk',
#   'Team': 'CGY',
#   'Position': 'LW'},
#  {'player_id': '8479346',
#   'Player Name': 'Dillon Dube',
#   'Team': 'CGY',
#   'Position': 'C'},
#  {'player_id': '8479976',
#   'Player Name': 'Juuso Valimaki',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8482067',
#   'Player Name': 'Connor Mackey',
#   'Team': 'CGY',
#   'Position': 'D'},
#  {'player_id': '8474685',
#   'Player Name': 'Matt Calvert',
#   'Team': 'COL',
#   'Position': 'LW'},
#  {'player_id': '8478038',
#   'Player Name': 'Devon Toews',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8474688',
#   'Player Name': 'Greg Pateryn',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8478502',
#   'Player Name': 'Dennis Gilbert',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8479439',
#   'Player Name': 'Jacob MacDonald',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8480032',
#   'Player Name': 'Shane Bowers',
#   'Team': 'COL',
#   'Position': 'C'},
#  {'player_id': '8480326',
#   'Player Name': 'Sheldon Dries',
#   'Team': 'COL',
#   'Position': 'C'},
#  {'player_id': '8480748',
#   'Player Name': 'Kiefer Sherwood',
#   'Team': 'COL',
#   'Position': 'LW'},
#  {'player_id': '8473446',
#   'Player Name': 'Erik Johnson',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8475172',
#   'Player Name': 'Nazem Kadri',
#   'Team': 'COL',
#   'Position': 'C'},
#  {'player_id': '8475820',
#   'Player Name': 'Joonas Donskoi',
#   'Team': 'COL',
#   'Position': 'RW'},
#  {'player_id': '8476438',
#   'Player Name': 'Brandon Saad',
#   'Team': 'COL',
#   'Position': 'LW'},
#  {'player_id': '8476455',
#   'Player Name': 'Gabriel Landeskog',
#   'Team': 'COL',
#   'Position': 'LW'},
#  {'player_id': '8477435',
#   'Player Name': 'Ryan Graves',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8477444',
#   'Player Name': 'Andre Burakovsky',
#   'Team': 'COL',
#   'Position': 'LW'},
#  {'player_id': '8477456',
#   'Player Name': 'J.T. Compher',
#   'Team': 'COL',
#   'Position': 'LW'},
#  {'player_id': '8477492',
#   'Player Name': 'Nathan MacKinnon',
#   'Team': 'COL',
#   'Position': 'C'},
#  {'player_id': '8477501',
#   'Player Name': 'Valeri Nichushkin',
#   'Team': 'COL',
#   'Position': 'RW'},
#  {'player_id': '8477930',
#   'Player Name': 'Pierre-Edouard Bellemare',
#   'Team': 'COL',
#   'Position': 'C'},
#  {'player_id': '8478420',
#   'Player Name': 'Mikko Rantanen',
#   'Team': 'COL',
#   'Position': 'RW'},
#  {'player_id': '8479370',
#   'Player Name': 'Tyson Jost',
#   'Team': 'COL',
#   'Position': 'C'},
#  {'player_id': '8479398',
#   'Player Name': 'Samuel Girard',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8479982',
#   'Player Name': 'Conor Timmins',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8480069',
#   'Player Name': 'Cale Makar',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8481186',
#   'Player Name': "Logan O'Connor",
#   'Team': 'COL',
#   'Position': 'RW'},
#  {'player_id': '8481524',
#   'Player Name': 'Bowen Byram',
#   'Team': 'COL',
#   'Position': 'D'},
#  {'player_id': '8475178',
#   'Player Name': 'Zack Kassian',
#   'Team': 'EDM',
#   'Position': 'RW'},
#  {'player_id': '8478451',
#   'Player Name': 'Ethan Bear',
#   'Team': 'EDM',
#   'Position': 'D'},
#  {'player_id': '8481813',
#   'Player Name': 'Gaetan Haas',
#   'Team': 'EDM',
#   'Position': 'C'},
#  {'player_id': '8479466',
#   'Player Name': 'Patrick Russell',
#   'Team': 'EDM',
#   'Position': 'RW'},
#  {'player_id': '8481638',
#   'Player Name': 'Joakim Nygard',
#   'Team': 'EDM',
#   'Position': 'LW'},
#  {'player_id': '8471707',
#   'Player Name': 'James Neal',
#   'Team': 'EDM',
#   'Position': 'LW'},
#  {'player_id': '8471729',
#   'Player Name': 'Kris Russell',
#   'Team': 'EDM',
#   'Position': 'D'},
#  {'player_id': '8474068',
#   'Player Name': 'Kyle Turris',
#   'Team': 'EDM',
#   'Position': 'C'},
#  {'player_id': '8474589',
#   'Player Name': 'Tyler Ennis',
#   'Team': 'EDM',
#   'Position': 'C'},
#  {'player_id': '8475163',
#   'Player Name': 'Alex Chiasson',
#   'Team': 'EDM',
#   'Position': 'RW'},
#  {'player_id': '8475197',
#   'Player Name': 'Tyson Barrie',
#   'Team': 'EDM',
#   'Position': 'D'},
#  {'player_id': '8476326',
#   'Player Name': 'Josh Archibald',
#   'Team': 'EDM',
#   'Position': 'RW'},
#  {'player_id': '8476454',
#   'Player Name': 'Ryan Nugent-Hopkins',
#   'Team': 'EDM',
#   'Position': 'C'},
#  {'player_id': '8476457',
#   'Player Name': 'Adam Larsson',
#   'Team': 'EDM',
#   'Position': 'D'},
#  {'player_id': '8476886',
#   'Player Name': 'Slater Koekkoek',
#   'Team': 'EDM',
#   'Position': 'D'},
#  {'player_id': '8476913',
#   'Player Name': 'Devin Shore',
#   'Team': 'EDM',
#   'Position': 'C'},
# ...
#  {'player_id': '8475729',
#   'Player Name': 'Mark Alt',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8478147',
#   'Player Name': 'Bokondji Imama',
#   'Team': 'LAK',
#   'Position': 'LW'},
#  {'player_id': '8480206',
#   'Player Name': 'Markus Phillips',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8481560',
#   'Player Name': 'Arthur Kaliyev',
#   'Team': 'LAK',
#   'Position': 'RW'},
#  {'player_id': '8470604',
#   'Player Name': 'Jeff Carter',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8470606',
#   'Player Name': 'Dustin Brown',
#   'Team': 'LAK',
#   'Position': 'RW'},
#  {'player_id': '8471685',
#   'Player Name': 'Anze Kopitar',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8474563',
#   'Player Name': 'Drew Doughty',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8476874',
#   'Player Name': 'Olli Maatta',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8476924',
#   'Player Name': 'Martin Frk',
#   'Team': 'LAK',
#   'Position': 'RW'},
#  {'player_id': '8477073',
#   'Player Name': 'Kurtis MacDermid',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8477960',
#   'Player Name': 'Adrian Kempe',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8478020',
#   'Player Name': 'Michael Amadio',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8478455',
#   'Player Name': 'Austin Wagner',
#   'Team': 'LAK',
#   'Position': 'LW'},
#  {'player_id': '8479336',
#   'Player Name': 'Carl Grundstrom',
#   'Team': 'LAK',
#   'Position': 'RW'},
#  {'player_id': '8479348',
#   'Player Name': 'Kale Clague',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8479644',
#   'Player Name': 'Matt Luff',
#   'Team': 'LAK',
#   'Position': 'RW'},
#  {'player_id': '8479675',
#   'Player Name': 'Trevor Moore',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8479994',
#   'Player Name': 'Jaret Anderson-Dolan',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8479998',
#   'Player Name': 'Mikey Anderson',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8480014',
#   'Player Name': 'Gabriel Vilardi',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8480072',
#   'Player Name': 'Lias Andersson',
#   'Team': 'LAK',
#   'Position': 'C'},
#  {'player_id': '8480113',
#   'Player Name': 'Alex Iafallo',
#   'Team': 'LAK',
#   'Position': 'LW'},
#  {'player_id': '8480467',
#   'Player Name': 'Austin Strand',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8481600',
#   'Player Name': 'Tobias Bjornfot',
#   'Team': 'LAK',
#   'Position': 'D'},
#  {'player_id': '8466139',
#   'Player Name': 'Patrick Marleau',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8470613',
#   'Player Name': 'Brent Burns',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8471709',
#   'Player Name': 'Marc-Edouard Vlasic',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8474053',
#   'Player Name': 'Logan Couture',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8474578',
#   'Player Name': 'Erik Karlsson',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8475169',
#   'Player Name': 'Evander Kane',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8475834',
#   'Player Name': 'Marcus Sorensen',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8476442',
#   'Player Name': 'Matt Nieto',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8476474',
#   'Player Name': 'Stefan Noesen',
#   'Team': 'SJS',
#   'Position': 'RW'},
#  {'player_id': '8476881',
#   'Player Name': 'Tomas Hertl',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8477987',
#   'Player Name': 'Ryan Donato',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8478099',
#   'Player Name': 'Kevin Labanc',
#   'Team': 'SJS',
#   'Position': 'RW'},
#  {'player_id': '8478414',
#   'Player Name': 'Timo Meier',
#   'Team': 'SJS',
#   'Position': 'RW'},
#  {'player_id': '8478467',
#   'Player Name': 'Nicolas Meloche',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8478870',
#   'Player Name': 'Rudolfs Balcers',
#   'Team': 'SJS',
#   'Position': 'LW'},
#  {'player_id': '8479393',
#   'Player Name': 'Noah Gregor',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8479580',
#   'Player Name': 'Dylan Gambrell',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8479983',
#   'Player Name': 'Mario Ferraro',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8480053',
#   'Player Name': 'Alexander Chmelevski',
#   'Team': 'SJS',
#   'Position': 'C'},
#  {'player_id': '8480160',
#   'Player Name': 'Radim Simek',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8481812',
#   'Player Name': 'Nikolai Knyzhov',
#   'Team': 'SJS',
#   'Position': 'D'},
#  {'player_id': '8471273',
#   'Player Name': 'Brandon Dubinsky',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478460',
#   'Player Name': 'Zach Werenski',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8476870',
#   'Player Name': 'Stefan Matteau',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8473422',
#   'Player Name': 'Nick Foligno',
#   'Team': 'CBJ',
#   'Position': 'LW'},
#  {'player_id': '8474062',
#   'Player Name': 'Riley Nash',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8474584',
#   'Player Name': 'Michael Del Zotto',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8474715',
#   'Player Name': 'Cam Atkinson',
#   'Team': 'CBJ',
#   'Position': 'RW'},
#  {'player_id': '8475233',
#   'Player Name': 'David Savard',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8476432',
#   'Player Name': 'Boone Jenner',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8476449',
#   'Player Name': 'Scott Harrington',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8476888',
#   'Player Name': 'Mikhail Grigorenko',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8477416',
#   'Player Name': 'Oliver Bjorkstrand',
#   'Team': 'CBJ',
#   'Position': 'RW'},
#  {'player_id': '8477495',
#   'Player Name': 'Seth Jones',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8477503',
#   'Player Name': 'Max Domi',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478458',
#   'Player Name': 'Jack Roslovic',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478506',
#   'Player Name': 'Gabriel Carlsson',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8478567',
#   'Player Name': 'Dean Kukan',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8478831',
#   'Player Name': 'Kevin Stenlund',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8478882',
#   'Player Name': 'Vladislav Gavrikov',
#   'Team': 'CBJ',
#   'Position': 'D'},
#  {'player_id': '8479339',
#   'Player Name': 'Patrik Laine',
#   'Team': 'CBJ',
#   'Position': 'RW'},
#  {'player_id': '8480074',
#   'Player Name': 'Alexandre Texier',
#   'Team': 'CBJ',
#   'Position': 'C'},
#  {'player_id': '8480762',
#   'Player Name': 'Eric Robinson',
#   'Team': 'CBJ',
#   'Position': 'LW'},
#  {'player_id': '8476856',
#   'Player Name': 'Matt Dumba',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8474749',
#   'Player Name': 'Matt Bartkowski',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8475692',
#   'Player Name': 'Mats Zuccarello',
#   'Team': 'MIN',
#   'Position': 'RW'},
#  {'player_id': '8476415',
#   'Player Name': 'Kyle Rau',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8477366',
#   'Player Name': 'Luke Johnson',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8477541',
#   'Player Name': 'Dakota Mermis',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8478011',
#   'Player Name': 'Louie Belpedio',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8479933',
#   'Player Name': 'Gerald Mayhew',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8482079',
#   'Player Name': 'Marco Rossi',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8470600',
#   'Player Name': 'Ryan Suter',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8470610',
#   'Player Name': 'Zach Parise',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8474009',
#   'Player Name': 'Nick Bonino',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8474013',
#   'Player Name': 'Ian Cole',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8474716',
#   'Player Name': 'Jared Spurgeon',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8475149',
#   'Player Name': 'Marcus Johansson',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8475220',
#   'Player Name': 'Marcus Foligno',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8475760',
#   'Player Name': 'Nick Bjugstad',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8476437',
#   'Player Name': 'Victor Rask',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8476463',
#   'Player Name': 'Jonas Brodin',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8476779',
#   'Player Name': 'Brad Hunt',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8477369',
#   'Player Name': 'Carson Soucy',
#   'Team': 'MIN',
#   'Position': 'D'},
#  {'player_id': '8477451',
#   'Player Name': 'Ryan Hartman',
#   'Team': 'MIN',
#   'Position': 'RW'},
#  {'player_id': '8477942',
#   'Player Name': 'Kevin Fiala',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8478413',
#   'Player Name': 'Jordan Greenway',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8478493',
#   'Player Name': 'Joel Eriksson Ek',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8478864',
#   'Player Name': 'Kirill Kaprizov',
#   'Team': 'MIN',
#   'Position': 'LW'},
#  {'player_id': '8481477',
#   'Player Name': 'Nico Sturm',
#   'Team': 'MIN',
#   'Position': 'C'},
#  {'player_id': '8470775',
#   'Player Name': 'Nate Thompson',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8473412',
#   'Player Name': 'Bryan Little',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8478424',
#   'Player Name': 'Jansen Harkins',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8477359',
#   'Player Name': 'Tucker Poolman',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8481572',
#   'Player Name': 'Ville Heinola',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8471218',
#   'Player Name': 'Blake Wheeler',
#   'Team': 'WPG',
#   'Position': 'RW'},
#  {'player_id': '8471669',
#   'Player Name': 'Paul Stastny',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8473453',
#   'Player Name': 'Trevor Lewis',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8473618',
#   'Player Name': 'Mathieu Perreault',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8475762',
#   'Player Name': 'Derek Forbort',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8476331',
#   'Player Name': 'Dylan DeMelo',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8476392',
#   'Player Name': 'Adam Lowry',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8476460',
#   'Player Name': 'Mark Scheifele',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8476470',
#   'Player Name': 'Nathan Beaulieu',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8477429',
#   'Player Name': 'Andrew Copp',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8477504',
#   'Player Name': 'Josh Morrissey',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8477940',
#   'Player Name': 'Nikolaj Ehlers',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8478398',
#   'Player Name': 'Kyle Connor',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8478891',
#   'Player Name': 'Mason Appleton',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8478915',
#   'Player Name': 'Sami Niku',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8479378',
#   'Player Name': 'Logan Stanley',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8479400',
#   'Player Name': 'Pierre-Luc Dubois',
#   'Team': 'WPG',
#   'Position': 'LW'},
#  {'player_id': '8480145',
#   'Player Name': 'Neal Pionk',
#   'Team': 'WPG',
#   'Position': 'D'},
#  {'player_id': '8481019',
#   'Player Name': 'David Gustafsson',
#   'Team': 'WPG',
#   'Position': 'C'},
#  {'player_id': '8475171',
#   'Player Name': 'Oliver Ekman-Larsson',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8478432',
#   'Player Name': 'Christian Fischer',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8478476',
#   'Player Name': 'Kyle Capobianco',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8480913',
#   'Player Name': 'Jordan Gross',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8471274',
#   'Player Name': 'Alex Goligoski',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8471769',
#   'Player Name': 'Niklas Hjalmarsson',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8473544',
#   'Player Name': 'Derick Brassard',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8473548',
#   'Player Name': 'Phil Kessel',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8474218',
#   'Player Name': 'Jason Demers',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8475728',
#   'Player Name': 'Johan Larsson',
#   'Team': 'ARI',
#   'Position': 'LW'},
#  {'player_id': '8475752',
#   'Player Name': 'Tyler Pitlick',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8477401',
#   'Player Name': 'John Hayden',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8477851',
#   'Player Name': 'Jordan Oesterle',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8477951',
#   'Player Name': 'Nick Schmaltz',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8477989',
#   'Player Name': 'Christian Dvorak',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8478474',
#   'Player Name': 'Lawson Crouse',
#   'Team': 'ARI',
#   'Position': 'LW'},
#  {'player_id': '8478856',
#   'Player Name': 'Conor Garland',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8479343',
#   'Player Name': 'Clayton Keller',
#   'Team': 'ARI',
#   'Position': 'RW'},
#  {'player_id': '8479345',
#   'Player Name': 'Jakob Chychrun',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8479465',
#   'Player Name': 'Drake Caggiula',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8480849',
#   'Player Name': 'Barrett Hayton',
#   'Team': 'ARI',
#   'Position': 'C'},
#  {'player_id': '8480950',
#   'Player Name': 'Ilya Lyubushkin',
#   'Team': 'ARI',
#   'Position': 'D'},
#  {'player_id': '8475188',
#   'Player Name': 'Brayden McNabb',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8476430',
#   'Player Name': 'Tomas Jurco',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8481522',
#   'Player Name': 'Peyton Krebs',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8471817',
#   'Player Name': 'Ryan Reaves',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8474157',
#   'Player Name': 'Max Pacioretty',
#   'Team': 'VGK',
#   'Position': 'LW'},
#  {'player_id': '8474166',
#   'Player Name': 'Alec Martinez',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8474207',
#   'Player Name': 'Nick Holden',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8474565',
#   'Player Name': 'Alex Pietrangelo',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8475191',
#   'Player Name': 'Reilly Smith',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8475913',
#   'Player Name': 'Mark Stone',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8476448',
#   'Player Name': 'William Karlsson',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8476539',
#   'Player Name': 'Jonathan Marchessault',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8476905',
#   'Player Name': 'Chandler Stephenson',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8477447',
#   'Player Name': 'Shea Theodore',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8477478',
#   'Player Name': 'William Carrier',
#   'Team': 'VGK',
#   'Position': 'LW'},
#  {'player_id': '8477931',
#   'Player Name': 'Tomas Nosek',
#   'Team': 'VGK',
#   'Position': 'LW'},
#  {'player_id': '8477949',
#   'Player Name': 'Alex Tuch',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8478434',
#   'Player Name': 'Keegan Kolesar',
#   'Team': 'VGK',
#   'Position': 'RW'},
#  {'player_id': '8478462',
#   'Player Name': 'Nicolas Roy',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8479639',
#   'Player Name': 'Dylan Coghlan',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8479980',
#   'Player Name': 'Nicolas Hague',
#   'Team': 'VGK',
#   'Position': 'D'},
#  {'player_id': '8479996',
#   'Player Name': 'Cody Glass',
#   'Team': 'VGK',
#   'Position': 'C'},
#  {'player_id': '8480727',
#   'Player Name': 'Zach Whitecloud',
#   'Team': 'VGK',
#   'Position': 'D'}]

# %%
# Get skater stats for most third season
skater_data_season3 = get_skater_stats(deepcopy(skater_data), season3)
# Out:
# [{'player_id': '8475222',
#   'Player Name': 'Sami Vatanen',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 47,
#   'G': 5,
#   'A': 18,
#   'Points': 23,
#   '+/-': -12,
#   'PIM': 22,
#   'SOG': 95,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 9,
#   'PPP': 10,
#   'BS': 80,
#   'Hits': 50,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8478447',
#   'Player Name': 'Nicholas Merkley',
#   'Team': 'NJD',
#   'Position': 'RW',
#   'Games': 4,
#   'G': 1,
#   'A': 1,
#   'Points': 2,
#   '+/-': 0,
#   'PIM': 2,
#   'SOG': 8,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 2,
#   'Hits': 9,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480003',
#   'Player Name': 'Jesper Boqvist',
#   'Team': 'NJD',
#   'Position': 'C',
#   'Games': 35,
#   'G': 4,
#   'A': 0,
#   'Points': 4,
#   '+/-': -11,
#   'PIM': 8,
#   'SOG': 41,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 16,
#   'Hits': 37,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480860',
#   'Player Name': 'Kevin Bahl',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474056',
#   'Player Name': 'P.K. Subban',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 68,
#   'G': 7,
#   'A': 11,
#   'Points': 18,
#   '+/-': -21,
#   'PIM': 79,
#   'SOG': 151,
#   'GWG': 3,
#   'PPG': 2,
#   'PPA': 4,
#   'PPP': 6,
#   'BS': 90,
#   'Hits': 88,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475151',
#   'Player Name': 'Kyle Palmieri',
#   'Team': 'NJD',
#   'Position': 'RW',
#   'Games': 65,
#   'G': 25,
#   'A': 20,
#   'Points': 45,
#   '+/-': -4,
#   'PIM': 41,
#   'SOG': 155,
#   'GWG': 3,
#   'PPG': 11,
#   'PPA': 7,
#   'PPP': 18,
#   'BS': 36,
#   'Hits': 74,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475179',
#   'Player Name': 'Dmitry Kulikov',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 51,
#   'G': 2,
#   'A': 8,
#   'Points': 10,
#   '+/-': -4,
#   'PIM': 32,
#   'SOG': 54,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 77,
#   'Hits': 104,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476807',
#   'Player Name': 'Matt Tennyson',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 20,
#   'G': 0,
#   'A': 3,
#   'Points': 3,
#   '+/-': -2,
#   'PIM': 6,
#   'SOG': 14,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 18,
#   'Hits': 27,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476850',
#   'Player Name': 'Ryan Murray',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 27,
#   'G': 2,
#   'A': 7,
#   'Points': 9,
#   '+/-': -9,
#   'PIM': 4,
#   'SOG': 32,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 2,
#   'PPP': 2,
#   'BS': 50,
#   'Hits': 12,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476923',
#   'Player Name': 'Damon Severson',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 69,
#   'G': 8,
#   'A': 23,
#   'Points': 31,
#   '+/-': -20,
#   'PIM': 52,
#   'SOG': 114,
#   'GWG': 2,
#   'PPG': 3,
#   'PPA': 7,
#   'PPP': 10,
#   'BS': 97,
#   'Hits': 81,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476941',
#   'Player Name': 'Connor Carrick',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 29,
#   'G': 1,
#   'A': 5,
#   'Points': 6,
#   '+/-': -6,
#   'PIM': 17,
#   'SOG': 25,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 39,
#   'Hits': 27,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477038',
#   'Player Name': 'Nikita Gusev',
#   'Team': 'NJD',
#   'Position': 'LW',
#   'Games': 66,
#   'G': 13,
#   'A': 31,
#   'Points': 44,
#   '+/-': -15,
#   'PIM': 12,
#   'SOG': 158,
#   'GWG': 2,
#   'PPG': 5,
#   'PPA': 10,
#   'PPP': 15,
#   'BS': 7,
#   'Hits': 12,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477341',
#   'Player Name': 'Andreas Johnsson',
#   'Team': 'NJD',
#   'Position': 'LW',
#   'Games': 43,
#   'G': 8,
#   'A': 13,
#   'Points': 21,
#   '+/-': 0,
#   'PIM': 14,
#   'SOG': 78,
#   'GWG': 1,
#   'PPG': 4,
#   'PPA': 1,
#   'PPP': 5,
#   'BS': 21,
#   'Hits': 43,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477355',
#   'Player Name': 'Will Butcher',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 56,
#   'G': 4,
#   'A': 17,
#   'Points': 21,
#   '+/-': -8,
#   'PIM': 6,
#   'SOG': 62,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 75,
#   'Hits': 31,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477425',
#   'Player Name': 'Miles Wood',
#   'Team': 'NJD',
#   'Position': 'LW',
#   'Games': 68,
#   'G': 11,
#   'A': 12,
#   'Points': 23,
#   '+/-': -19,
#   'PIM': 57,
#   'SOG': 141,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 26,
#   'Hits': 102,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478401',
#   'Player Name': 'Pavel Zacha',
#   'Team': 'NJD',
#   'Position': 'C',
#   'Games': 65,
#   'G': 8,
#   'A': 24,
#   'Points': 32,
#   '+/-': -12,
#   'PIM': 14,
#   'SOG': 97,
#   'GWG': 1,
#   'PPG': 3,
#   'PPA': 5,
#   'PPP': 8,
#   'BS': 19,
#   'Hits': 62,
#   'SHG': 2,
#   'SHA': 2},
#  {'player_id': '8479407',
#   'Player Name': 'Jesper Bratt',
#   'Team': 'NJD',
#   'Position': 'LW',
#   'Games': 60,
#   'G': 16,
#   'A': 16,
#   'Points': 32,
#   '+/-': -6,
#   'PIM': 6,
#   'SOG': 101,
#   'GWG': 2,
#   'PPG': 1,
#   'PPA': 5,
#   'PPP': 6,
#   'BS': 22,
#   'Hits': 29,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479414',
#   'Player Name': 'Nathan Bastian',
#   'Team': 'NJD',
#   'Position': 'RW',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479415',
#   'Player Name': 'Michael McLeod',
#   'Team': 'NJD',
#   'Position': 'C',
#   'Games': 12,
#   'G': 0,
#   'A': 2,
#   'Points': 2,
#   '+/-': 4,
#   'PIM': 4,
#   'SOG': 11,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 6,
#   'Hits': 19,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479511',
#   'Player Name': 'Janne Kuokkanen',
#   'Team': 'NJD',
#   'Position': 'LW',
#   'Games': 1,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 3,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479573',
#   'Player Name': 'Mikhail Maltsev',
#   'Team': 'NJD',
#   'Position': 'LW',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480883',
#   'Player Name': 'Ty Smith',
#   'Team': 'NJD',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8481068',
#   'Player Name': 'Yegor Sharangovich',
#   'Team': 'NJD',
#   'Position': 'C',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8481559',
#   'Player Name': 'Jack Hughes',
#   'Team': 'NJD',
#   'Position': 'C',
#   'Games': 61,
#   'G': 7,
#   'A': 14,
#   'Points': 21,
#   '+/-': -26,
#   'PIM': 10,
#   'SOG': 123,
#   'GWG': 2,
#   'PPG': 4,
#   'PPA': 5,
#   'PPP': 9,
#   'BS': 21,
#   'Hits': 12,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478463',
#   'Player Name': 'Anthony Beauvillier',
#   'Team': 'NYI',
#   'Position': 'LW',
#   'Games': 68,
#   'G': 18,
#   'A': 21,
#   'Points': 39,
#   '+/-': -11,
#   'PIM': 15,
#   'SOG': 132,
#   'GWG': 3,
#   'PPG': 3,
#   'PPA': 4,
#   'PPP': 7,
#   'BS': 36,
#   'Hits': 86,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8470187',
#   'Player Name': 'Johnny Boychuk',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 64,
#   'G': 2,
#   'A': 9,
#   'Points': 11,
#   '+/-': -11,
#   'PIM': 14,
#   'SOG': 96,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 128,
#   'Hits': 135,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474066',
#   'Player Name': 'Thomas Hickey',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478857',
#   'Player Name': 'Dmytro Timashov',
#   'Team': 'NYI',
#   'Position': 'LW',
#   'Games': 44,
#   'G': 4,
#   'A': 5,
#   'Points': 9,
#   '+/-': 1,
#   'PIM': 16,
#   'SOG': 37,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 11,
#   'Hits': 93,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479526',
#   'Player Name': 'Otto Koivula',
#   'Team': 'NYI',
#   'Position': 'LW',
#   'Games': 12,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 2,
#   'SOG': 4,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 4,
#   'Hits': 12,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480789',
#   'Player Name': 'Oliver Wahlstrom',
#   'Team': 'NYI',
#   'Position': 'RW',
#   'Games': 9,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': -2,
#   'PIM': 4,
#   'SOG': 9,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 4,
#   'Hits': 10,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8472382',
#   'Player Name': 'Andy Greene',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 63,
#   'G': 2,
#   'A': 12,
#   'Points': 14,
#   '+/-': 1,
#   'PIM': 16,
#   'SOG': 60,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 155,
#   'Hits': 30,
#   'SHG': 0,
#   'SHA': 2},
#  {'player_id': '8473463',
#   'Player Name': 'Leo Komarov',
#   'Team': 'NYI',
#   'Position': 'RW',
#   'Games': 48,
#   'G': 4,
#   'A': 10,
#   'Points': 14,
#   '+/-': 2,
#   'PIM': 10,
#   'SOG': 46,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 29,
#   'Hits': 123,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8473504',
#   'Player Name': 'Cal Clutterbuck',
#   'Team': 'NYI',
#   'Position': 'RW',
#   'Games': 37,
#   'G': 3,
#   'A': 4,
#   'Points': 7,
#   '+/-': 6,
#   'PIM': 22,
#   'SOG': 35,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 38,
#   'Hits': 127,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8474573',
#   'Player Name': 'Josh Bailey',
#   'Team': 'NYI',
#   'Position': 'RW',
#   'Games': 68,
#   'G': 14,
#   'A': 29,
#   'Points': 43,
#   '+/-': -12,
#   'PIM': 10,
#   'SOG': 94,
#   'GWG': 2,
#   'PPG': 2,
#   'PPA': 7,
#   'PPP': 9,
#   'BS': 48,
#   'Hits': 20,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8474586',
#   'Player Name': 'Jordan Eberle',
#   'Team': 'NYI',
#   'Position': 'RW',
#   'Games': 58,
#   'G': 16,
#   'A': 24,
#   'Points': 40,
#   '+/-': 1,
#   'PIM': 12,
#   'SOG': 136,
#   'GWG': 1,
#   'PPG': 4,
#   'PPA': 7,
#   'PPP': 11,
#   'BS': 39,
#   'Hits': 37,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474709',
#   'Player Name': 'Matt Martin',
#   'Team': 'NYI',
#   'Position': 'LW',
#   'Games': 55,
#   'G': 5,
#   'A': 3,
#   'Points': 8,
#   '+/-': -1,
#   'PIM': 40,
#   'SOG': 49,
#   'GWG': 2,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 24,
#   'Hits': 242,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475181',
#   'Player Name': 'Nick Leddy',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 60,
#   'G': 3,
#   'A': 18,
#   'Points': 21,
#   '+/-': -1,
#   'PIM': 14,
#   'SOG': 72,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 3,
#   'PPP': 4,
#   'BS': 72,
#   'Hits': 62,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475231',
#   'Player Name': 'Casey Cizikas',
#   'Team': 'NYI',
#   'Position': 'C',
#   'Games': 48,
#   'G': 10,
#   'A': 4,
#   'Points': 14,
#   '+/-': 12,
#   'PIM': 41,
#   'SOG': 67,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 39,
#   'Hits': 133,
#   'SHG': 3,
#   'SHA': 2},
#  {'player_id': '8475314',
#   'Player Name': 'Anders Lee',
#   'Team': 'NYI',
#   'Position': 'LW',
#   'Games': 68,
#   'G': 20,
#   'A': 23,
#   'Points': 43,
#   '+/-': 8,
#   'PIM': 47,
#   'SOG': 195,
#   'GWG': 6,
#   'PPG': 2,
#   'PPA': 5,
#   'PPP': 7,
#   'BS': 50,
#   'Hits': 102,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475754',
#   'Player Name': 'Brock Nelson',
#   'Team': 'NYI',
#   'Position': 'C',
#   'Games': 68,
#   'G': 26,
#   'A': 28,
#   'Points': 54,
#   '+/-': 6,
#   'PIM': 32,
#   'SOG': 175,
#   'GWG': 5,
#   'PPG': 4,
#   'PPA': 3,
#   'PPP': 7,
#   'BS': 44,
#   'Hits': 49,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476419',
#   'Player Name': 'Jean-Gabriel Pageau',
#   'Team': 'NYI',
#   'Position': 'C',
#   'Games': 67,
#   'G': 26,
#   'A': 16,
#   'Points': 42,
#   '+/-': 4,
#   'PIM': 49,
#   'SOG': 151,
#   'GWG': 5,
#   'PPG': 5,
#   'PPA': 5,
#   'PPP': 10,
#   'BS': 53,
#   'Hits': 128,
#   'SHG': 3,
#   'SHA': 3},
#  {'player_id': '8476429',
#   'Player Name': 'Scott Mayfield',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 67,
#   'G': 5,
#   'A': 8,
#   'Points': 13,
#   '+/-': 8,
#   'PIM': 53,
#   'SOG': 98,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 117,
#   'Hits': 93,
#   'SHG': 0,
#   'SHA': 2},
#  {'player_id': '8476917',
#   'Player Name': 'Adam Pelech',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 38,
#   'G': 1,
#   'A': 8,
#   'Points': 9,
#   '+/-': 4,
#   'PIM': 20,
#   'SOG': 49,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 83,
#   'Hits': 81,
#   'SHG': 0,
#   'SHA': 2},
#  {'player_id': '8477506',
#   'Player Name': 'Ryan Pulock',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 68,
#   'G': 10,
#   'A': 25,
#   'Points': 35,
#   '+/-': 8,
#   'PIM': 14,
#   'SOG': 163,
#   'GWG': 3,
#   'PPG': 3,
#   'PPA': 5,
#   'PPP': 8,
#   'BS': 139,
#   'Hits': 110,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477527',
#   'Player Name': 'Ross Johnston',
#   'Team': 'NYI',
#   'Position': 'LW',
#   'Games': 32,
#   'G': 3,
#   'A': 1,
#   'Points': 4,
#   '+/-': 1,
#   'PIM': 78,
#   'SOG': 16,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 14,
#   'Hits': 93,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477936',
#   'Player Name': 'Michael Dal Colle',
#   'Team': 'NYI',
#   'Position': 'LW',
#   'Games': 53,
#   'G': 4,
#   'A': 6,
#   'Points': 10,
#   '+/-': -8,
#   'PIM': 12,
#   'SOG': 59,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 21,
#   'Hits': 81,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478445',
#   'Player Name': 'Mathew Barzal',
#   'Team': 'NYI',
#   'Position': 'C',
#   'Games': 68,
#   'G': 19,
#   'A': 41,
#   'Points': 60,
#   '+/-': 5,
#   'PIM': 44,
#   'SOG': 171,
#   'GWG': 2,
#   'PPG': 4,
#   'PPA': 8,
#   'PPP': 12,
#   'BS': 43,
#   'Hits': 22,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480222',
#   'Player Name': 'Sebastian Aho',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480865',
#   'Player Name': 'Noah Dobson',
#   'Team': 'NYI',
#   'Position': 'D',
#   'Games': 34,
#   'G': 1,
#   'A': 6,
#   'Points': 7,
#   '+/-': -1,
#   'PIM': 8,
#   'SOG': 37,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 31,
#   'Hits': 25,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480078',
#   'Player Name': 'Filip Chytil',
#   'Team': 'NYR',
#   'Position': 'C',
#   'Games': 60,
#   'G': 14,
#   'A': 9,
#   'Points': 23,
#   '+/-': -7,
#   'PIM': 10,
#   'SOG': 114,
#   'GWG': 2,
#   'PPG': 1,
#   'PPA': 2,
#   'PPP': 3,
#   'BS': 31,
#   'Hits': 13,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8471677',
#   'Player Name': 'Jack Johnson',
#   'Team': 'NYR',
#   'Position': 'D',
#   'Games': 67,
#   'G': 3,
#   'A': 8,
#   'Points': 11,
#   '+/-': -1,
#   'PIM': 26,
#   'SOG': 63,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 97,
#   'Hits': 183,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8474090',
#   'Player Name': 'Brendan Smith',
#   'Team': 'NYR',
#   'Position': 'D',
#   'Games': 62,
#   'G': 3,
#   'A': 5,
#   'Points': 8,
#   '+/-': -12,
#   'PIM': 71,
#   'SOG': 45,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 41,
#   'Hits': 90,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8475184',
#   'Player Name': 'Chris Kreider',
#   'Team': 'NYR',
#   'Position': 'LW',
#   'Games': 63,
#   'G': 24,
#   'A': 21,
#   'Points': 45,
#   '+/-': 13,
#   'PIM': 58,
#   'SOG': 156,
#   'GWG': 5,
#   'PPG': 9,
#   'PPA': 4,
#   'PPP': 13,
#   'BS': 42,
#   'Hits': 116,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475868',
#   'Player Name': 'Anthony Bitetto',
#   'Team': 'NYR',
#   'Position': 'D',
#   'Games': 51,
#   'G': 0,
#   'A': 8,
#   'Points': 8,
#   '+/-': 3,
#   'PIM': 32,
#   'SOG': 54,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 50,
#   'Hits': 145,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8476278',
#   'Player Name': 'Colin Blackwell',
#   'Team': 'NYR',
#   'Position': 'C',
#   'Games': 27,
#   'G': 3,
#   'A': 7,
#   'Points': 10,
#   '+/-': 7,
#   'PIM': 10,
#   'SOG': 31,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 23,
#   'Hits': 43,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476458',
#   'Player Name': 'Ryan Strome',
#   'Team': 'NYR',
#   'Position': 'C',
#   'Games': 70,
#   'G': 18,
#   'A': 41,
#   'Points': 59,
#   '+/-': 21,
#   'PIM': 48,
#   'SOG': 154,
#   'GWG': 3,
#   'PPG': 3,
#   'PPA': 14,
#   'PPP': 17,
#   'BS': 32,
#   'Hits': 45,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8476459',
#   'Player Name': 'Mika Zibanejad',
#   'Team': 'NYR',
#   'Position': 'C',
#   'Games': 57,
#   'G': 41,
#   'A': 34,
#   'Points': 75,
#   '+/-': 9,
#   'PIM': 14,
#   'SOG': 208,
#   'GWG': 6,
#   'PPG': 15,
#   'PPA': 12,
#   'PPP': 27,
#   'BS': 49,
#   'Hits': 51,
#   'SHG': 3,
#   'SHA': 2},
#  {'player_id': '8476858',
#   'Player Name': 'Phillip Di Giuseppe',
#   'Team': 'NYR',
#   'Position': 'LW',
#   'Games': 20,
#   'G': 1,
#   'A': 3,
#   'Points': 4,
#   '+/-': 1,
#   'PIM': 2,
#   'SOG': 35,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 20,
#   'Hits': 38,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476885',
#   'Player Name': 'Jacob Trouba',
#   'Team': 'NYR',
#   'Position': 'D',
#   'Games': 70,
#   'G': 7,
#   'A': 20,
#   'Points': 27,
#   '+/-': -12,
#   'PIM': 61,
#   'SOG': 168,
#   'GWG': 1,
#   'PPG': 4,
#   'PPA': 4,
#   'PPP': 8,
#   'BS': 128,
#   'Hits': 173,
#   'SHG': 0,
#   'SHA': 2},
#  {'player_id': '8477402',
#   'Player Name': 'Pavel Buchnevich',
#   'Team': 'NYR',
#   'Position': 'RW',
#   'Games': 68,
#   'G': 16,
#   'A': 30,
#   'Points': 46,
#   '+/-': 2,
#   'PIM': 24,
#   'SOG': 148,
#   'GWG': 1,
#   'PPG': 4,
#   'PPA': 5,
#   'PPP': 9,
#   'BS': 22,
#   'Hits': 80,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477962',
#   'Player Name': 'Brendan Lemieux',
#   'Team': 'NYR',
#   'Position': 'LW',
#   'Games': 59,
#   'G': 6,
#   'A': 12,
#   'Points': 18,
#   '+/-': -14,
#   'PIM': 111,
#   'SOG': 86,
#   'GWG': 0,
#   'PPG': 2,
#   'PPA': 3,
#   'PPP': 5,
#   'BS': 52,
#   'Hits': 164,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8478550',
#   'Player Name': 'Artemi Panarin',
#   'Team': 'NYR',
#   'Position': 'LW',
#   'Games': 69,
#   'G': 32,
#   'A': 63,
#   'Points': 95,
#   '+/-': 36,
#   'PIM': 20,
#   'SOG': 209,
#   'GWG': 4,
#   'PPG': 7,
#   'PPA': 17,
#   'PPP': 24,
#   'BS': 18,
#   'Hits': 25,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479291',
#   'Player Name': 'Kevin Rooney',
#   'Team': 'NYR',
#   'Position': 'C',
#   'Games': 49,
#   'G': 4,
#   'A': 5,
#   'Points': 9,
#   '+/-': 8,
#   'PIM': 20,
#   'SOG': 59,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 32,
#   'Hits': 64,
#   'SHG': 2,
#   'SHA': 1},
#  {'player_id': '8479323',
#   'Player Name': 'Adam Fox',
#   'Team': 'NYR',
#   'Position': 'D',
#   'Games': 70,
#   'G': 8,
#   'A': 34,
#   'Points': 42,
#   '+/-': 22,
#   'PIM': 32,
#   'SOG': 125,
#   'GWG': 4,
#   'PPG': 1,
#   'PPA': 12,
#   'PPP': 13,
#   'BS': 92,
#   'Hits': 35,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479324',
#   'Player Name': 'Ryan Lindgren',
#   'Team': 'NYR',
#   'Position': 'D',
#   'Games': 60,
#   'G': 1,
#   'A': 13,
#   'Points': 14,
#   '+/-': 16,
#   'PIM': 47,
#   'SOG': 47,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 70,
#   'Hits': 94,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479328',
#   'Player Name': 'Julien Gauthier',
#   'Team': 'NYR',
#   'Position': 'RW',
#   'Games': 17,
#   'G': 0,
#   'A': 3,
#   'Points': 3,
#   '+/-': 1,
#   'PIM': 8,
#   'SOG': 10,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 7,
#   'Hits': 15,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479353',
#   'Player Name': 'Brett Howden',
#   'Team': 'NYR',
#   'Position': 'C',
#   'Games': 70,
#   'G': 9,
#   'A': 10,
#   'Points': 19,
#   '+/-': -11,
#   'PIM': 28,
#   'SOG': 64,
#   'GWG': 2,
#   'PPG': 1,
#   'PPA': 1,
#   'PPP': 2,
#   'BS': 67,
#   'Hits': 69,
#   'SHG': 0,
#   'SHA': 2},
#  {'player_id': '8482109',
#   'Player Name': 'Alexis Lafrenière',
#   'Team': 'NYR',
#   'Position': 'LW',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480028',
#   'Player Name': 'Morgan Frost',
#   'Team': 'PHI',
#   'Position': 'C',
#   'Games': 20,
#   'G': 2,
#   'A': 5,
#   'Points': 7,
#   '+/-': -3,
#   'PIM': 4,
#   'SOG': 31,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 4,
#   'Hits': 4,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8473512',
#   'Player Name': 'Claude Giroux',
#   'Team': 'PHI',
#   'Position': 'C',
#   'Games': 69,
#   'G': 21,
#   'A': 32,
#   'Points': 53,
#   '+/-': 7,
#   'PIM': 28,
#   'SOG': 197,
#   'GWG': 6,
#   'PPG': 7,
#   'PPA': 13,
#   'PPP': 20,
#   'BS': 16,
#   'Hits': 45,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8474027',
#   'Player Name': 'Justin Braun',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 62,
#   'G': 3,
#   'A': 16,
#   'Points': 19,
#   '+/-': -2,
#   'PIM': 18,
#   'SOG': 70,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 84,
#   'Hits': 91,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474037',
#   'Player Name': 'James van Riemsdyk',
#   'Team': 'PHI',
#   'Position': 'LW',
#   'Games': 66,
#   'G': 19,
#   'A': 21,
#   'Points': 40,
#   '+/-': 5,
#   'PIM': 8,
#   'SOG': 151,
#   'GWG': 2,
#   'PPG': 4,
#   'PPA': 5,
#   'PPP': 9,
#   'BS': 18,
#   'Hits': 25,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474161',
#   'Player Name': 'Jakub Voracek',
#   'Team': 'PHI',
#   'Position': 'RW',
#   'Games': 69,
#   'G': 12,
#   'A': 44,
#   'Points': 56,
#   '+/-': 14,
#   'PIM': 31,
#   'SOG': 132,
#   'GWG': 3,
#   'PPG': 4,
#   'PPA': 13,
#   'PPP': 17,
#   'BS': 21,
#   'Hits': 17,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475763',
#   'Player Name': 'Kevin Hayes',
#   'Team': 'PHI',
#   'Position': 'C',
#   'Games': 69,
#   'G': 23,
#   'A': 18,
#   'Points': 41,
#   '+/-': -6,
#   'PIM': 34,
#   'SOG': 175,
#   'GWG': 5,
#   'PPG': 4,
#   'PPA': 3,
#   'PPP': 7,
#   'BS': 22,
#   'Hits': 88,
#   'SHG': 4,
#   'SHA': 0},
#  {'player_id': '8476461',
#   'Player Name': 'Sean Couturier',
#   'Team': 'PHI',
#   'Position': 'C',
#   'Games': 69,
#   'G': 22,
#   'A': 37,
#   'Points': 59,
#   '+/-': 21,
#   'PIM': 30,
#   'SOG': 185,
#   'GWG': 4,
#   'PPG': 4,
#   'PPA': 9,
#   'PPP': 13,
#   'BS': 26,
#   'Hits': 60,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476872',
#   'Player Name': 'Scott Laughton',
#   'Team': 'PHI',
#   'Position': 'C',
#   'Games': 49,
#   'G': 13,
#   'A': 14,
#   'Points': 27,
#   '+/-': 13,
#   'PIM': 26,
#   'SOG': 74,
#   'GWG': 2,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 26,
#   'Hits': 109,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476906',
#   'Player Name': 'Shayne Gostisbehere',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 42,
#   'G': 5,
#   'A': 7,
#   'Points': 12,
#   '+/-': -4,
#   'PIM': 20,
#   'SOG': 73,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 4,
#   'PPP': 5,
#   'BS': 37,
#   'Hits': 14,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476979',
#   'Player Name': 'Erik Gustafsson',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 66,
#   'G': 6,
#   'A': 23,
#   'Points': 29,
#   '+/-': -9,
#   'PIM': 27,
#   'SOG': 103,
#   'GWG': 0,
#   'PPG': 2,
#   'PPA': 7,
#   'PPP': 9,
#   'BS': 58,
#   'Hits': 86,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477290',
#   'Player Name': 'Michael Raffl',
#   'Team': 'PHI',
#   'Position': 'LW',
#   'Games': 58,
#   'G': 8,
#   'A': 12,
#   'Points': 20,
#   '+/-': -2,
#   'PIM': 14,
#   'SOG': 66,
#   'GWG': 2,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 25,
#   'Hits': 73,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8477462',
#   'Player Name': 'Robert Hagg',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 49,
#   'G': 3,
#   'A': 10,
#   'Points': 13,
#   '+/-': 14,
#   'PIM': 30,
#   'SOG': 38,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 79,
#   'Hits': 136,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477948',
#   'Player Name': 'Travis Sanheim',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 69,
#   'G': 8,
#   'A': 17,
#   'Points': 25,
#   '+/-': 4,
#   'PIM': 32,
#   'SOG': 110,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 4,
#   'PPP': 4,
#   'BS': 79,
#   'Hits': 41,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477979',
#   'Player Name': 'Nicolas Aube-Kubel',
#   'Team': 'PHI',
#   'Position': 'RW',
#   'Games': 36,
#   'G': 7,
#   'A': 8,
#   'Points': 15,
#   '+/-': 1,
#   'PIM': 19,
#   'SOG': 48,
#   'GWG': 1,
#   'PPG': 2,
#   'PPA': 1,
#   'PPP': 3,
#   'BS': 16,
#   'Hits': 82,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478017',
#   'Player Name': 'Mark Friedman',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 6,
#   'G': 0,
#   'A': 1,
#   'Points': 1,
#   '+/-': 0,
#   'PIM': 2,
#   'SOG': 2,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 5,
#   'Hits': 8,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478067',
#   'Player Name': 'Oskar Lindblom',
#   'Team': 'PHI',
#   'Position': 'LW',
#   'Games': 30,
#   'G': 11,
#   'A': 7,
#   'Points': 18,
#   '+/-': 4,
#   'PIM': 4,
#   'SOG': 72,
#   'GWG': 0,
#   'PPG': 3,
#   'PPA': 1,
#   'PPP': 4,
#   'BS': 16,
#   'Hits': 31,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478439',
#   'Player Name': 'Travis Konecny',
#   'Team': 'PHI',
#   'Position': 'RW',
#   'Games': 66,
#   'G': 24,
#   'A': 37,
#   'Points': 61,
#   '+/-': -1,
#   'PIM': 28,
#   'SOG': 141,
#   'GWG': 3,
#   'PPG': 5,
#   'PPA': 18,
#   'PPP': 23,
#   'BS': 30,
#   'Hits': 63,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478500',
#   'Player Name': 'Ivan Provorov',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 69,
#   'G': 13,
#   'A': 23,
#   'Points': 36,
#   '+/-': 11,
#   'PIM': 24,
#   'SOG': 150,
#   'GWG': 3,
#   'PPG': 7,
#   'PPA': 9,
#   'PPP': 16,
#   'BS': 111,
#   'Hits': 84,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8479026',
#   'Player Name': 'Philippe Myers',
#   'Team': 'PHI',
#   'Position': 'D',
#   'Games': 50,
#   'G': 4,
#   'A': 12,
#   'Points': 16,
#   '+/-': 17,
#   'PIM': 30,
#   'SOG': 78,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 44,
#   'Hits': 80,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479974',
#   'Player Name': 'Nolan Patrick',
#   'Team': 'PHI',
#   'Position': 'C',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480797',
#   'Player Name': 'Joel Farabee',
#   'Team': 'PHI',
#   'Position': 'LW',
#   'Games': 52,
#   'G': 8,
#   'A': 13,
#   'Points': 21,
#   '+/-': 6,
#   'PIM': 39,
#   'SOG': 81,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 1,
#   'PPP': 2,
#   'BS': 18,
#   'Hits': 31,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475208',
#   'Player Name': 'Brian Dumoulin',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 28,
#   'G': 1,
#   'A': 7,
#   'Points': 8,
#   '+/-': 17,
#   'PIM': 10,
#   'SOG': 35,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 35,
#   'Hits': 44,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8477969',
#   'Player Name': 'Marcus Pettersson',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 69,
#   'G': 2,
#   'A': 20,
#   'Points': 22,
#   '+/-': 9,
#   'PIM': 35,
#   'SOG': 79,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 2,
#   'PPP': 2,
#   'BS': 84,
#   'Hits': 106,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478542',
#   'Player Name': 'Evan Rodrigues',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 45,
#   'G': 6,
#   'A': 4,
#   'Points': 10,
#   '+/-': -8,
#   'PIM': 14,
#   'SOG': 75,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 15,
#   'Hits': 24,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480945',
#   'Player Name': 'Juuso Riikola',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 36,
#   'G': 1,
#   'A': 6,
#   'Points': 7,
#   '+/-': 3,
#   'PIM': 6,
#   'SOG': 38,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 2,
#   'PPP': 2,
#   'BS': 24,
#   'Hits': 74,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477814',
#   'Player Name': 'Kevin Czuczman',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477919',
#   'Player Name': 'Frederick Gaudreau',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478074',
#   'Player Name': 'Anthony Angello',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 8,
#   'G': 1,
#   'A': 0,
#   'Points': 1,
#   '+/-': -1,
#   'PIM': 4,
#   'SOG': 5,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 5,
#   'Hits': 13,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8471215',
#   'Player Name': 'Evgeni Malkin',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 55,
#   'G': 25,
#   'A': 49,
#   'Points': 74,
#   '+/-': 7,
#   'PIM': 58,
#   'SOG': 171,
#   'GWG': 5,
#   'PPG': 7,
#   'PPA': 17,
#   'PPP': 24,
#   'BS': 22,
#   'Hits': 38,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8471675',
#   'Player Name': 'Sidney Crosby',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 41,
#   'G': 16,
#   'A': 31,
#   'Points': 47,
#   '+/-': -8,
#   'PIM': 15,
#   'SOG': 109,
#   'GWG': 4,
#   'PPG': 4,
#   'PPA': 13,
#   'PPP': 17,
#   'BS': 17,
#   'Hits': 28,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8471724',
#   'Player Name': 'Kris Letang',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 61,
#   'G': 15,
#   'A': 29,
#   'Points': 44,
#   '+/-': 0,
#   'PIM': 38,
#   'SOG': 177,
#   'GWG': 2,
#   'PPG': 6,
#   'PPA': 9,
#   'PPP': 15,
#   'BS': 91,
#   'Hits': 101,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474098',
#   'Player Name': 'Colton Sceviour',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 69,
#   'G': 6,
#   'A': 10,
#   'Points': 16,
#   '+/-': 2,
#   'PIM': 6,
#   'SOG': 114,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 72,
#   'Hits': 91,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474134',
#   'Player Name': 'Yannick Weber',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 41,
#   'G': 1,
#   'A': 2,
#   'Points': 3,
#   '+/-': -1,
#   'PIM': 14,
#   'SOG': 45,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 38,
#   'Hits': 37,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475722',
#   'Player Name': 'Jason Zucker',
#   'Team': 'PIT',
#   'Position': 'LW',
#   'Games': 60,
#   'G': 20,
#   'A': 21,
#   'Points': 41,
#   '+/-': -4,
#   'PIM': 21,
#   'SOG': 111,
#   'GWG': 4,
#   'PPG': 7,
#   'PPA': 5,
#   'PPP': 12,
#   'BS': 23,
#   'Hits': 53,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475810',
#   'Player Name': 'Bryan Rust',
#   'Team': 'PIT',
#   'Position': 'RW',
#   'Games': 55,
#   'G': 27,
#   'A': 29,
#   'Points': 56,
#   '+/-': 14,
#   'PIM': 30,
#   'SOG': 151,
#   'GWG': 4,
#   'PPG': 8,
#   'PPA': 9,
#   'PPP': 17,
#   'BS': 35,
#   'Hits': 71,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8476873',
#   'Player Name': 'Mark Jankowski',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 56,
#   'G': 5,
#   'A': 2,
#   'Points': 7,
#   '+/-': -12,
#   'PIM': 14,
#   'SOG': 38,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 33,
#   'Hits': 14,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476875',
#   'Player Name': 'Mike Matheson',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 59,
#   'G': 8,
#   'A': 12,
#   'Points': 20,
#   '+/-': -1,
#   'PIM': 14,
#   'SOG': 104,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 1,
#   'PPP': 2,
#   'BS': 53,
#   'Hits': 44,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476879',
#   'Player Name': 'Cody Ceci',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 56,
#   'G': 1,
#   'A': 7,
#   'Points': 8,
#   '+/-': 7,
#   'PIM': 20,
#   'SOG': 48,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 79,
#   'Hits': 92,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476927',
#   'Player Name': 'Teddy Blueger',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 69,
#   'G': 9,
#   'A': 13,
#   'Points': 22,
#   '+/-': 2,
#   'PIM': 25,
#   'SOG': 102,
#   'GWG': 2,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 35,
#   'Hits': 83,
#   'SHG': 0,
#   'SHA': 2},
#  {'player_id': '8477244',
#   'Player Name': 'Chad Ruhwedel',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 41,
#   'G': 2,
#   'A': 4,
#   'Points': 6,
#   '+/-': 4,
#   'PIM': 12,
#   'SOG': 44,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 25,
#   'Hits': 74,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477404',
#   'Player Name': 'Jake Guentzel',
#   'Team': 'PIT',
#   'Position': 'LW',
#   'Games': 39,
#   'G': 20,
#   'A': 23,
#   'Points': 43,
#   '+/-': 11,
#   'PIM': 14,
#   'SOG': 127,
#   'GWG': 4,
#   'PPG': 6,
#   'PPA': 4,
#   'PPP': 10,
#   'BS': 19,
#   'Hits': 46,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477953',
#   'Player Name': 'Kasperi Kapanen',
#   'Team': 'PIT',
#   'Position': 'RW',
#   'Games': 69,
#   'G': 13,
#   'A': 23,
#   'Points': 36,
#   '+/-': 0,
#   'PIM': 22,
#   'SOG': 121,
#   'GWG': 2,
#   'PPG': 0,
#   'PPA': 3,
#   'PPP': 3,
#   'BS': 17,
#   'Hits': 73,
#   'SHG': 2,
#   'SHA': 0},
#  {'player_id': '8477955',
#   'Player Name': 'Jared McCann',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 66,
#   'G': 14,
#   'A': 21,
#   'Points': 35,
#   '+/-': 6,
#   'PIM': 17,
#   'SOG': 150,
#   'GWG': 4,
#   'PPG': 2,
#   'PPA': 4,
#   'PPP': 6,
#   'BS': 27,
#   'Hits': 89,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478043',
#   'Player Name': 'Sam Lafferty',
#   'Team': 'PIT',
#   'Position': 'C',
#   'Games': 50,
#   'G': 6,
#   'A': 7,
#   'Points': 13,
#   '+/-': 5,
#   'PIM': 23,
#   'SOG': 56,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 17,
#   'Hits': 95,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478507',
#   'Player Name': 'John Marino',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 56,
#   'G': 6,
#   'A': 20,
#   'Points': 26,
#   '+/-': 17,
#   'PIM': 20,
#   'SOG': 61,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 3,
#   'PPP': 4,
#   'BS': 77,
#   'Hits': 72,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479293',
#   'Player Name': 'Brandon Tanev',
#   'Team': 'PIT',
#   'Position': 'LW',
#   'Games': 68,
#   'G': 11,
#   'A': 14,
#   'Points': 25,
#   '+/-': -1,
#   'PIM': 16,
#   'SOG': 95,
#   'GWG': 4,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 65,
#   'Hits': 244,
#   'SHG': 2,
#   'SHA': 1},
#  {'player_id': '8480058',
#   'Player Name': 'Pierre-Olivier Joseph',
#   'Team': 'PIT',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8482055',
#   'Player Name': "Drew O'Connor",
#   'Team': 'PIT',
#   'Position': 'LW',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478131',
#   'Player Name': 'Ondrej Kase',
#   'Team': 'BOS',
#   'Position': 'RW',
#   'Games': 55,
#   'G': 7,
#   'A': 17,
#   'Points': 24,
#   '+/-': -7,
#   'PIM': 14,
#   'SOG': 144,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 2,
#   'PPP': 2,
#   'BS': 17,
#   'Hits': 13,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8478498',
#   'Player Name': 'Jake DeBrusk',
#   'Team': 'BOS',
#   'Position': 'LW',
#   'Games': 65,
#   'G': 19,
#   'A': 16,
#   'Points': 35,
#   '+/-': -1,
#   'PIM': 14,
#   'SOG': 161,
#   'GWG': 5,
#   'PPG': 7,
#   'PPA': 3,
#   'PPP': 10,
#   'BS': 15,
#   'Hits': 35,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480021',
#   'Player Name': 'Jack Studnicka',
#   'Team': 'BOS',
#   'Position': 'C',
#   'Games': 2,
#   'G': 0,
#   'A': 1,
#   'Points': 1,
#   '+/-': 2,
#   'PIM': 2,
#   'SOG': 3,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 2,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8470638',
#   'Player Name': 'Patrice Bergeron',
#   'Team': 'BOS',
#   'Position': 'C',
#   'Games': 61,
#   'G': 31,
#   'A': 25,
#   'Points': 56,
#   '+/-': 23,
#   'PIM': 28,
#   'SOG': 203,
#   'GWG': 5,
#   'PPG': 11,
#   'PPA': 9,
#   'PPP': 20,
#   'BS': 46,
#   'Hits': 46,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8471276',
#   'Player Name': 'David Krejci',
#   'Team': 'BOS',
#   'Position': 'C',
#   'Games': 61,
#   'G': 13,
#   'A': 30,
#   'Points': 43,
#   '+/-': 14,
#   'PIM': 23,
#   'SOG': 83,
#   'GWG': 3,
#   'PPG': 3,
#   'PPA': 11,
#   'PPP': 14,
#   'BS': 32,
#   'Hits': 37,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8473419',
#   'Player Name': 'Brad Marchand',
#   'Team': 'BOS',
#   'Position': 'LW',
#   'Games': 70,
#   'G': 28,
#   'A': 59,
#   'Points': 87,
#   '+/-': 25,
#   'PIM': 82,
#   'SOG': 185,
#   'GWG': 5,
#   'PPG': 5,
#   'PPA': 23,
#   'PPP': 28,
#   'BS': 19,
#   'Hits': 55,
#   'SHG': 1,
#   'SHA': 2},
#  {'player_id': '8475186',
#   'Player Name': 'John Moore',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 24,
#   'G': 2,
#   'A': 1,
#   'Points': 3,
#   '+/-': -2,
#   'PIM': 11,
#   'SOG': 33,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 27,
#   'Hits': 36,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475225',
#   'Player Name': 'Craig Smith',
#   'Team': 'BOS',
#   'Position': 'C',
#   'Games': 69,
#   'G': 18,
#   'A': 13,
#   'Points': 31,
#   '+/-': 18,
#   'PIM': 34,
#   'SOG': 184,
#   'GWG': 2,
#   'PPG': 4,
#   'PPA': 3,
#   'PPP': 7,
#   'BS': 19,
#   'Hits': 60,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475745',
#   'Player Name': 'Charlie Coyle',
#   'Team': 'BOS',
#   'Position': 'C',
#   'Games': 70,
#   'G': 16,
#   'A': 21,
#   'Points': 37,
#   '+/-': 9,
#   'PIM': 21,
#   'SOG': 145,
#   'GWG': 3,
#   'PPG': 1,
#   'PPA': 4,
#   'PPP': 5,
#   'BS': 34,
#   'Hits': 83,
#   'SHG': 2,
#   'SHA': 0},
#  {'player_id': '8475780',
#   'Player Name': 'Chris Wagner',
#   'Team': 'BOS',
#   'Position': 'RW',
#   'Games': 67,
#   'G': 6,
#   'A': 4,
#   'Points': 10,
#   '+/-': -8,
#   'PIM': 47,
#   'SOG': 78,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 31,
#   'Hits': 192,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8476191',
#   'Player Name': 'Kevan Miller',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476374',
#   'Player Name': 'Sean Kuraly',
#   'Team': 'BOS',
#   'Position': 'C',
#   'Games': 69,
#   'G': 6,
#   'A': 17,
#   'Points': 23,
#   '+/-': -2,
#   'PIM': 34,
#   'SOG': 95,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 31,
#   'Hits': 145,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8476891',
#   'Player Name': 'Matt Grzelcyk',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 68,
#   'G': 4,
#   'A': 17,
#   'Points': 21,
#   '+/-': 15,
#   'PIM': 34,
#   'SOG': 112,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 6,
#   'PPP': 7,
#   'BS': 67,
#   'Hits': 56,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8477365',
#   'Player Name': 'Connor Clifton',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 31,
#   'G': 2,
#   'A': 0,
#   'Points': 2,
#   '+/-': 4,
#   'PIM': 12,
#   'SOG': 20,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 33,
#   'Hits': 90,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477941',
#   'Player Name': 'Nick Ritchie',
#   'Team': 'BOS',
#   'Position': 'LW',
#   'Games': 48,
#   'G': 9,
#   'A': 12,
#   'Points': 21,
#   '+/-': 1,
#   'PIM': 97,
#   'SOG': 78,
#   'GWG': 2,
#   'PPG': 2,
#   'PPA': 1,
#   'PPP': 3,
#   'BS': 17,
#   'Hits': 102,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477956',
#   'Player Name': 'David Pastrnak',
#   'Team': 'BOS',
#   'Position': 'RW',
#   'Games': 70,
#   'G': 48,
#   'A': 47,
#   'Points': 95,
#   '+/-': 21,
#   'PIM': 40,
#   'SOG': 279,
#   'GWG': 10,
#   'PPG': 20,
#   'PPA': 18,
#   'PPP': 38,
#   'BS': 22,
#   'Hits': 47,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478075',
#   'Player Name': 'Anders Bjork',
#   'Team': 'BOS',
#   'Position': 'LW',
#   'Games': 58,
#   'G': 9,
#   'A': 10,
#   'Points': 19,
#   '+/-': 5,
#   'PIM': 10,
#   'SOG': 66,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 21,
#   'Hits': 43,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478415',
#   'Player Name': 'Jakub Zboril',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478443',
#   'Player Name': 'Brandon Carlo',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 67,
#   'G': 4,
#   'A': 15,
#   'Points': 19,
#   '+/-': 16,
#   'PIM': 33,
#   'SOG': 111,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 76,
#   'Hits': 126,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478468',
#   'Player Name': 'Jeremy Lauzon',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 19,
#   'G': 1,
#   'A': 1,
#   'Points': 2,
#   '+/-': 5,
#   'PIM': 29,
#   'SOG': 20,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 23,
#   'Hits': 32,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479325',
#   'Player Name': 'Charlie McAvoy',
#   'Team': 'BOS',
#   'Position': 'D',
#   'Games': 67,
#   'G': 5,
#   'A': 27,
#   'Points': 32,
#   '+/-': 24,
#   'PIM': 41,
#   'SOG': 101,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 1,
#   'PPP': 2,
#   'BS': 131,
#   'Hits': 131,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8479365',
#   'Player Name': 'Trent Frederic',
#   'Team': 'BOS',
#   'Position': 'C',
#   'Games': 2,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': -1,
#   'PIM': 0,
#   'SOG': 1,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 8,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476878',
#   'Player Name': 'Zemgus Girgensons',
#   'Team': 'BUF',
#   'Position': 'LW',
#   'Games': 69,
#   'G': 12,
#   'A': 7,
#   'Points': 19,
#   '+/-': -1,
#   'PIM': 10,
#   'SOG': 85,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 20,
#   'Hits': 110,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8475869',
#   'Player Name': 'Brandon Davidson',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 12,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': -3,
#   'PIM': 0,
#   'SOG': 17,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 20,
#   'Hits': 24,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477520',
#   'Player Name': 'Jean-Sebastien Dea',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 3,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 3,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478840',
#   'Player Name': 'William Borgen',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480083',
#   'Player Name': 'C.J. Smith',
#   'Team': 'BUF',
#   'Position': 'LW',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8470595',
#   'Player Name': 'Eric Staal',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 66,
#   'G': 19,
#   'A': 28,
#   'Points': 47,
#   '+/-': -9,
#   'PIM': 28,
#   'SOG': 113,
#   'GWG': 5,
#   'PPG': 5,
#   'PPA': 9,
#   'PPP': 14,
#   'BS': 22,
#   'Hits': 24,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8473449',
#   'Player Name': 'Kyle Okposo',
#   'Team': 'BUF',
#   'Position': 'RW',
#   'Games': 52,
#   'G': 9,
#   'A': 10,
#   'Points': 19,
#   '+/-': -3,
#   'PIM': 28,
#   'SOG': 82,
#   'GWG': 2,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 15,
#   'Hits': 55,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475236',
#   'Player Name': 'Cody Eakin',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 49,
#   'G': 5,
#   'A': 10,
#   'Points': 15,
#   '+/-': -3,
#   'PIM': 16,
#   'SOG': 61,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 1,
#   'PPP': 1,
#   'BS': 16,
#   'Hits': 49,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475625',
#   'Player Name': 'Matt Irwin',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 36,
#   'G': 0,
#   'A': 3,
#   'Points': 3,
#   '+/-': -15,
#   'PIM': 15,
#   'SOG': 58,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 54,
#   'Hits': 80,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475772',
#   'Player Name': 'Riley Sheahan',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 66,
#   'G': 8,
#   'A': 7,
#   'Points': 15,
#   '+/-': -13,
#   'PIM': 6,
#   'SOG': 70,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 33,
#   'Hits': 26,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8475784',
#   'Player Name': 'Jeff Skinner',
#   'Team': 'BUF',
#   'Position': 'LW',
#   'Games': 59,
#   'G': 14,
#   'A': 9,
#   'Points': 23,
#   '+/-': -22,
#   'PIM': 18,
#   'SOG': 183,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 3,
#   'PPP': 3,
#   'BS': 11,
#   'Hits': 29,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475791',
#   'Player Name': 'Taylor Hall',
#   'Team': 'BUF',
#   'Position': 'LW',
#   'Games': 65,
#   'G': 16,
#   'A': 36,
#   'Points': 52,
#   '+/-': -14,
#   'PIM': 34,
#   'SOG': 232,
#   'GWG': 1,
#   'PPG': 4,
#   'PPA': 14,
#   'PPP': 18,
#   'BS': 29,
#   'Hits': 47,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476356',
#   'Player Name': 'Tobias Rieder',
#   'Team': 'BUF',
#   'Position': 'LW',
#   'Games': 55,
#   'G': 4,
#   'A': 6,
#   'Points': 10,
#   '+/-': -12,
#   'PIM': 6,
#   'SOG': 77,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 26,
#   'Hits': 30,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8476525',
#   'Player Name': 'Colin Miller',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 51,
#   'G': 1,
#   'A': 10,
#   'Points': 11,
#   '+/-': -9,
#   'PIM': 22,
#   'SOG': 79,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 3,
#   'PPP': 3,
#   'BS': 40,
#   'Hits': 87,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476931',
#   'Player Name': 'Jake McCabe',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 66,
#   'G': 3,
#   'A': 10,
#   'Points': 13,
#   '+/-': -11,
#   'PIM': 41,
#   'SOG': 75,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 90,
#   'Hits': 91,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8477499',
#   'Player Name': 'Rasmus Ristolainen',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 69,
#   'G': 6,
#   'A': 27,
#   'Points': 33,
#   '+/-': -2,
#   'PIM': 46,
#   'SOG': 128,
#   'GWG': 0,
#   'PPG': 2,
#   'PPA': 7,
#   'PPP': 9,
#   'BS': 82,
#   'Hits': 203,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8477508',
#   'Player Name': 'Curtis Lazar',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 38,
#   'G': 5,
#   'A': 5,
#   'Points': 10,
#   '+/-': -3,
#   'PIM': 9,
#   'SOG': 33,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 24,
#   'Hits': 70,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8477933',
#   'Player Name': 'Sam Reinhart',
#   'Team': 'BUF',
#   'Position': 'RW',
#   'Games': 69,
#   'G': 22,
#   'A': 28,
#   'Points': 50,
#   '+/-': -15,
#   'PIM': 20,
#   'SOG': 144,
#   'GWG': 2,
#   'PPG': 5,
#   'PPA': 7,
#   'PPP': 12,
#   'BS': 27,
#   'Hits': 36,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477986',
#   'Player Name': 'Brandon Montour',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 54,
#   'G': 5,
#   'A': 13,
#   'Points': 18,
#   '+/-': 13,
#   'PIM': 28,
#   'SOG': 86,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 2,
#   'PPP': 2,
#   'BS': 53,
#   'Hits': 60,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478109',
#   'Player Name': 'Victor Olofsson',
#   'Team': 'BUF',
#   'Position': 'LW',
#   'Games': 54,
#   'G': 20,
#   'A': 22,
#   'Points': 42,
#   '+/-': -1,
#   'PIM': 6,
#   'SOG': 127,
#   'GWG': 4,
#   'PPG': 11,
#   'PPA': 6,
#   'PPP': 17,
#   'BS': 16,
#   'Hits': 10,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478403',
#   'Player Name': 'Jack Eichel',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 68,
#   'G': 36,
#   'A': 42,
#   'Points': 78,
#   '+/-': 5,
#   'PIM': 34,
#   'SOG': 227,
#   'GWG': 9,
#   'PPG': 11,
#   'PPA': 16,
#   'PPP': 27,
#   'BS': 42,
#   'Hits': 40,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8479420',
#   'Player Name': 'Tage Thompson',
#   'Team': 'BUF',
#   'Position': 'RW',
#   'Games': 1,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 2,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479999',
#   'Player Name': 'Casey Mittelstadt',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 31,
#   'G': 4,
#   'A': 5,
#   'Points': 9,
#   '+/-': -5,
#   'PIM': 2,
#   'SOG': 34,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 1,
#   'PPP': 2,
#   'BS': 8,
#   'Hits': 11,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480035',
#   'Player Name': 'Henri Jokiharju',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 69,
#   'G': 4,
#   'A': 11,
#   'Points': 15,
#   '+/-': -6,
#   'PIM': 32,
#   'SOG': 78,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 1,
#   'PPP': 2,
#   'BS': 63,
#   'Hits': 74,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480839',
#   'Player Name': 'Rasmus Dahlin',
#   'Team': 'BUF',
#   'Position': 'D',
#   'Games': 59,
#   'G': 4,
#   'A': 36,
#   'Points': 40,
#   '+/-': -7,
#   'PIM': 38,
#   'SOG': 90,
#   'GWG': 1,
#   'PPG': 2,
#   'PPA': 17,
#   'PPP': 19,
#   'BS': 51,
#   'Hits': 72,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8481528',
#   'Player Name': 'Dylan Cozens',
#   'Team': 'BUF',
#   'Position': 'C',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8470621',
#   'Player Name': 'Corey Perry',
#   'Team': 'MTL',
#   'Position': 'RW',
#   'Games': 57,
#   'G': 5,
#   'A': 16,
#   'Points': 21,
#   '+/-': -2,
#   'PIM': 70,
#   'SOG': 77,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 6,
#   'PPP': 7,
#   'BS': 33,
#   'Hits': 60,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8473564',
#   'Player Name': 'Michael Frolik',
#   'Team': 'MTL',
#   'Position': 'RW',
#   'Games': 57,
#   'G': 6,
#   'A': 8,
#   'Points': 14,
#   '+/-': -12,
#   'PIM': 28,
#   'SOG': 70,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 22,
#   'Hits': 32,
#   'SHG': 2,
#   'SHA': 1},
#  {'player_id': '8478133',
#   'Player Name': 'Jake Evans',
#   'Team': 'MTL',
#   'Position': 'C',
#   'Games': 13,
#   'G': 2,
#   'A': 1,
#   'Points': 3,
#   '+/-': 1,
#   'PIM': 0,
#   'SOG': 14,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 5,
#   'Hits': 16,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8470642',
#   'Player Name': 'Shea Weber',
#   'Team': 'MTL',
#   'Position': 'D',
#   'Games': 65,
#   'G': 15,
#   'A': 21,
#   'Points': 36,
#   '+/-': 8,
#   'PIM': 33,
#   'SOG': 185,
#   'GWG': 2,
#   'PPG': 3,
#   'PPA': 5,
#   'PPP': 8,
#   'BS': 114,
#   'Hits': 112,
#   'SHG': 0,
#   'SHA': 0},
# ...
#   'Team': 'WPG',
#   'Position': 'D',
#   'Games': 38,
#   'G': 1,
#   'A': 7,
#   'Points': 8,
#   '+/-': 15,
#   'PIM': 29,
#   'SOG': 38,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 47,
#   'Hits': 62,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477429',
#   'Player Name': 'Andrew Copp',
#   'Team': 'WPG',
#   'Position': 'C',
#   'Games': 63,
#   'G': 10,
#   'A': 16,
#   'Points': 26,
#   '+/-': -3,
#   'PIM': 10,
#   'SOG': 121,
#   'GWG': 5,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 27,
#   'Hits': 59,
#   'SHG': 0,
#   'SHA': 3},
#  {'player_id': '8477504',
#   'Player Name': 'Josh Morrissey',
#   'Team': 'WPG',
#   'Position': 'D',
#   'Games': 65,
#   'G': 5,
#   'A': 26,
#   'Points': 31,
#   '+/-': 1,
#   'PIM': 24,
#   'SOG': 120,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 11,
#   'PPP': 12,
#   'BS': 59,
#   'Hits': 34,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477940',
#   'Player Name': 'Nikolaj Ehlers',
#   'Team': 'WPG',
#   'Position': 'LW',
#   'Games': 71,
#   'G': 25,
#   'A': 33,
#   'Points': 58,
#   '+/-': 14,
#   'PIM': 30,
#   'SOG': 203,
#   'GWG': 5,
#   'PPG': 3,
#   'PPA': 2,
#   'PPP': 5,
#   'BS': 28,
#   'Hits': 36,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8478398',
#   'Player Name': 'Kyle Connor',
#   'Team': 'WPG',
#   'Position': 'LW',
#   'Games': 71,
#   'G': 38,
#   'A': 35,
#   'Points': 73,
#   '+/-': 4,
#   'PIM': 34,
#   'SOG': 239,
#   'GWG': 7,
#   'PPG': 9,
#   'PPA': 8,
#   'PPP': 17,
#   'BS': 17,
#   'Hits': 18,
#   'SHG': 1,
#   'SHA': 1},
#  {'player_id': '8478891',
#   'Player Name': 'Mason Appleton',
#   'Team': 'WPG',
#   'Position': 'C',
#   'Games': 46,
#   'G': 5,
#   'A': 3,
#   'Points': 8,
#   '+/-': -9,
#   'PIM': 20,
#   'SOG': 55,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 12,
#   'Hits': 20,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8478915',
#   'Player Name': 'Sami Niku',
#   'Team': 'WPG',
#   'Position': 'D',
#   'Games': 17,
#   'G': 0,
#   'A': 5,
#   'Points': 5,
#   '+/-': -2,
#   'PIM': 12,
#   'SOG': 27,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 19,
#   'Hits': 16,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479378',
#   'Player Name': 'Logan Stanley',
#   'Team': 'WPG',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479400',
#   'Player Name': 'Pierre-Luc Dubois',
#   'Team': 'WPG',
#   'Position': 'LW',
#   'Games': 70,
#   'G': 18,
#   'A': 31,
#   'Points': 49,
#   '+/-': -2,
#   'PIM': 49,
#   'SOG': 158,
#   'GWG': 4,
#   'PPG': 1,
#   'PPA': 9,
#   'PPP': 10,
#   'BS': 50,
#   'Hits': 85,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480145',
#   'Player Name': 'Neal Pionk',
#   'Team': 'WPG',
#   'Position': 'D',
#   'Games': 71,
#   'G': 6,
#   'A': 39,
#   'Points': 45,
#   '+/-': 10,
#   'PIM': 32,
#   'SOG': 177,
#   'GWG': 1,
#   'PPG': 3,
#   'PPA': 22,
#   'PPP': 25,
#   'BS': 78,
#   'Hits': 165,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8481019',
#   'Player Name': 'David Gustafsson',
#   'Team': 'WPG',
#   'Position': 'C',
#   'Games': 22,
#   'G': 1,
#   'A': 0,
#   'Points': 1,
#   '+/-': -2,
#   'PIM': 0,
#   'SOG': 4,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 6,
#   'Hits': 5,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475171',
#   'Player Name': 'Oliver Ekman-Larsson',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 66,
#   'G': 9,
#   'A': 21,
#   'Points': 30,
#   '+/-': -3,
#   'PIM': 38,
#   'SOG': 135,
#   'GWG': 1,
#   'PPG': 2,
#   'PPA': 5,
#   'PPP': 7,
#   'BS': 65,
#   'Hits': 129,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8478432',
#   'Player Name': 'Christian Fischer',
#   'Team': 'ARI',
#   'Position': 'RW',
#   'Games': 56,
#   'G': 6,
#   'A': 3,
#   'Points': 9,
#   '+/-': 2,
#   'PIM': 16,
#   'SOG': 83,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 22,
#   'Hits': 140,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478476',
#   'Player Name': 'Kyle Capobianco',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 9,
#   'G': 1,
#   'A': 0,
#   'Points': 1,
#   '+/-': -1,
#   'PIM': 2,
#   'SOG': 10,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 10,
#   'Hits': 14,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480913',
#   'Player Name': 'Jordan Gross',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 2,
#   'G': 0,
#   'A': 1,
#   'Points': 1,
#   '+/-': 2,
#   'PIM': 0,
#   'SOG': 3,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 1,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8471274',
#   'Player Name': 'Alex Goligoski',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 70,
#   'G': 4,
#   'A': 28,
#   'Points': 32,
#   '+/-': 8,
#   'PIM': 24,
#   'SOG': 101,
#   'GWG': 0,
#   'PPG': 2,
#   'PPA': 9,
#   'PPP': 11,
#   'BS': 134,
#   'Hits': 91,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8471769',
#   'Player Name': 'Niklas Hjalmarsson',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 27,
#   'G': 1,
#   'A': 4,
#   'Points': 5,
#   '+/-': -2,
#   'PIM': 14,
#   'SOG': 18,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 46,
#   'Hits': 20,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8473544',
#   'Player Name': 'Derick Brassard',
#   'Team': 'ARI',
#   'Position': 'C',
#   'Games': 66,
#   'G': 10,
#   'A': 22,
#   'Points': 32,
#   '+/-': -2,
#   'PIM': 16,
#   'SOG': 110,
#   'GWG': 1,
#   'PPG': 3,
#   'PPA': 7,
#   'PPP': 10,
#   'BS': 24,
#   'Hits': 115,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8473548',
#   'Player Name': 'Phil Kessel',
#   'Team': 'ARI',
#   'Position': 'RW',
#   'Games': 70,
#   'G': 14,
#   'A': 24,
#   'Points': 38,
#   '+/-': -21,
#   'PIM': 22,
#   'SOG': 153,
#   'GWG': 2,
#   'PPG': 9,
#   'PPA': 8,
#   'PPP': 17,
#   'BS': 20,
#   'Hits': 11,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474218',
#   'Player Name': 'Jason Demers',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 50,
#   'G': 0,
#   'A': 11,
#   'Points': 11,
#   '+/-': 5,
#   'PIM': 25,
#   'SOG': 53,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 70,
#   'Hits': 76,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8475728',
#   'Player Name': 'Johan Larsson',
#   'Team': 'ARI',
#   'Position': 'LW',
#   'Games': 62,
#   'G': 6,
#   'A': 12,
#   'Points': 18,
#   '+/-': 8,
#   'PIM': 26,
#   'SOG': 60,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 31,
#   'Hits': 85,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475752',
#   'Player Name': 'Tyler Pitlick',
#   'Team': 'ARI',
#   'Position': 'C',
#   'Games': 63,
#   'G': 8,
#   'A': 12,
#   'Points': 20,
#   '+/-': 11,
#   'PIM': 12,
#   'SOG': 76,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 42,
#   'Hits': 132,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477401',
#   'Player Name': 'John Hayden',
#   'Team': 'ARI',
#   'Position': 'C',
#   'Games': 43,
#   'G': 3,
#   'A': 1,
#   'Points': 4,
#   '+/-': -2,
#   'PIM': 77,
#   'SOG': 39,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 27,
#   'Hits': 87,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477851',
#   'Player Name': 'Jordan Oesterle',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 58,
#   'G': 3,
#   'A': 10,
#   'Points': 13,
#   '+/-': -9,
#   'PIM': 14,
#   'SOG': 69,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 2,
#   'PPP': 2,
#   'BS': 88,
#   'Hits': 48,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477951',
#   'Player Name': 'Nick Schmaltz',
#   'Team': 'ARI',
#   'Position': 'C',
#   'Games': 70,
#   'G': 11,
#   'A': 34,
#   'Points': 45,
#   '+/-': 3,
#   'PIM': 20,
#   'SOG': 95,
#   'GWG': 2,
#   'PPG': 2,
#   'PPA': 11,
#   'PPP': 13,
#   'BS': 34,
#   'Hits': 12,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477989',
#   'Player Name': 'Christian Dvorak',
#   'Team': 'ARI',
#   'Position': 'C',
#   'Games': 70,
#   'G': 18,
#   'A': 20,
#   'Points': 38,
#   '+/-': 6,
#   'PIM': 12,
#   'SOG': 134,
#   'GWG': 2,
#   'PPG': 6,
#   'PPA': 4,
#   'PPP': 10,
#   'BS': 36,
#   'Hits': 39,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478474',
#   'Player Name': 'Lawson Crouse',
#   'Team': 'ARI',
#   'Position': 'LW',
#   'Games': 66,
#   'G': 15,
#   'A': 10,
#   'Points': 25,
#   '+/-': 0,
#   'PIM': 33,
#   'SOG': 109,
#   'GWG': 3,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 29,
#   'Hits': 201,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8478856',
#   'Player Name': 'Conor Garland',
#   'Team': 'ARI',
#   'Position': 'RW',
#   'Games': 68,
#   'G': 22,
#   'A': 17,
#   'Points': 39,
#   '+/-': 1,
#   'PIM': 20,
#   'SOG': 158,
#   'GWG': 5,
#   'PPG': 4,
#   'PPA': 6,
#   'PPP': 10,
#   'BS': 20,
#   'Hits': 26,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479343',
#   'Player Name': 'Clayton Keller',
#   'Team': 'ARI',
#   'Position': 'RW',
#   'Games': 70,
#   'G': 17,
#   'A': 27,
#   'Points': 44,
#   '+/-': -6,
#   'PIM': 28,
#   'SOG': 184,
#   'GWG': 2,
#   'PPG': 2,
#   'PPA': 13,
#   'PPP': 15,
#   'BS': 13,
#   'Hits': 20,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479345',
#   'Player Name': 'Jakob Chychrun',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 63,
#   'G': 12,
#   'A': 14,
#   'Points': 26,
#   '+/-': 4,
#   'PIM': 38,
#   'SOG': 149,
#   'GWG': 2,
#   'PPG': 5,
#   'PPA': 3,
#   'PPP': 8,
#   'BS': 95,
#   'Hits': 75,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479465',
#   'Player Name': 'Drake Caggiula',
#   'Team': 'ARI',
#   'Position': 'C',
#   'Games': 40,
#   'G': 9,
#   'A': 6,
#   'Points': 15,
#   '+/-': -3,
#   'PIM': 32,
#   'SOG': 56,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 16,
#   'Hits': 81,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8480849',
#   'Player Name': 'Barrett Hayton',
#   'Team': 'ARI',
#   'Position': 'C',
#   'Games': 20,
#   'G': 1,
#   'A': 3,
#   'Points': 4,
#   '+/-': 2,
#   'PIM': 14,
#   'SOG': 27,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 3,
#   'Hits': 14,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480950',
#   'Player Name': 'Ilya Lyubushkin',
#   'Team': 'ARI',
#   'Position': 'D',
#   'Games': 51,
#   'G': 0,
#   'A': 4,
#   'Points': 4,
#   '+/-': 4,
#   'PIM': 18,
#   'SOG': 41,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 53,
#   'Hits': 151,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8475188',
#   'Player Name': 'Brayden McNabb',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 71,
#   'G': 2,
#   'A': 7,
#   'Points': 9,
#   '+/-': 1,
#   'PIM': 40,
#   'SOG': 73,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 133,
#   'Hits': 201,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8476430',
#   'Player Name': 'Tomas Jurco',
#   'Team': 'VGK',
#   'Position': 'RW',
#   'Games': 12,
#   'G': 0,
#   'A': 2,
#   'Points': 2,
#   '+/-': 1,
#   'PIM': 4,
#   'SOG': 7,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 3,
#   'Hits': 4,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8481522',
#   'Player Name': 'Peyton Krebs',
#   'Team': 'VGK',
#   'Position': 'C',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8471817',
#   'Player Name': 'Ryan Reaves',
#   'Team': 'VGK',
#   'Position': 'RW',
#   'Games': 71,
#   'G': 8,
#   'A': 7,
#   'Points': 15,
#   '+/-': -5,
#   'PIM': 47,
#   'SOG': 61,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 24,
#   'Hits': 316,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474157',
#   'Player Name': 'Max Pacioretty',
#   'Team': 'VGK',
#   'Position': 'LW',
#   'Games': 71,
#   'G': 32,
#   'A': 34,
#   'Points': 66,
#   '+/-': 18,
#   'PIM': 44,
#   'SOG': 307,
#   'GWG': 5,
#   'PPG': 8,
#   'PPA': 11,
#   'PPP': 19,
#   'BS': 35,
#   'Hits': 90,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474166',
#   'Player Name': 'Alec Martinez',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 51,
#   'G': 3,
#   'A': 13,
#   'Points': 16,
#   '+/-': -4,
#   'PIM': 23,
#   'SOG': 75,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 4,
#   'PPP': 4,
#   'BS': 117,
#   'Hits': 43,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8474207',
#   'Player Name': 'Nick Holden',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 61,
#   'G': 6,
#   'A': 8,
#   'Points': 14,
#   '+/-': -1,
#   'PIM': 13,
#   'SOG': 101,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 74,
#   'Hits': 129,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8474565',
#   'Player Name': 'Alex Pietrangelo',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 70,
#   'G': 16,
#   'A': 36,
#   'Points': 52,
#   '+/-': 11,
#   'PIM': 20,
#   'SOG': 225,
#   'GWG': 3,
#   'PPG': 6,
#   'PPA': 16,
#   'PPP': 22,
#   'BS': 89,
#   'Hits': 47,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8475191',
#   'Player Name': 'Reilly Smith',
#   'Team': 'VGK',
#   'Position': 'RW',
#   'Games': 71,
#   'G': 27,
#   'A': 27,
#   'Points': 54,
#   '+/-': 17,
#   'PIM': 20,
#   'SOG': 169,
#   'GWG': 6,
#   'PPG': 3,
#   'PPA': 2,
#   'PPP': 5,
#   'BS': 30,
#   'Hits': 55,
#   'SHG': 2,
#   'SHA': 2},
#  {'player_id': '8475913',
#   'Player Name': 'Mark Stone',
#   'Team': 'VGK',
#   'Position': 'RW',
#   'Games': 65,
#   'G': 21,
#   'A': 42,
#   'Points': 63,
#   '+/-': 15,
#   'PIM': 27,
#   'SOG': 168,
#   'GWG': 3,
#   'PPG': 6,
#   'PPA': 11,
#   'PPP': 17,
#   'BS': 51,
#   'Hits': 56,
#   'SHG': 0,
#   'SHA': 1},
#  {'player_id': '8476448',
#   'Player Name': 'William Karlsson',
#   'Team': 'VGK',
#   'Position': 'C',
#   'Games': 63,
#   'G': 15,
#   'A': 31,
#   'Points': 46,
#   '+/-': 11,
#   'PIM': 16,
#   'SOG': 138,
#   'GWG': 1,
#   'PPG': 2,
#   'PPA': 6,
#   'PPP': 8,
#   'BS': 38,
#   'Hits': 40,
#   'SHG': 2,
#   'SHA': 3},
#  {'player_id': '8476539',
#   'Player Name': 'Jonathan Marchessault',
#   'Team': 'VGK',
#   'Position': 'C',
#   'Games': 66,
#   'G': 22,
#   'A': 25,
#   'Points': 47,
#   '+/-': 6,
#   'PIM': 28,
#   'SOG': 235,
#   'GWG': 3,
#   'PPG': 6,
#   'PPA': 6,
#   'PPP': 12,
#   'BS': 12,
#   'Hits': 99,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8476905',
#   'Player Name': 'Chandler Stephenson',
#   'Team': 'VGK',
#   'Position': 'C',
#   'Games': 65,
#   'G': 11,
#   'A': 15,
#   'Points': 26,
#   '+/-': 24,
#   'PIM': 16,
#   'SOG': 73,
#   'GWG': 5,
#   'PPG': 1,
#   'PPA': 1,
#   'PPP': 2,
#   'BS': 32,
#   'Hits': 52,
#   'SHG': 2,
#   'SHA': 1},
#  {'player_id': '8477447',
#   'Player Name': 'Shea Theodore',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 71,
#   'G': 13,
#   'A': 33,
#   'Points': 46,
#   '+/-': 12,
#   'PIM': 25,
#   'SOG': 219,
#   'GWG': 4,
#   'PPG': 1,
#   'PPA': 15,
#   'PPP': 16,
#   'BS': 69,
#   'Hits': 20,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8477478',
#   'Player Name': 'William Carrier',
#   'Team': 'VGK',
#   'Position': 'LW',
#   'Games': 71,
#   'G': 7,
#   'A': 12,
#   'Points': 19,
#   '+/-': 0,
#   'PIM': 39,
#   'SOG': 99,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 11,
#   'Hits': 213,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8477931',
#   'Player Name': 'Tomas Nosek',
#   'Team': 'VGK',
#   'Position': 'LW',
#   'Games': 67,
#   'G': 8,
#   'A': 7,
#   'Points': 15,
#   '+/-': -2,
#   'PIM': 20,
#   'SOG': 93,
#   'GWG': 1,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 38,
#   'Hits': 91,
#   'SHG': 1,
#   'SHA': 0},
#  {'player_id': '8477949',
#   'Player Name': 'Alex Tuch',
#   'Team': 'VGK',
#   'Position': 'RW',
#   'Games': 42,
#   'G': 8,
#   'A': 9,
#   'Points': 17,
#   '+/-': -10,
#   'PIM': 8,
#   'SOG': 98,
#   'GWG': 2,
#   'PPG': 3,
#   'PPA': 4,
#   'PPP': 7,
#   'BS': 20,
#   'Hits': 58,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478434',
#   'Player Name': 'Keegan Kolesar',
#   'Team': 'VGK',
#   'Position': 'RW',
#   'Games': 1,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 1,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 2,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8478462',
#   'Player Name': 'Nicolas Roy',
#   'Team': 'VGK',
#   'Position': 'C',
#   'Games': 28,
#   'G': 5,
#   'A': 5,
#   'Points': 10,
#   '+/-': 3,
#   'PIM': 8,
#   'SOG': 42,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 0,
#   'PPP': 1,
#   'BS': 7,
#   'Hits': 39,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479639',
#   'Player Name': 'Dylan Coghlan',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 0,
#   'G': 0,
#   'A': 0,
#   'Points': 0,
#   '+/-': 0,
#   'PIM': 0,
#   'SOG': 0,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 0,
#   'Hits': 0,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479980',
#   'Player Name': 'Nicolas Hague',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 38,
#   'G': 1,
#   'A': 10,
#   'Points': 11,
#   '+/-': 0,
#   'PIM': 32,
#   'SOG': 54,
#   'GWG': 0,
#   'PPG': 1,
#   'PPA': 3,
#   'PPP': 4,
#   'BS': 26,
#   'Hits': 69,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8479996',
#   'Player Name': 'Cody Glass',
#   'Team': 'VGK',
#   'Position': 'C',
#   'Games': 39,
#   'G': 5,
#   'A': 7,
#   'Points': 12,
#   '+/-': -7,
#   'PIM': 6,
#   'SOG': 51,
#   'GWG': 1,
#   'PPG': 1,
#   'PPA': 5,
#   'PPP': 6,
#   'BS': 6,
#   'Hits': 15,
#   'SHG': 0,
#   'SHA': 0},
#  {'player_id': '8480727',
#   'Player Name': 'Zach Whitecloud',
#   'Team': 'VGK',
#   'Position': 'D',
#   'Games': 16,
#   'G': 0,
#   'A': 1,
#   'Points': 1,
#   '+/-': 3,
#   'PIM': 4,
#   'SOG': 9,
#   'GWG': 0,
#   'PPG': 0,
#   'PPA': 0,
#   'PPP': 0,
#   'BS': 16,
#   'Hits': 10,
#   'SHG': 0,
#   'SHA': 0}]
